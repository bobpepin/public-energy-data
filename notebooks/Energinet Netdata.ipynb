# %%
import sys
if ".." not in sys.path:
    sys.path.append("..")
import openpyxl
from energydata import energinet

import importlib
energinet = importlib.reload(energinet)

# %%
descriptor = {"resource_id": "connectionpointsingrid"}
service = energinet.EnergiDataServiceDk(descriptor)

# %%
list(energinet.fetch_edh(descriptor, 1))
# Out:
# []

# %%
list(service.fetch_data())
# Out:
# [{'_id': 1001,
#   'ConnectionPointCode': 'ØLS',
#   'ConnectionPointName': 'Ølstykkegård',
#   'MunicipalityNo': '240',
#   'Municipality': 'Egedal',
#   'RegionName': 'Hovedstaden',
#   'ConnectionPointLatitude': 55.77148,
#   'ConnectionPointLongitude': 12.143712,
#   'NetCompanyName': 'REGIONALE NET',
#   'region_code': 'dk_mun_240'},
#  {'_id': 20,
#   'ConnectionPointCode': 'AMK',
#   'ConnectionPointName': 'Amagerkbst',
#   'MunicipalityNo': '101',
#   'Municipality': 'København',
#   'RegionName': 'Hovedstaden',
#   'ConnectionPointLatitude': 55.641284,
#   'ConnectionPointLongitude': 12.609259,
#   'NetCompanyName': 'KE TRANSMISSION',
#   'region_code': 'dk_mun_101'},
#  {'_id': 22,
#   'ConnectionPointCode': 'AMV',
#   'ConnectionPointName': 'Amagerværket',
#   'MunicipalityNo': '101',
#   'Municipality': 'København',
#   'RegionName': 'Hovedstaden',
#   'ConnectionPointLatitude': 55.685241,
#   'ConnectionPointLongitude': 12.624494,
#   'NetCompanyName': 'KE TRANSMISSION',
#   'region_code': 'dk_mun_101'},
#  {'_id': 23,
#   'ConnectionPointCode': 'AND',
#   'ConnectionPointName': 'Andst',
#   'MunicipalityNo': '575',
#   'Municipality': 'Vejen',
#   'RegionName': 'Syddanmark',
#   'ConnectionPointLatitude': 55.472217,
#   'ConnectionPointLongitude': 9.246799,
#   'NetCompanyName': 'Sydøstjyske Net A/S',
#   'region_code': 'dk_mun_575'},
#  {'_id': 29,
#   'ConnectionPointCode': 'ASR',
#   'ConnectionPointName': 'Askær',
#   'MunicipalityNo': '756',
#   'Municipality': 'Ikast-Brande',
#   'RegionName': 'Midtjylland',
#   'ConnectionPointLatitude': 55.929066,
#   'ConnectionPointLongitude': 9.182534,
#   'NetCompanyName': 'Sydøstjyske Net A/S',
#   'region_code': 'dk_mun_756'},
#  {'_id': 32,
#   'ConnectionPointCode': 'ASV',
#   'ConnectionPointName': 'Asnæsværket',
#   'MunicipalityNo': '326',
#   'Municipality': 'Kalundborg',
#   'RegionName': 'Sjælland',
#   'ConnectionPointLatitude': 55.662748,
#   'ConnectionPointLongitude': 11.069824,
#   'NetCompanyName': 'SEAS/NVE NET',
#   'region_code': 'dk_mun_326'},
#  {'_id': 39,
#   'ConnectionPointCode': 'AVV',
#   'ConnectionPointName': 'Avedøreværket',
#   'MunicipalityNo': '167',
#   'Municipality': 'Hvidovre',
#   'RegionName': 'Hovedstaden',
#   'ConnectionPointLatitude': 55.604989,
#   'ConnectionPointLongitude': 12.480812,
#   'NetCompanyName': 'REGIONALE NET',
#   'region_code': 'dk_mun_167'},
#  {'_id': 41,
#   'ConnectionPointCode': 'BAG',
#   'ConnectionPointName': 'Bagsværdgård',
#   'MunicipalityNo': '159',
#   'Municipality': 'Gladsaxe',
#   'RegionName': 'Hovedstaden',
#   'ConnectionPointLatitude': 55.757222,
#   'ConnectionPointLongitude': 12.45374,
#   'NetCompanyName': 'REGIONALE NET',
#   'region_code': 'dk_mun_159'},
#  {'_id': 43,
#   'ConnectionPointCode': 'BALV',
#   'ConnectionPointName': 'Ballum',
#   'MunicipalityNo': '550',
#   'Municipality': 'Tønder',
#   'RegionName': 'Syddanmark',
#   'ConnectionPointLatitude': 55.05743,
#   'ConnectionPointLongitude': 8.69692,
#   'NetCompanyName': 'N1',
#   'region_code': 'dk_mun_550'},
#  {'_id': 45,
#   'ConnectionPointCode': 'BAR',
#   'ConnectionPointName': 'BARRIT',
#   'MunicipalityNo': '766',
#   'Municipality': 'Hedensted',
#   'RegionName': 'Midtjylland',
#   'ConnectionPointLatitude': 55.72334,
#   'ConnectionPointLongitude': 9.89668,
#   'NetCompanyName': 'Konstant Syd',
#   'region_code': 'dk_mun_766'},
#  {'_id': 49,
#   'ConnectionPointCode': 'BBR',
#   'ConnectionPointName': 'Bredebro',
#   'MunicipalityNo': '550',
#   'Municipality': 'Tønder',
#   'RegionName': 'Syddanmark',
#   'ConnectionPointLatitude': 55.053378,
#   'ConnectionPointLongitude': 8.836996,
#   'NetCompanyName': 'Syd Net A/S',
#   'region_code': 'dk_mun_550'},
#  {'_id': 52,
#   'ConnectionPointCode': 'BDK',
#   'ConnectionPointName': 'Bredkær',
#   'MunicipalityNo': '860',
#   'Municipality': 'Hjørring',
#   'RegionName': 'Nordjylland',
#   'ConnectionPointLatitude': 57.450695,
#   'ConnectionPointLongitude': 10.026742,
#   'NetCompanyName': 'NV Net Amba',
#   'region_code': 'dk_mun_860'},
#  {'_id': 53,
#   'ConnectionPointCode': 'BDR',
#   'ConnectionPointName': 'Bramdrup',
#   'MunicipalityNo': '621',
#   'Municipality': 'Kolding',
#   'RegionName': 'Syddanmark',
#   'ConnectionPointLatitude': 55.510641,
#   'ConnectionPointLongitude': 9.462136,
#   'NetCompanyName': 'Sydøstjyske Net A/S',
#   'region_code': 'dk_mun_621'},
#  {'_id': 2,
#   'ConnectionPointCode': 'ABI',
#   'ConnectionPointName': 'Abild',
#   'MunicipalityNo': '550',
#   'Municipality': 'Tønder',
#   'RegionName': 'Syddanmark',
#   'ConnectionPointLatitude': 54.98199,
#   'ConnectionPointLongitude': 8.881553,
#   'NetCompanyName': 'Konstant Syd',
#   'region_code': 'dk_mun_550'},
#  {'_id': 4,
#   'ConnectionPointCode': 'ABS',
#   'ConnectionPointName': 'Abildskov',
#   'MunicipalityNo': '420',
#   'Municipality': 'Assens',
#   'RegionName': 'Syddanmark',
#   'ConnectionPointLatitude': 55.249257,
#   'ConnectionPointLongitude': 10.168535,
#   'NetCompanyName': 'FynsNet a.m.b.a.',
#   'region_code': 'dk_mun_420'},
#  {'_id': 6,
#   'ConnectionPointCode': 'ADL',
#   'ConnectionPointName': 'Ådalen',
#   'MunicipalityNo': '851',
#   'Municipality': 'Aalborg',
#   'RegionName': 'Nordjylland',
#   'ConnectionPointLatitude': 57.024592,
#   'ConnectionPointLongitude': 9.920004,
#   'NetCompanyName': 'NV Net Amba',
#   'region_code': 'dk_mun_851'},
#  {'_id': 16,
#   'ConnectionPointCode': 'ALG',
#   'ConnectionPointName': 'Allinge',
#   'MunicipalityNo': '400',
#   'Municipality': 'Bornholm',
#   'RegionName': 'Hovedstaden',
#   'ConnectionPointLatitude': 55.2474,
#   'ConnectionPointLongitude': 14.79562,
#   'NetCompanyName': 'El-Net oest A/S',
#   'region_code': 'dk_mun_400'},
#  {'_id': 17,
#   'ConnectionPointCode': 'ALL',
#   'ConnectionPointName': 'Allerrødgård',
#   'MunicipalityNo': '201',
#   'Municipality': 'Allerød',
#   'RegionName': 'Hovedstaden',
#   'ConnectionPointLatitude': 55.885227,
#   'ConnectionPointLongitude': 12.338456,
#   'NetCompanyName': 'REGIONALE NET',
#   'region_code': 'dk_mun_201'},
#  {'_id': 56,
#   'ConnectionPointCode': 'BED',
#   'ConnectionPointName': 'Bedsted',
#   'MunicipalityNo': '787',
#   'Municipality': 'Thisted',
#   'RegionName': 'Nordjylland',
#   'ConnectionPointLatitude': 56.810406,
#   'ConnectionPointLongitude': 8.415304,
#   'NetCompanyName': 'Vestjyske Net A/S',
#   'region_code': 'dk_mun_787'},
#  {'_id': 57,
#   'ConnectionPointCode': 'BEG',
#   'ConnectionPointName': 'Begtrup',
#   'MunicipalityNo': '706',
#   'Municipality': 'Syddjurs',
#   'RegionName': 'Midtjylland',
#   'ConnectionPointLatitude': 56.18787,
#   'ConnectionPointLongitude': 10.5192,
#   'NetCompanyName': 'Konstant Nord',
#   'region_code': 'dk_mun_706'},
#  {'_id': 58,
#   'ConnectionPointCode': 'BELV',
#   'ConnectionPointName': 'Bellinge',
#   'MunicipalityNo': '461',
#   'Municipality': 'Odense',
#   'RegionName': 'Syddanmark',
#   'ConnectionPointLatitude': 55.32802,
#   'ConnectionPointLongitude': 10.28828,
#   'NetCompanyName': 'VORES ELNET A/S',
#   'region_code': 'dk_mun_461'},
#  {'_id': 70,
#   'ConnectionPointCode': 'BIRV',
#   'ConnectionPointName': 'Birkelse',
#   'MunicipalityNo': '849',
#   'Municipality': 'Jammerbugt',
#   'RegionName': 'Nordjylland',
#   'ConnectionPointLatitude': 57.14337,
#   'ConnectionPointLongitude': 9.67849,
#   'NetCompanyName': 'N1',
#   'region_code': 'dk_mun_849'},
#  {'_id': 74,
#   'ConnectionPointCode': 'BJEV',
#   'ConnectionPointName': 'Bjerre',
#   'MunicipalityNo': '766',
#   'Municipality': 'Hedensted',
#   'RegionName': 'Midtjylland',
#   'ConnectionPointLatitude': 55.77997,
#   'ConnectionPointLongitude': 9.84898,
#   'NetCompanyName': 'Konstant Syd',
#   'region_code': 'dk_mun_766'},
#  {'_id': 76,
#   'ConnectionPointCode': 'BJS',
#   'ConnectionPointName': 'Bjæverskov',
#   'MunicipalityNo': '259',
#   'Municipality': 'Køge',
#   'RegionName': 'Sjælland',
#   'ConnectionPointLatitude': 55.45053,
#   'ConnectionPointLongitude': 12.00791,
#   'NetCompanyName': 'SEAS/NVE TRANSMISSION',
#   'region_code': 'dk_mun_259'},
#  {'_id': 79,
#   'ConnectionPointCode': 'BLA',
#   'ConnectionPointName': 'Blangslev',
#   'MunicipalityNo': '370',
#   'Municipality': 'Næstved',
#   'RegionName': 'Sjælland',
#   'ConnectionPointLatitude': 55.167546,
#   'ConnectionPointLongitude': 11.901284,
#   'NetCompanyName': 'SEAS/NVE TRANSMISSION',
#   'region_code': 'dk_mun_370'},
#  {'_id': 94,
#   'ConnectionPointCode': 'BOR',
#   'ConnectionPointName': 'Borup',
#   'MunicipalityNo': '219',
#   'Municipality': 'Hillerød',
#   'RegionName': 'Hovedstaden',
#   'ConnectionPointLatitude': 55.908136,
#   'ConnectionPointLongitude': 12.178718,
#   'NetCompanyName': 'REGIONALE NET',
#   'region_code': 'dk_mun_219'},
#  {'_id': 108,
#   'ConnectionPointCode': 'BRYV',
#   'ConnectionPointName': 'Bryrup',
#   'MunicipalityNo': '615',
#   'Municipality': 'Horsens',
#   'RegionName': 'Midtjylland',
#   'ConnectionPointLatitude': 56.01916,
#   'ConnectionPointLongitude': 9.57011,
#   'NetCompanyName': 'N1',
#   'region_code': 'dk_mun_615'},
#  {'_id': 118,
#   'ConnectionPointCode': 'BYG',
#   'ConnectionPointName': 'Bygholm C',
#   'MunicipalityNo': '615',
#   'Municipality': 'Horsens',
#   'RegionName': 'Midtjylland',
#   'ConnectionPointLatitude': 55.86179,
#   'ConnectionPointLongitude': 9.82403,
#   'NetCompanyName': 'Konstant Syd',
#   'region_code': 'dk_mun_615'},
#  {'_id': 119,
#   'ConnectionPointCode': 'BYN',
#   'ConnectionPointName': 'Byen',
#   'MunicipalityNo': '751',
#   'Municipality': 'Aarhus',
#   'RegionName': 'Midtjylland',
#   'ConnectionPointLatitude': 56.15407,
#   'ConnectionPointLongitude': 10.18114,
#   'NetCompanyName': 'Konstant Nord',
#   'region_code': 'dk_mun_751'},
#  {'_id': 122,
#   'ConnectionPointCode': 'CHB',
#   'ConnectionPointName': 'Christiansbjerg',
#   'MunicipalityNo': '751',
#   'Municipality': 'Aarhus',
#   'RegionName': 'Midtjylland',
#   'ConnectionPointLatitude': 56.19175,
#   'ConnectionPointLongitude': 10.18695,
#   'NetCompanyName': 'Konstant Nord',
#   'region_code': 'dk_mun_751'},
#  {'_id': 140,
#   'ConnectionPointCode': 'DYB',
#   'ConnectionPointName': 'Dybvad',
#   'MunicipalityNo': '813',
#   'Municipality': 'Frederikshavn',
#   'RegionName': 'Nordjylland',
#   'ConnectionPointLatitude': 57.287356,
#   'ConnectionPointLongitude': 10.380106,
#   'NetCompanyName': 'NV Net Amba',
#   'region_code': 'dk_mun_813'},
#  {'_id': 141,
#   'ConnectionPointCode': 'DYRV',
#   'ConnectionPointName': 'Dyrup',
#   'MunicipalityNo': '461',
#   'Municipality': 'Odense',
#   'RegionName': 'Syddanmark',
#   'ConnectionPointLatitude': 55.35296,
#   'ConnectionPointLongitude': 10.33307,
#   'NetCompanyName': 'VORES ELNET A/S',
#   'region_code': 'dk_mun_461'},
#  {'_id': 147,
#   'ConnectionPointCode': 'EBR',
#   'ConnectionPointName': 'Egåbro',
#   'MunicipalityNo': '751',
#   'Municipality': 'Aarhus',
#   'RegionName': 'Midtjylland',
#   'ConnectionPointLatitude': 56.20482,
#   'ConnectionPointLongitude': 10.25069,
#   'NetCompanyName': 'Konstant Nord',
#   'region_code': 'dk_mun_751'},
#  {'_id': 148,
#   'ConnectionPointCode': 'EBT',
#   'ConnectionPointName': 'Ebeltoft',
#   'MunicipalityNo': '706',
#   'Municipality': 'Syddjurs',
#   'RegionName': 'Midtjylland',
#   'ConnectionPointLatitude': 56.20616,
#   'ConnectionPointLongitude': 10.68448,
#   'NetCompanyName': 'Konstant Nord',
#   'region_code': 'dk_mun_706'},
#  {'_id': 149,
#   'ConnectionPointCode': 'EBY',
#   'ConnectionPointName': 'Ejbygård',
#   'MunicipalityNo': '161',
#   'Municipality': 'Glostrup',
#   'RegionName': 'Hovedstaden',
#   'ConnectionPointLatitude': 55.686573,
#   'ConnectionPointLongitude': 12.397478,
#   'NetCompanyName': 'REGIONALE NET',
#   'region_code': 'dk_mun_161'},
#  {'_id': 150,
#   'ConnectionPointCode': 'EDR',
#   'ConnectionPointName': 'Endrup',
#   'MunicipalityNo': '561',
#   'Municipality': 'Esbjerg',
#   'RegionName': 'Syddanmark',
#   'ConnectionPointLatitude': 55.531823,
#   'ConnectionPointLongitude': 8.707872,
#   'NetCompanyName': 'Vestjyske Net A/S',
#   'region_code': 'dk_mun_561'},
#  {'_id': 165,
#   'ConnectionPointCode': 'ELE',
#   'ConnectionPointName': 'Elev',
#   'MunicipalityNo': '751',
#   'Municipality': 'Aarhus',
#   'RegionName': 'Midtjylland',
#   'ConnectionPointLatitude': 56.23243,
#   'ConnectionPointLongitude': 10.21047,
#   'NetCompanyName': 'Konstant Nord',
#   'region_code': 'dk_mun_751'},
#  {'_id': 171,
#   'ConnectionPointCode': 'ESK',
#   'ConnectionPointName': 'Eskilstrup',
#   'MunicipalityNo': '376',
#   'Municipality': 'Guldborgsund',
#   'RegionName': 'Sjælland',
#   'ConnectionPointLatitude': 54.849705,
#   'ConnectionPointLongitude': 11.893968,
#   'NetCompanyName': 'SEAS/NVE TRANSMISSION',
#   'region_code': 'dk_mun_376'},
#  {'_id': 173,
#   'ConnectionPointCode': 'EST',
#   'ConnectionPointName': 'Estrupvej',
#   'MunicipalityNo': '561',
#   'Municipality': 'Esbjerg',
#   'RegionName': 'Syddanmark',
#   'ConnectionPointLatitude': 55.462691,
#   'ConnectionPointLongitude': 8.474662,
#   'NetCompanyName': 'Vestjyske Net A/S',
#   'region_code': 'dk_mun_561'},
#  {'_id': 180,
#   'ConnectionPointCode': 'FARV',
#   'ConnectionPointName': 'Farstrup',
#   'MunicipalityNo': '480',
#   'Municipality': 'Nordfyn',
#   'RegionName': 'Syddanmark',
#   'ConnectionPointLatitude': 55.46349,
#   'ConnectionPointLongitude': 10.1906,
#   'NetCompanyName': 'VORES ELNET A/S',
#   'region_code': 'dk_mun_480'},
#  {'_id': 188,
#   'ConnectionPointCode': 'FER',
#   'ConnectionPointName': 'Ferslev',
#   'MunicipalityNo': '851',
#   'Municipality': 'Aalborg',
#   'RegionName': 'Nordjylland',
#   'ConnectionPointLatitude': 56.957586,
#   'ConnectionPointLongitude': 9.881441,
#   'NetCompanyName': 'NV Net Amba',
#   'region_code': 'dk_mun_851'},
#  {'_id': 190,
#   'ConnectionPointCode': 'FGD',
#   'ConnectionPointName': 'Fraugde',
#   'MunicipalityNo': '461',
#   'Municipality': 'Odense',
#   'RegionName': 'Syddanmark',
#   'ConnectionPointLatitude': 55.365471,
#   'ConnectionPointLongitude': 10.502758,
#   'NetCompanyName': 'FynsNet a.m.b.a.',
#   'region_code': 'dk_mun_461'},
#  {'_id': 195,
#   'ConnectionPointCode': 'FLAV',
#   'ConnectionPointName': 'Flade',
#   'MunicipalityNo': '773',
#   'Municipality': 'Morsø',
#   'RegionName': 'Nordjylland',
#   'ConnectionPointLatitude': 56.88306,
#   'ConnectionPointLongitude': 8.819394,
#   'NetCompanyName': 'Thy-Mors Energi A/S',
#   'region_code': 'dk_mun_773'},
#  {'_id': 197,
#   'ConnectionPointCode': 'FLB',
#   'ConnectionPointName': 'Flintborg',
#   'MunicipalityNo': '787',
#   'Municipality': 'Thisted',
#   'RegionName': 'Nordjylland',
#   'ConnectionPointLatitude': 56.96705,
#   'ConnectionPointLongitude': 8.72538,
#   'NetCompanyName': 'Thy-Mors Energi A/S',
#   'region_code': 'dk_mun_787'},
#  {'_id': 201,
#   'ConnectionPointCode': 'FNM',
#   'ConnectionPointName': 'Fensmark',
#   'MunicipalityNo': '370',
#   'Municipality': 'Næstved',
#   'RegionName': 'Sjælland',
#   'ConnectionPointLatitude': 55.275149,
#   'ConnectionPointLongitude': 11.820434,
#   'NetCompanyName': 'SEAS/NVE TRANSMISSION',
#   'region_code': 'dk_mun_370'},
#  {'_id': 203,
#   'ConnectionPointCode': 'FRD',
#   'ConnectionPointName': 'Fredensdal',
#   'MunicipalityNo': '849',
#   'Municipality': 'Jammerbugt',
#   'RegionName': 'Nordjylland',
#   'ConnectionPointLatitude': 57.114087,
#   'ConnectionPointLongitude': 9.502717,
#   'NetCompanyName': 'NV Net Amba',
#   'region_code': 'dk_mun_849'},
#  {'_id': 204,
#   'ConnectionPointCode': 'FRI',
#   'ConnectionPointName': 'Frichsvej',
#   'MunicipalityNo': '751',
#   'Municipality': 'Aarhus',
#   'RegionName': 'Midtjylland',
#   'ConnectionPointLatitude': 56.15563,
#   'ConnectionPointLongitude': 10.13814,
#   'NetCompanyName': 'Konstant Nord',
#   'region_code': 'dk_mun_751'},
#  {'_id': 205,
#   'ConnectionPointCode': 'FRSV',
#   'ConnectionPointName': 'Frederiks',
#   'MunicipalityNo': '791',
#   'Municipality': 'Viborg',
#   'RegionName': 'Midtjylland',
#   'ConnectionPointLatitude': 56.34757,
#   'ConnectionPointLongitude': 9.26066,
#   'NetCompanyName': 'N1',
#   'region_code': 'dk_mun_791'},
#  {'_id': 211,
#   'ConnectionPointCode': 'FUGV',
#   'ConnectionPointName': 'Fuglsang',
#   'MunicipalityNo': '707',
#   'Municipality': 'Norddjurs',
#   'RegionName': 'Midtjylland',
#   'ConnectionPointLatitude': 56.39289,
#   'ConnectionPointLongitude': 10.87502,
#   'NetCompanyName': 'Konstant Nord',
#   'region_code': 'dk_mun_707'},
#  {'_id': 212,
#   'ConnectionPointCode': 'FUS',
#   'ConnectionPointName': 'FUSSINGVEJ',
#   'MunicipalityNo': '615',
#   'Municipality': 'Horsens',
#   'RegionName': 'Midtjylland',
#   'ConnectionPointLatitude': 55.87301,
#   'ConnectionPointLongitude': 9.83733,
#   'NetCompanyName': 'Konstant Syd',
#   'region_code': 'dk_mun_615'},
#  {'_id': 214,
#   'ConnectionPointCode': 'FVO',
#   'ConnectionPointName': 'Fynsværket',
#   'MunicipalityNo': '461',
#   'Municipality': 'Odense',
#   'RegionName': 'Syddanmark',
#   'ConnectionPointLatitude': 55.426096,
#   'ConnectionPointLongitude': 10.40505,
#   'NetCompanyName': 'FynsNet a.m.b.a.',
#   'region_code': 'dk_mun_461'},
#  {'_id': 230,
#   'ConnectionPointCode': 'GLB',
#   'ConnectionPointName': 'GlÃ¦sborg',
#   'MunicipalityNo': '707',
#   'Municipality': 'Norddjurs',
#   'RegionName': 'Midtjylland',
#   'ConnectionPointLatitude': 56.47375,
#   'ConnectionPointLongitude': 10.72084,
#   'NetCompanyName': 'Konstant Nord',
#   'region_code': 'dk_mun_707'},
#  {'_id': 233,
#   'ConnectionPointCode': 'GLN',
#   'ConnectionPointName': 'Glentegård',
#   'MunicipalityNo': '159',
#   'Municipality': 'Gladsaxe',
#   'RegionName': 'Hovedstaden',
#   'ConnectionPointLatitude': 55.75242,
#   'ConnectionPointLongitude': 12.499116,
#   'NetCompanyName': 'REGIONALE NET',
#   'region_code': 'dk_mun_159'},
#  {'_id': 247,
#   'ConnectionPointCode': 'GRN',
#   'ConnectionPointName': 'Grønnegård',
#   'MunicipalityNo': '159',
#   'Municipality': 'Gladsaxe',
#   'RegionName': 'Hovedstaden',
#   'ConnectionPointLatitude': 55.733821,
#   'ConnectionPointLongitude': 12.46402,
#   'NetCompanyName': 'REGIONALE NET',
#   'region_code': 'dk_mun_159'},
#  {'_id': 249,
#   'ConnectionPointCode': 'GRP',
#   'ConnectionPointName': 'Graderup',
#   'MunicipalityNo': '410',
#   'Municipality': 'Middelfart',
#   'RegionName': 'Syddanmark',
#   'ConnectionPointLatitude': 55.472469,
#   'ConnectionPointLongitude': 10.002912,
#   'NetCompanyName': 'FynsNet a.m.b.a.',
#   'region_code': 'dk_mun_410'},
#  {'_id': 257,
#   'ConnectionPointCode': 'GØR',
#   'ConnectionPointName': 'Gørløse',
#   'MunicipalityNo': '219',
#   'Municipality': 'Hillerød',
#   'RegionName': 'Hovedstaden',
#   'ConnectionPointLatitude': 55.891386,
#   'ConnectionPointLongitude': 12.202483,
#   'NetCompanyName': 'REGIONALE NET',
#   'region_code': 'dk_mun_219'},
#  {'_id': 278,
#   'ConnectionPointCode': 'HCV',
#   'ConnectionPointName': 'H.C.Ørstedværket',
#   'MunicipalityNo': '101',
#   'Municipality': 'København',
#   'RegionName': 'Hovedstaden',
#   'ConnectionPointLatitude': 55.656638,
#   'ConnectionPointLongitude': 12.554723,
#   'NetCompanyName': 'KE TRANSMISSION',
#   'region_code': 'dk_mun_101'},
#  {'_id': 288,
#   'ConnectionPointCode': 'HEMV',
#   'ConnectionPointName': 'Hemmet',
#   'MunicipalityNo': '760',
#   'Municipality': 'Ringkøbing-Skjern',
#   'RegionName': 'Midtjylland',
#   'ConnectionPointLatitude': 55.84888,
#   'ConnectionPointLongitude': 8.35919,
#   'NetCompanyName': 'N1',
#   'region_code': 'dk_mun_760'},
#  {'_id': 312,
#   'ConnectionPointCode': 'HLBV',
#   'ConnectionPointName': 'Holbæk',
#   'MunicipalityNo': '707',
#   'Municipality': 'Norddjurs',
#   'RegionName': 'Midtjylland',
#   'ConnectionPointLatitude': 56.55841,
#   'ConnectionPointLongitude': 10.32586,
#   'NetCompanyName': 'N1',
#   'region_code': 'dk_mun_707'},
#  {'_id': 318,
#   'ConnectionPointCode': 'HMA',
#   'ConnectionPointName': 'Herlufmagle',
#   'MunicipalityNo': '370',
#   'Municipality': 'Næstved',
#   'RegionName': 'Sjælland',
#   'ConnectionPointLatitude': 55.3345,
#   'ConnectionPointLongitude': 11.742174,
#   'NetCompanyName': 'SEAS/NVE TRANSMISSION',
#   'region_code': 'dk_mun_370'},
#  {'_id': 322,
#   'ConnectionPointCode': 'HNB',
#   'ConnectionPointName': 'Hornbæk',
#   'MunicipalityNo': '730',
#   'Municipality': 'Randers',
#   'RegionName': 'Midtjylland',
#   'ConnectionPointLatitude': 56.469286,
#   'ConnectionPointLongitude': 9.980677,
#   'NetCompanyName': 'Midtjyske Net A.m.b.a.',
#   'region_code': 'dk_mun_730'},
#  {'_id': 328,
#   'ConnectionPointCode': 'HOD',
#   'ConnectionPointName': 'Holsted',
#   'MunicipalityNo': '575',
#   'Municipality': 'Vejen',
#   'RegionName': 'Syddanmark',
#   'ConnectionPointLatitude': 55.519919,
#   'ConnectionPointLongitude': 8.917026,
#   'NetCompanyName': 'Vestjyske Net A/S',
#   'region_code': 'dk_mun_575'},
#  {'_id': 332,
#   'ConnectionPointCode': 'HOLV',
#   'ConnectionPointName': 'Holstebro',
#   'MunicipalityNo': '661',
#   'Municipality': 'Holstebro',
#   'RegionName': 'Midtjylland',
#   'ConnectionPointLatitude': 56.35249,
#   'ConnectionPointLongitude': 8.602755,
#   'NetCompanyName': 'L-Net A/S',
#   'region_code': 'dk_mun_661'},
#  {'_id': 337,
#   'ConnectionPointCode': 'HOSV',
#   'ConnectionPointName': 'Holsted Syd',
#   'MunicipalityNo': '575',
#   'Municipality': 'Vejen',
#   'RegionName': 'Syddanmark',
#   'ConnectionPointLatitude': 55.48046,
#   'ConnectionPointLongitude': 8.90162,
#   'NetCompanyName': 'N1',
#   'region_code': 'dk_mun_575'},
#  {'_id': 340,
#   'ConnectionPointCode': 'HRA',
#   'ConnectionPointName': 'Hornsrev,Havvinda',
#   'MunicipalityNo': '573',
#   'Municipality': 'Varde',
#   'RegionName': 'Syddanmark',
#   'ConnectionPointLatitude': 55.509084,
#   'ConnectionPointLongitude': 7.875232,
#   'NetCompanyName': 'Eltra amba',
#   'region_code': 'dk_mun_573'},
#  {'_id': 341,
#   'ConnectionPointCode': 'HRB',
#   'ConnectionPointName': 'Hornsrev,Havvindb',
#   'MunicipalityNo': '561',
#   'Municipality': 'Esbjerg',
#   'RegionName': 'Syddanmark',
#   'ConnectionPointLatitude': 55.599541,
#   'ConnectionPointLongitude': 7.622498,
#   'NetCompanyName': 'Eltra amba',
#   'region_code': 'dk_mun_561'},
#  {'_id': 359,
#   'ConnectionPointCode': 'HUP',
#   'ConnectionPointName': 'Hunstrup',
#   'MunicipalityNo': '787',
#   'Municipality': 'Thisted',
#   'RegionName': 'Nordjylland',
#   'ConnectionPointLatitude': 57.04151,
#   'ConnectionPointLongitude': 8.8117,
#   'NetCompanyName': 'Thy-Mors Energi A/S',
#   'region_code': 'dk_mun_787'},
#  {'_id': 366,
#   'ConnectionPointCode': 'HVE',
#   'ConnectionPointName': 'Hovegård',
#   'MunicipalityNo': '240',
#   'Municipality': 'Egedal',
#   'RegionName': 'Hovedstaden',
#   'ConnectionPointLatitude': 55.7311,
#   'ConnectionPointLongitude': 12.23388,
#   'NetCompanyName': 'REGIONALE NET',
#   'region_code': 'dk_mun_240'},
#  {'_id': 368,
#   'ConnectionPointCode': 'HVIV',
#   'ConnectionPointName': 'Hvidbjerg',
#   'MunicipalityNo': '671',
#   'Municipality': 'Struer',
#   'RegionName': 'Midtjylland',
#   'ConnectionPointLatitude': 56.64397,
#   'ConnectionPointLongitude': 8.518505,
#   'NetCompanyName': 'Thy-Mors Energi A/S',
#   'region_code': 'dk_mun_671'},
#  {'_id': 370,
#   'ConnectionPointCode': 'HVO',
#   'ConnectionPointName': 'Hvorupgård',
#   'MunicipalityNo': '851',
#   'Municipality': 'Aalborg',
#   'RegionName': 'Nordjylland',
#   'ConnectionPointLatitude': 57.116325,
#   'ConnectionPointLongitude': 9.930814,
#   'NetCompanyName': 'NV Net Amba',
#   'region_code': 'dk_mun_851'},
#  {'_id': 373,
#   'ConnectionPointCode': 'HVV',
#   'ConnectionPointName': 'Håndværkervej',
#   'MunicipalityNo': '851',
#   'Municipality': 'Aalborg',
#   'RegionName': 'Nordjylland',
#   'ConnectionPointLatitude': 57.036075,
#   'ConnectionPointLongitude': 9.925886,
#   'NetCompanyName': 'NV Net Amba',
#   'region_code': 'dk_mun_851'},
#  {'_id': 374,
#   'ConnectionPointCode': 'HYL',
#   'ConnectionPointName': 'Hyllested',
#   'MunicipalityNo': '706',
#   'Municipality': 'Syddjurs',
#   'RegionName': 'Midtjylland',
#   'ConnectionPointLatitude': 56.28254,
#   'ConnectionPointLongitude': 10.75175,
#   'NetCompanyName': 'Konstant Nord',
#   'region_code': 'dk_mun_706'},
#  {'_id': 379,
#   'ConnectionPointCode': 'HØN',
#   'ConnectionPointName': 'Hørning',
#   'MunicipalityNo': '746',
#   'Municipality': 'Skanderborg',
#   'RegionName': 'Midtjylland',
#   'ConnectionPointLatitude': 56.076675,
#   'ConnectionPointLongitude': 10.028266,
#   'NetCompanyName': 'Sydøstjyske Net A/S',
#   'region_code': 'dk_mun_746'},
#  {'_id': 382,
#   'ConnectionPointCode': 'IDE',
#   'ConnectionPointName': 'Idestrup',
#   'MunicipalityNo': '376',
#   'Municipality': 'Guldborgsund',
#   'RegionName': 'Sjælland',
#   'ConnectionPointLatitude': 54.751226,
#   'ConnectionPointLongitude': 11.946306,
#   'NetCompanyName': 'SEAS/NVE TRANSMISSION',
#   'region_code': 'dk_mun_376'},
#  {'_id': 383,
#   'ConnectionPointCode': 'IDU',
#   'ConnectionPointName': 'Idomlund',
#   'MunicipalityNo': '661',
#   'Municipality': 'Holstebro',
#   'RegionName': 'Midtjylland',
#   'ConnectionPointLatitude': 56.352613,
#   'ConnectionPointLongitude': 8.552965,
#   'NetCompanyName': 'Vestjyske Net A/S',
#   'region_code': 'dk_mun_661'},
#  {'_id': 389,
#   'ConnectionPointCode': 'ISH',
#   'ConnectionPointName': 'Ishøj',
#   'MunicipalityNo': '183',
#   'Municipality': 'Ishøj',
#   'RegionName': 'Hovedstaden',
#   'ConnectionPointLatitude': 55.6346,
#   'ConnectionPointLongitude': 12.32171,
#   'NetCompanyName': 'REGIONALE NET',
#   'region_code': 'dk_mun_183'},
#  {'_id': 393,
#   'ConnectionPointCode': 'JERV',
#   'ConnectionPointName': 'Jerlev',
#   'MunicipalityNo': '630',
#   'Municipality': 'Vejle',
#   'RegionName': 'Syddanmark',
#   'ConnectionPointLatitude': 55.6722,
#   'ConnectionPointLongitude': 9.45542,
#   'NetCompanyName': 'TREFOR',
#   'region_code': 'dk_mun_630'},
#  {'_id': 399,
#   'ConnectionPointCode': 'JUL',
#   'ConnectionPointName': 'JUELSMINDE',
#   'MunicipalityNo': '766',
#   'Municipality': 'Hedensted',
#   'RegionName': 'Midtjylland',
#   'ConnectionPointLatitude': 55.71408,
#   'ConnectionPointLongitude': 9.96537,
#   'NetCompanyName': 'Konstant Syd',
#   'region_code': 'dk_mun_766'},
#  {'_id': 403,
#   'ConnectionPointCode': 'KAE',
#   'ConnectionPointName': 'Karlsgårde',
#   'MunicipalityNo': '573',
#   'Municipality': 'Varde',
#   'RegionName': 'Syddanmark',
#   'ConnectionPointLatitude': 55.650333,
#   'ConnectionPointLongitude': 8.574082,
#   'NetCompanyName': 'Vestjyske Net A/S',
#   'region_code': 'dk_mun_573'},
#  {'_id': 404,
#   'ConnectionPointCode': 'KAG',
#   'ConnectionPointName': 'Katbjerg',
#   'MunicipalityNo': '846',
#   'Municipality': 'Mariagerfjord',
#   'RegionName': 'Nordjylland',
#   'ConnectionPointLatitude': 56.639269,
#   'ConnectionPointLongitude': 9.880145,
#   'NetCompanyName': 'Midtjyske Net A.m.b.a.',
#   'region_code': 'dk_mun_846'},
#  {'_id': 405,
#   'ConnectionPointCode': 'KAK',
#   'ConnectionPointName': 'Kastrup',
#   'MunicipalityNo': '185',
#   'Municipality': 'Tårnby',
#   'RegionName': 'Hovedstaden',
#   'ConnectionPointLatitude': 55.631542,
#   'ConnectionPointLongitude': 12.657965,
#   'NetCompanyName': 'KE TRANSMISSION',
#   'region_code': 'dk_mun_185'},
#  {'_id': 406,
#   'ConnectionPointCode': 'KAM',
#   'ConnectionPointName': 'Kamstrup',
#   'MunicipalityNo': '265',
#   'Municipality': 'Roskilde',
#   'RegionName': 'Sjælland',
#   'ConnectionPointLatitude': 55.608542,
#   'ConnectionPointLongitude': 12.073195,
#   'NetCompanyName': 'REGIONALE NET',
#   'region_code': 'dk_mun_265'},
#  {'_id': 409,
#   'ConnectionPointCode': 'KAS',
#   'ConnectionPointName': 'Kassø',
#   'MunicipalityNo': '580',
#   'Municipality': 'Aabenraa',
#   'RegionName': 'Syddanmark',
#   'ConnectionPointLatitude': 55.036517,
#   'ConnectionPointLongitude': 9.269812,
#   'NetCompanyName': 'Eltra amba',
#   'region_code': 'dk_mun_580'},
#  {'_id': 414,
#   'ConnectionPointCode': 'KBG',
#   'ConnectionPointName': 'Kalundborg(Kba/Kbb)',
#   'MunicipalityNo': '326',
#   'Municipality': 'Kalundborg',
#   'RegionName': 'Sjælland',
#   'ConnectionPointLatitude': 55.675343,
#   'ConnectionPointLongitude': 11.109847,
#   'NetCompanyName': 'SEAS/NVE NET',
#   'region_code': 'dk_mun_326'},
#  {'_id': 415,
#   'ConnectionPointCode': 'KBYV',
#   'ConnectionPointName': 'Klinkby',
#   'MunicipalityNo': '665',
#   'Municipality': 'Lemvig',
#   'RegionName': 'Midtjylland',
#   'ConnectionPointLatitude': 56.56278,
#   'ConnectionPointLongitude': 8.21433,
#   'NetCompanyName': 'NOE Net A/S',
#   'region_code': 'dk_mun_665'},
#  {'_id': 428,
#   'ConnectionPointCode': 'KIN',
#   'ConnectionPointName': 'Kingstrup',
#   'MunicipalityNo': '410',
#   'Municipality': 'Middelfart',
#   'RegionName': 'Syddanmark',
#   'ConnectionPointLatitude': 55.411047,
#   'ConnectionPointLongitude': 9.968659,
#   'NetCompanyName': 'FynsNet a.m.b.a.',
#   'region_code': 'dk_mun_410'},
#  {'_id': 435,
#   'ConnectionPointCode': 'KLU',
#   'ConnectionPointName': 'Korslund',
#   'MunicipalityNo': '706',
#   'Municipality': 'Syddjurs',
#   'RegionName': 'Midtjylland',
#   'ConnectionPointLatitude': 56.3215,
#   'ConnectionPointLongitude': 10.41817,
#   'NetCompanyName': 'Konstant Nord',
#   'region_code': 'dk_mun_706'},
#  {'_id': 438,
#   'ConnectionPointCode': 'KNA',
#   'ConnectionPointName': 'Knabberup',
#   'MunicipalityNo': '630',
#   'Municipality': 'Vejle',
#   'RegionName': 'Syddanmark',
#   'ConnectionPointLatitude': 55.712496,
#   'ConnectionPointLongitude': 9.489462,
#   'NetCompanyName': 'Sydøstjyske Net A/S',
#   'region_code': 'dk_mun_630'},
#  {'_id': 448,
#   'ConnectionPointCode': 'KRIV',
#   'ConnectionPointName': 'Korinth',
#   'MunicipalityNo': '430',
#   'Municipality': 'Faaborg-Midtfyn',
#   'RegionName': 'Syddanmark',
#   'ConnectionPointLatitude': 55.14457,
#   'ConnectionPointLongitude': 10.33012,
#   'NetCompanyName': 'VORES ELNET A/S',
#   'region_code': 'dk_mun_430'},
#  {'_id': 450,
#   'ConnectionPointCode': 'KRL',
#   'ConnectionPointName': 'Karlstrup',
#   'MunicipalityNo': '269',
#   'Municipality': 'Solrød',
#   'RegionName': 'Sjælland',
#   'ConnectionPointLatitude': 55.54376,
#   'ConnectionPointLongitude': 12.20485,
#   'NetCompanyName': 'Konstant Syd',
#   'region_code': 'dk_mun_269'},
#  {'_id': 456,
#   'ConnectionPointCode': 'KSV',
#   'ConnectionPointName': 'Kirkeskovgård',
#   'MunicipalityNo': '350',
#   'Municipality': 'Lejre',
#   'RegionName': 'Sjælland',
#   'ConnectionPointLatitude': 55.623098,
#   'ConnectionPointLongitude': 11.879284,
#   'NetCompanyName': 'REGIONALE NET',
#   'region_code': 'dk_mun_350'},
#  {'_id': 464,
#   'ConnectionPointCode': 'KYV',
#   'ConnectionPointName': 'Kyndbyværket',
#   'MunicipalityNo': '250',
#   'Municipality': 'Frederikssund',
#   'RegionName': 'Hovedstaden',
#   'ConnectionPointLatitude': 55.812141,
#   'ConnectionPointLongitude': 11.878858,
#   'NetCompanyName': 'REGIONALE NET',
#   'region_code': 'dk_mun_250'},
#  {'_id': 467,
#   'ConnectionPointCode': 'LAG',
#   'ConnectionPointName': 'Landerupgård',
#   'MunicipalityNo': '621',
#   'Municipality': 'Kolding',
#   'RegionName': 'Syddanmark',
#   'ConnectionPointLatitude': 55.563378,
#   'ConnectionPointLongitude': 9.541198,
#   'NetCompanyName': 'Sydøstjyske Net A/S',
#   'region_code': 'dk_mun_621'},
#  {'_id': 487,
#   'ConnectionPointCode': 'LILV',
#   'ConnectionPointName': 'Lilballe',
#   'MunicipalityNo': '621',
#   'Municipality': 'Kolding',
#   'RegionName': 'Syddanmark',
#   'ConnectionPointLatitude': 55.53767,
#   'ConnectionPointLongitude': 9.49172,
#   'NetCompanyName': 'TREFOR',
#   'region_code': 'dk_mun_621'},
#  {'_id': 491,
#   'ConnectionPointCode': 'LIV',
#   'ConnectionPointName': 'Lindved (fyn)',
#   'MunicipalityNo': '461',
#   'Municipality': 'Odense',
#   'RegionName': 'Syddanmark',
#   'ConnectionPointLatitude': 55.34037,
#   'ConnectionPointLongitude': 10.44345,
#   'NetCompanyName': 'VORES ELNET A/S',
#   'region_code': 'dk_mun_461'},
#  {'_id': 507,
#   'ConnectionPointCode': 'LUP',
#   'ConnectionPointName': 'Lyngerup',
#   'MunicipalityNo': '250',
#   'Municipality': 'Frederikssund',
#   'RegionName': 'Hovedstaden',
#   'ConnectionPointLatitude': 55.796804,
#   'ConnectionPointLongitude': 11.983184,
#   'NetCompanyName': 'REGIONALE NET',
#   'region_code': 'dk_mun_250'},
#  {'_id': 514,
#   'ConnectionPointCode': 'LYH',
#   'ConnectionPointName': 'LYSHOLT',
#   'MunicipalityNo': '630',
#   'Municipality': 'Vejle',
#   'RegionName': 'Syddanmark',
#   'ConnectionPointLatitude': 55.73414,
#   'ConnectionPointLongitude': 9.58195,
#   'NetCompanyName': 'Konstant Syd',
#   'region_code': 'dk_mun_630'},
#  {'_id': 515,
#   'ConnectionPointCode': 'LYK',
#   'ConnectionPointName': 'Lykkegårdogvke',
#   'MunicipalityNo': '561',
#   'Municipality': 'Esbjerg',
#   'RegionName': 'Syddanmark',
#   'ConnectionPointLatitude': 55.466811,
#   'ConnectionPointLongitude': 8.504054,
#   'NetCompanyName': 'Vestjyske Net A/S',
#   'region_code': 'dk_mun_561'},
#  {'_id': 526,
#   'ConnectionPointCode': 'MAL',
#   'ConnectionPointName': 'Malling',
#   'MunicipalityNo': '751',
#   'Municipality': 'Aarhus',
#   'RegionName': 'Midtjylland',
#   'ConnectionPointLatitude': 56.04847,
#   'ConnectionPointLongitude': 10.141158,
#   'NetCompanyName': 'Sydøstjyske Net A/S',
#   'region_code': 'dk_mun_751'},
#  {'_id': 527,
#   'ConnectionPointCode': 'MARV',
#   'ConnectionPointName': 'Mariager',
#   'MunicipalityNo': '846',
#   'Municipality': 'Mariagerfjord',
#   'RegionName': 'Nordjylland',
#   'ConnectionPointLatitude': 56.63688,
#   'ConnectionPointLongitude': 9.9694,
#   'NetCompanyName': 'N1',
#   'region_code': 'dk_mun_846'},
#  {'_id': 529,
#   'ConnectionPointCode': 'MAS',
#   'ConnectionPointName': 'Marselis',
#   'MunicipalityNo': '751',
#   'Municipality': 'Aarhus',
#   'RegionName': 'Midtjylland',
#   'ConnectionPointLatitude': 56.1401,
#   'ConnectionPointLongitude': 10.18655,
#   'NetCompanyName': 'Konstant Nord',
#   'region_code': 'dk_mun_751'},
#  {'_id': 531,
#   'ConnectionPointCode': 'MAV',
#   'ConnectionPointName': 'Masnedøværket',
#   'MunicipalityNo': '390',
#   'Municipality': 'Vordingborg',
#   'RegionName': 'Sjælland',
#   'ConnectionPointLatitude': 54.995765,
#   'ConnectionPointLongitude': 11.881601,
#   'NetCompanyName': 'SEAS/NVE TRANSMISSION',
#   'region_code': 'dk_mun_390'},
#  {'_id': 534,
#   'ConnectionPointCode': 'MBYV',
#   'ConnectionPointName': 'Midtbyen',
#   'MunicipalityNo': '851',
#   'Municipality': 'Aalborg',
#   'RegionName': 'Nordjylland',
#   'ConnectionPointLatitude': 57.04487,
#   'ConnectionPointLongitude': 9.93567,
#   'NetCompanyName': 'N1',
#   'region_code': 'dk_mun_851'},
#  {'_id': 538,
#   'ConnectionPointCode': 'MES',
#   'ConnectionPointName': 'Mesballe',
#   'MunicipalityNo': '706',
#   'Municipality': 'Syddjurs',
#   'RegionName': 'Midtjylland',
#   'ConnectionPointLatitude': 56.366732,
#   'ConnectionPointLongitude': 10.498075,
#   'NetCompanyName': 'Midtjyske Net A.m.b.a.',
#   'region_code': 'dk_mun_706'},
#  {'_id': 543,
#   'ConnectionPointCode': 'MKA',
#   'ConnectionPointName': 'Midtkraft',
#   'MunicipalityNo': '751',
#   'Municipality': 'Aarhus',
#   'RegionName': 'Midtjylland',
#   'ConnectionPointLatitude': 56.15162,
#   'ConnectionPointLongitude': 10.21433,
#   'NetCompanyName': 'Konstant Nord',
#   'region_code': 'dk_mun_751'},
#  {'_id': 544,
#   'ConnectionPointCode': 'MKS',
#   'ConnectionPointName': 'Studstrup',
#   'MunicipalityNo': '751',
#   'Municipality': 'Aarhus',
#   'RegionName': 'Midtjylland',
#   'ConnectionPointLatitude': 56.25165,
#   'ConnectionPointLongitude': 10.34222,
#   'NetCompanyName': 'Midtjyske Net A.m.b.a.',
#   'region_code': 'dk_mun_751'},
#  {'_id': 545,
#   'ConnectionPointCode': 'MLA',
#   'ConnectionPointName': 'Langelandsvej',
#   'MunicipalityNo': '410',
#   'Municipality': 'Middelfart',
#   'RegionName': 'Syddanmark',
#   'ConnectionPointLatitude': 55.5049,
#   'ConnectionPointLongitude': 9.7651,
#   'NetCompanyName': 'TREFOR',
#   'region_code': 'dk_mun_410'},
#  {'_id': 548,
#   'ConnectionPointCode': 'MLP',
#   'ConnectionPointName': 'Mollerup',
#   'MunicipalityNo': '751',
#   'Municipality': 'Aarhus',
#   'RegionName': 'Midtjylland',
#   'ConnectionPointLatitude': 56.210921,
#   'ConnectionPointLongitude': 10.189905,
#   'NetCompanyName': 'Midtjyske Net A.m.b.a.',
#   'region_code': 'dk_mun_751'},
#  {'_id': 549,
#   'ConnectionPointCode': 'MLU',
#   'ConnectionPointName': 'Moselund',
#   'MunicipalityNo': '730',
#   'Municipality': 'Randers',
#   'RegionName': 'Midtjylland',
#   'ConnectionPointLatitude': 56.429819,
#   'ConnectionPointLongitude': 10.095076,
#   'NetCompanyName': 'Midtjyske Net A.m.b.a.',
#   'region_code': 'dk_mun_730'},
#  {'_id': 552,
#   'ConnectionPointCode': 'MOSØ',
#   'ConnectionPointName': 'Mosedegård',
#   'MunicipalityNo': '253',
#   'Municipality': 'Greve',
#   'RegionName': 'Sjælland',
#   'ConnectionPointLatitude': 55.585099,
#   'ConnectionPointLongitude': 12.258356,
#   'NetCompanyName': 'REGIONALE NET',
#   'region_code': 'dk_mun_253'},
#  {'_id': 564,
#   'ConnectionPointCode': 'MÅLØ',
#   'ConnectionPointName': 'Måløvgård',
#   'MunicipalityNo': '151',
#   'Municipality': 'Ballerup',
#   'RegionName': 'Hovedstaden',
#   'ConnectionPointLatitude': 55.744171,
#   'ConnectionPointLongitude': 12.32608,
#   'NetCompanyName': 'REGIONALE NET',
#   'region_code': 'dk_mun_151'},
#  {'_id': 569,
#   'ConnectionPointCode': 'NAM',
#   'ConnectionPointName': 'Nr.Asmindrup',
#   'MunicipalityNo': '306',
#   'Municipality': 'Odsherred',
#   'RegionName': 'Sjælland',
#   'ConnectionPointLatitude': 55.871017,
#   'ConnectionPointLongitude': 11.603077,
#   'NetCompanyName': 'SEAS/NVE NET',
#   'region_code': 'dk_mun_306'},
#  {'_id': 590,
#   'ConnectionPointCode': 'NOR',
#   'ConnectionPointName': 'Nors',
#   'MunicipalityNo': '787',
#   'Municipality': 'Thisted',
#   'RegionName': 'Nordjylland',
#   'ConnectionPointLatitude': 57.030922,
#   'ConnectionPointLongitude': 8.700611,
#   'NetCompanyName': 'NV Net Amba',
#   'region_code': 'dk_mun_787'},
#  {'_id': 592,
#   'ConnectionPointCode': 'NOV',
#   'ConnectionPointName': 'Nordvest',
#   'MunicipalityNo': '751',
#   'Municipality': 'Aarhus',
#   'RegionName': 'Midtjylland',
#   'ConnectionPointLatitude': 56.17347,
#   'ConnectionPointLongitude': 10.1975,
#   'NetCompanyName': 'Konstant Nord',
#   'region_code': 'dk_mun_751'},
#  {'_id': 596,
#   'ConnectionPointCode': 'NSP',
#   'ConnectionPointName': 'Nibstrup',
#   'MunicipalityNo': '810',
#   'Municipality': 'Brønderslev',
#   'RegionName': 'Nordjylland',
#   'ConnectionPointLatitude': 57.267212,
#   'ConnectionPointLongitude': 9.979697,
#   'NetCompanyName': 'NV Net Amba',
#   'region_code': 'dk_mun_810'},
#  {'_id': 598,
#   'ConnectionPointCode': 'NSV',
#   'ConnectionPointName': 'NæStved',
#   'MunicipalityNo': '370',
#   'Municipality': 'Næstved',
#   'RegionName': 'Sjælland',
#   'ConnectionPointLatitude': 55.248,
#   'ConnectionPointLongitude': 11.71266,
#   'NetCompanyName': 'SEAS/NVE TRANSMISSION',
#   'region_code': 'dk_mun_370'},
#  {'_id': 604,
#   'ConnectionPointCode': 'NVV',
#   'ConnectionPointName': 'Vendsyssel værket',
#   'MunicipalityNo': '851',
#   'Municipality': 'Aalborg',
#   'RegionName': 'Nordjylland',
#   'ConnectionPointLatitude': 57.076048,
#   'ConnectionPointLongitude': 10.046705,
#   'NetCompanyName': 'NV Net Amba',
#   'region_code': 'dk_mun_851'},
#  {'_id': 608,
#   'ConnectionPointCode': 'NYMV',
#   'ConnectionPointName': 'Nymindegab',
#   'MunicipalityNo': '760',
#   'Municipality': 'Ringkøbing-Skjern',
#   'RegionName': 'Midtjylland',
#   'ConnectionPointLatitude': 55.81874,
#   'ConnectionPointLongitude': 8.21561,
#   'NetCompanyName': 'N1',
#   'region_code': 'dk_mun_760'},
#  {'_id': 610,
#   'ConnectionPointCode': 'NYR',
#   'ConnectionPointName': 'Nyrup',
#   'MunicipalityNo': '340',
#   'Municipality': 'Sorø',
#   'RegionName': 'Sjælland',
#   'ConnectionPointLatitude': 55.545725,
#   'ConnectionPointLongitude': 11.641376,
#   'NetCompanyName': 'SEAS/NVE NET',
#   'region_code': 'dk_mun_340'},
#  {'_id': 618,
#   'ConnectionPointCode': 'OEST',
#   'ConnectionPointName': 'Ørestad Trfst',
#   'MunicipalityNo': '400',
#   'Municipality': 'Bornholm',
#   'RegionName': 'Hovedstaden',
#   'ConnectionPointLatitude': 55.63227,
#   'ConnectionPointLongitude': 12.57593,
#   'NetCompanyName': 'Radius Elnet',
#   'region_code': 'dk_mun_400'},
#  {'_id': 634,
#   'ConnectionPointCode': 'ORH',
#   'ConnectionPointName': 'Orehoved',
#   'MunicipalityNo': '376',
#   'Municipality': 'Guldborgsund',
#   'RegionName': 'Sjælland',
#   'ConnectionPointLatitude': 54.953433,
#   'ConnectionPointLongitude': 11.844089,
#   'NetCompanyName': 'SEAS/NVE TRANSMISSION',
#   'region_code': 'dk_mun_376'},
#  {'_id': 639,
#   'ConnectionPointCode': 'OST',
#   'ConnectionPointName': 'Ostedgård',
#   'MunicipalityNo': '350',
#   'Municipality': 'Lejre',
#   'RegionName': 'Sjælland',
#   'ConnectionPointLatitude': 55.576425,
#   'ConnectionPointLongitude': 11.987835,
#   'NetCompanyName': 'REGIONALE NET',
#   'region_code': 'dk_mun_350'},
#  {'_id': 640,
#   'ConnectionPointCode': 'OSØ',
#   'ConnectionPointName': 'Odense SØ',
#   'MunicipalityNo': '461',
#   'Municipality': 'Odense',
#   'RegionName': 'Syddanmark',
#   'ConnectionPointLatitude': 55.394232,
#   'ConnectionPointLongitude': 10.447981,
#   'NetCompanyName': 'FynsNet a.m.b.a.',
#   'region_code': 'dk_mun_461'},
#  {'_id': 650,
#   'ConnectionPointCode': 'PDS',
#   'ConnectionPointName': 'Pindstrup',
#   'MunicipalityNo': '706',
#   'Municipality': 'Syddjurs',
#   'RegionName': 'Midtjylland',
#   'ConnectionPointLatitude': 56.386,
#   'ConnectionPointLongitude': 10.41618,
#   'NetCompanyName': 'Konstant Nord',
#   'region_code': 'dk_mun_706'},
#  {'_id': 660,
#   'ConnectionPointCode': 'RAM',
#   'ConnectionPointName': 'Ramme',
#   'MunicipalityNo': '665',
#   'Municipality': 'Lemvig',
#   'RegionName': 'Midtjylland',
#   'ConnectionPointLatitude': 56.49206,
#   'ConnectionPointLongitude': 8.218299,
#   'NetCompanyName': 'Vestjyske Net A/S',
#   'region_code': 'dk_mun_665'},
#  {'_id': 668,
#   'ConnectionPointCode': 'RDS',
#   'ConnectionPointName': 'Vindmøllepark Rødsand1',
#   'MunicipalityNo': '376',
#   'Municipality': 'Guldborgsund',
#   'RegionName': 'Sjælland',
#   'ConnectionPointLatitude': 55.28378,
#   'ConnectionPointLongitude': 9.01547,
#   'NetCompanyName': 'N1',
#   'region_code': 'dk_mun_376'},
#  {'_id': 669,
#   'ConnectionPointCode': 'RDSV',
#   'ConnectionPointName': 'Rødding Syd',
#   'MunicipalityNo': '575',
#   'Municipality': 'Vejen',
#   'RegionName': 'Syddanmark',
#   'ConnectionPointLatitude': 55.29551,
#   'ConnectionPointLongitude': 9.04702,
#   'NetCompanyName': 'N1',
#   'region_code': 'dk_mun_575'},
#  {'_id': 677,
#   'ConnectionPointCode': 'RIB',
#   'ConnectionPointName': 'Ribe',
#   'MunicipalityNo': '561',
#   'Municipality': 'Esbjerg',
#   'RegionName': 'Syddanmark',
#   'ConnectionPointLatitude': 55.326571,
#   'ConnectionPointLongitude': 8.799812,
#   'NetCompanyName': 'Syd Net A/S',
#   'region_code': 'dk_mun_561'},
#  {'_id': 680,
#   'ConnectionPointCode': 'RIL',
#   'ConnectionPointName': 'Rislev',
#   'MunicipalityNo': '370',
#   'Municipality': 'Næstved',
#   'RegionName': 'Sjælland',
#   'ConnectionPointLatitude': 55.28144,
#   'ConnectionPointLongitude': 11.724904,
#   'NetCompanyName': 'SEAS/NVE TRANSMISSION',
#   'region_code': 'dk_mun_370'},
#  {'_id': 681,
#   'ConnectionPointCode': 'RINV',
#   'ConnectionPointName': 'Rindum',
#   'MunicipalityNo': '760',
#   'Municipality': 'Ringkøbing-Skjern',
#   'RegionName': 'Midtjylland',
#   'ConnectionPointLatitude': 56.10129,
#   'ConnectionPointLongitude': 8.27468,
#   'NetCompanyName': 'RAH Net A/S',
#   'region_code': 'dk_mun_760'},
#  {'_id': 688,
#   'ConnectionPointCode': 'RMT',
#   'ConnectionPointName': 'Ramten',
#   'MunicipalityNo': '707',
#   'Municipality': 'Norddjurs',
#   'RegionName': 'Midtjylland',
#   'ConnectionPointLatitude': 56.43753,
#   'ConnectionPointLongitude': 10.65091,
#   'NetCompanyName': 'Konstant Nord',
#   'region_code': 'dk_mun_707'},
#  {'_id': 702,
#   'ConnectionPointCode': 'RYEV',
#   'ConnectionPointName': 'Ry',
#   'MunicipalityNo': '746',
#   'Municipality': 'Skanderborg',
#   'RegionName': 'Midtjylland',
#   'ConnectionPointLatitude': 56.08661,
#   'ConnectionPointLongitude': 9.77903,
#   'NetCompanyName': 'Dinel',
#   'region_code': 'dk_mun_746'},
#  {'_id': 705,
#   'ConnectionPointCode': 'RYT',
#   'ConnectionPointName': 'Ryttergård',
#   'MunicipalityNo': '607',
#   'Municipality': 'Fredericia',
#   'RegionName': 'Syddanmark',
#   'ConnectionPointLatitude': 55.589658,
#   'ConnectionPointLongitude': 9.712238,
#   'NetCompanyName': 'Sydøstjyske Net A/S',
#   'region_code': 'dk_mun_607'},
#  {'_id': 722,
#   'ConnectionPointCode': 'SBA',
#   'ConnectionPointName': 'Starbakke',
#   'MunicipalityNo': '813',
#   'Municipality': 'Frederikshavn',
#   'RegionName': 'Nordjylland',
#   'ConnectionPointLatitude': 57.457866,
#   'ConnectionPointLongitude': 10.458984,
#   'NetCompanyName': 'NV Net Amba',
#   'region_code': 'dk_mun_813'},
#  {'_id': 730,
#   'ConnectionPointCode': 'SBYV',
#   'ConnectionPointName': 'Saeby',
#   'MunicipalityNo': '813',
#   'Municipality': 'Frederikshavn',
#   'RegionName': 'Nordjylland',
#   'ConnectionPointLatitude': 57.33318,
#   'ConnectionPointLongitude': 10.50519,
#   'NetCompanyName': 'Elinord',
#   'region_code': 'dk_mun_813'},
#  {'_id': 737,
#   'ConnectionPointCode': 'SFE',
#   'ConnectionPointName': 'Sdrfelding',
#   'MunicipalityNo': '657',
#   'Municipality': 'Herning',
#   'RegionName': 'Midtjylland',
#   'ConnectionPointLatitude': 55.952752,
#   'ConnectionPointLongitude': 8.797765,
#   'NetCompanyName': 'Vestjyske Net A/S',
#   'region_code': 'dk_mun_657'},
#  {'_id': 741,
#   'ConnectionPointCode': 'SHE',
#   'ConnectionPointName': 'Enstedværket',
#   'MunicipalityNo': '580',
#   'Municipality': 'Aabenraa',
#   'RegionName': 'Syddanmark',
#   'ConnectionPointLatitude': 55.019127,
#   'ConnectionPointLongitude': 9.433511,
#   'NetCompanyName': 'Eltra amba',
#   'region_code': 'dk_mun_580'},
#  {'_id': 742,
#   'ConnectionPointCode': 'SHO',
#   'ConnectionPointName': 'Sønderho',
#   'MunicipalityNo': '615',
#   'Municipality': 'Horsens',
#   'RegionName': 'Midtjylland',
#   'ConnectionPointLatitude': 55.83926,
#   'ConnectionPointLongitude': 9.78391,
#   'NetCompanyName': 'Konstant Syd',
#   'region_code': 'dk_mun_615'},
#  {'_id': 747,
#   'ConnectionPointCode': 'SIB',
#   'ConnectionPointName': 'Skibbygård',
#   'MunicipalityNo': '350',
#   'Municipality': 'Lejre',
#   'RegionName': 'Sjælland',
#   'ConnectionPointLatitude': 55.737827,
#   'ConnectionPointLongitude': 11.931328,
#   'NetCompanyName': 'REGIONALE NET',
#   'region_code': 'dk_mun_350'},
#  {'_id': 754,
#   'ConnectionPointCode': 'SKA',
#   'ConnectionPointName': 'Skansen',
#   'MunicipalityNo': '851',
#   'Municipality': 'Aalborg',
#   'RegionName': 'Nordjylland',
#   'ConnectionPointLatitude': 57.067043,
#   'ConnectionPointLongitude': 9.929144,
#   'NetCompanyName': 'NV Net Amba',
#   'region_code': 'dk_mun_851'},
#  {'_id': 758,
#   'ConnectionPointCode': 'SKEV',
#   'ConnectionPointName': 'Skelund',
#   'MunicipalityNo': '846',
#   'Municipality': 'Mariagerfjord',
#   'RegionName': 'Nordjylland',
#   'ConnectionPointLatitude': 56.76612,
#   'ConnectionPointLongitude': 10.17435,
#   'NetCompanyName': 'N1',
#   'region_code': 'dk_mun_846'},
#  {'_id': 766,
#   'ConnectionPointCode': 'SKR',
#   'ConnectionPointName': 'Skrillinge',
#   'MunicipalityNo': '410',
#   'Municipality': 'Middelfart',
#   'RegionName': 'Syddanmark',
#   'ConnectionPointLatitude': 55.4891,
#   'ConnectionPointLongitude': 9.76221,
#   'NetCompanyName': 'TREFOR',
#   'region_code': 'dk_mun_410'},
#  {'_id': 771,
#   'ConnectionPointCode': 'SLAV',
#   'ConnectionPointName': 'Solvangsalle',
#   'MunicipalityNo': '707',
#   'Municipality': 'Norddjurs',
#   'RegionName': 'Midtjylland',
#   'ConnectionPointLatitude': 56.4174,
#   'ConnectionPointLongitude': 10.88389,
#   'NetCompanyName': 'Konstant Nord',
#   'region_code': 'dk_mun_707'},
#  {'_id': 775,
#   'ConnectionPointCode': 'SMK',
#   'ConnectionPointName': 'SvanemøLlekbst',
#   'MunicipalityNo': '101',
#   'Municipality': 'København',
#   'RegionName': 'Hovedstaden',
#   'ConnectionPointLatitude': 55.710065,
#   'ConnectionPointLongitude': 12.580626,
#   'NetCompanyName': 'KE TRANSMISSION',
#   'region_code': 'dk_mun_101'},
#  {'_id': 777,
#   'ConnectionPointCode': 'SMO',
#   'ConnectionPointName': 'Sortemose',
#   'MunicipalityNo': '751',
#   'Municipality': 'Aarhus',
#   'RegionName': 'Midtjylland',
#   'ConnectionPointLatitude': 56.26451,
#   'ConnectionPointLongitude': 10.28944,
#   'NetCompanyName': 'Konstant Nord',
#   'region_code': 'dk_mun_751'},
#  {'_id': 780,
#   'ConnectionPointCode': 'SMV',
#   'ConnectionPointName': 'Svanemølleværket',
#   'MunicipalityNo': '101',
#   'Municipality': 'København',
#   'RegionName': 'Hovedstaden',
#   'ConnectionPointLatitude': 55.7131,
#   'ConnectionPointLongitude': 12.58801,
#   'NetCompanyName': 'Radius Elnet',
#   'region_code': 'dk_mun_101'},
#  {'_id': 783,
#   'ConnectionPointCode': 'SNO',
#   'ConnectionPointName': 'Snoghoej',
#   'MunicipalityNo': '607',
#   'Municipality': 'Fredericia',
#   'RegionName': 'Syddanmark',
#   'ConnectionPointLatitude': 55.5312,
#   'ConnectionPointLongitude': 9.711729,
#   'NetCompanyName': 'TREFOR',
#   'region_code': 'dk_mun_607'},
#  {'_id': 792,
#   'ConnectionPointCode': 'SOS',
#   'ConnectionPointName': 'Søstremose',
#   'MunicipalityNo': '326',
#   'Municipality': 'Kalundborg',
#   'RegionName': 'Sjælland',
#   'ConnectionPointLatitude': 55.641889,
#   'ConnectionPointLongitude': 11.118173,
#   'NetCompanyName': 'SEAS/NVE NET',
#   'region_code': 'dk_mun_326'},
#  {'_id': 798,
#   'ConnectionPointCode': 'SPR',
#   'ConnectionPointName': 'Sperrestrupgård',
#   'MunicipalityNo': '240',
#   'Municipality': 'Egedal',
#   'RegionName': 'Hovedstaden',
#   'ConnectionPointLatitude': 55.789084,
#   'ConnectionPointLongitude': 12.18442,
#   'NetCompanyName': 'REGIONALE NET',
#   'region_code': 'dk_mun_240'},
#  {'_id': 807,
#   'ConnectionPointCode': 'STEV',
#   'ConnectionPointName': 'Stenstrup',
#   'MunicipalityNo': '479',
#   'Municipality': 'Svendborg',
#   'RegionName': 'Syddanmark',
#   'ConnectionPointLatitude': 55.12069,
#   'ConnectionPointLongitude': 10.51975,
#   'NetCompanyName': 'FLOW ELNET A/S',
#   'region_code': 'dk_mun_479'},
#  {'_id': 815,
#   'ConnectionPointCode': 'STR',
#   'ConnectionPointName': 'Struer',
#   'MunicipalityNo': '671',
#   'Municipality': 'Struer',
#   'RegionName': 'Midtjylland',
#   'ConnectionPointLatitude': 56.483126,
#   'ConnectionPointLongitude': 8.575286,
#   'NetCompanyName': 'Vestjyske Net A/S',
#   'region_code': 'dk_mun_671'},
#  {'_id': 817,
#   'ConnectionPointCode': 'STSØ',
#   'ConnectionPointName': 'Statoil syd',
#   'MunicipalityNo': '326',
#   'Municipality': 'Kalundborg',
#   'RegionName': 'Sjælland',
#   'ConnectionPointLatitude': 55.650606,
#   'ConnectionPointLongitude': 11.100961,
#   'NetCompanyName': 'SEAS/NVE NET',
#   'region_code': 'dk_mun_326'},
#  {'_id': 818,
#   'ConnectionPointCode': 'STVV',
#   'ConnectionPointName': 'Stevning',
#   'MunicipalityNo': '540',
#   'Municipality': 'Sønderborg',
#   'RegionName': 'Syddanmark',
#   'ConnectionPointLatitude': 55.00827,
#   'ConnectionPointLongitude': 9.81692,
#   'NetCompanyName': 'N1',
#   'region_code': 'dk_mun_540'},
#  {'_id': 827,
#   'ConnectionPointCode': 'SVB',
#   'ConnectionPointName': 'Svendborg',
#   'MunicipalityNo': '479',
#   'Municipality': 'Svendborg',
#   'RegionName': 'Syddanmark',
#   'ConnectionPointLatitude': 55.07023,
#   'ConnectionPointLongitude': 10.57612,
#   'NetCompanyName': 'FynsNet a.m.b.a.',
#   'region_code': 'dk_mun_479'},
#  {'_id': 834,
#   'ConnectionPointCode': 'SVN',
#   'ConnectionPointName': 'SKELVANGEN',
#   'MunicipalityNo': '630',
#   'Municipality': 'Vejle',
#   'RegionName': 'Syddanmark',
#   'ConnectionPointLatitude': 55.7193,
#   'ConnectionPointLongitude': 9.60238,
#   'NetCompanyName': 'Konstant Syd',
#   'region_code': 'dk_mun_630'},
#  {'_id': 835,
#   'ConnectionPointCode': 'SVS',
#   'ConnectionPointName': 'Skærbækværket',
#   'MunicipalityNo': '607',
#   'Municipality': 'Fredericia',
#   'RegionName': 'Syddanmark',
#   'ConnectionPointLatitude': 55.51321,
#   'ConnectionPointLongitude': 9.614425,
#   'NetCompanyName': 'Sydøstjyske Net A/S',
#   'region_code': 'dk_mun_607'},
#  {'_id': 845,
#   'ConnectionPointCode': 'SØN',
#   'ConnectionPointName': 'Sønderborg',
#   'MunicipalityNo': '540',
#   'Municipality': 'Sønderborg',
#   'RegionName': 'Syddanmark',
#   'ConnectionPointLatitude': 54.923616,
#   'ConnectionPointLongitude': 9.785672,
#   'NetCompanyName': 'Syd Net A/S',
#   'region_code': 'dk_mun_540'},
#  {'_id': 849,
#   'ConnectionPointCode': 'TAN',
#   'ConnectionPointName': 'Tange',
#   'MunicipalityNo': '791',
#   'Municipality': 'Viborg',
#   'RegionName': 'Midtjylland',
#   'ConnectionPointLatitude': 56.360937,
#   'ConnectionPointLongitude': 9.595545,
#   'NetCompanyName': 'Midtjyske Net A.m.b.a.',
#   'region_code': 'dk_mun_791'},
#  {'_id': 861,
#   'ConnectionPointCode': 'TEG',
#   'ConnectionPointName': 'Teglstrupgård',
#   'MunicipalityNo': '217',
#   'Municipality': 'Helsingør',
#   'RegionName': 'Hovedstaden',
#   'ConnectionPointLatitude': 56.028681,
#   'ConnectionPointLongitude': 12.563658,
#   'NetCompanyName': 'REGIONALE NET',
#   'region_code': 'dk_mun_217'},
#  {'_id': 863,
#   'ConnectionPointCode': 'TERV',
#   'ConnectionPointName': 'TERNEVEJ',
#   'MunicipalityNo': '630',
#   'Municipality': 'Vejle',
#   'RegionName': 'Syddanmark',
#   'ConnectionPointLatitude': 55.70109,
#   'ConnectionPointLongitude': 9.54401,
#   'NetCompanyName': 'Konstant Syd',
#   'region_code': 'dk_mun_630'},
#  {'_id': 867,
#   'ConnectionPointCode': 'THØ',
#   'ConnectionPointName': 'Tinghøh',
#   'MunicipalityNo': '846',
#   'Municipality': 'Mariagerfjord',
#   'RegionName': 'Nordjylland',
#   'ConnectionPointLatitude': 56.70256,
#   'ConnectionPointLongitude': 9.893529,
#   'NetCompanyName': 'NV Net Amba',
#   'region_code': 'dk_mun_846'},
#  {'_id': 871,
#   'ConnectionPointCode': 'TJE',
#   'ConnectionPointName': 'Tjele',
#   'MunicipalityNo': '791',
#   'Municipality': 'Viborg',
#   'RegionName': 'Midtjylland',
#   'ConnectionPointLatitude': 56.479606,
#   'ConnectionPointLongitude': 9.565874,
#   'NetCompanyName': 'Eltra amba',
#   'region_code': 'dk_mun_791'},
#  {'_id': 878,
#   'ConnectionPointCode': 'TNP',
#   'ConnectionPointName': 'Tendrup',
#   'MunicipalityNo': '706',
#   'Municipality': 'Syddjurs',
#   'RegionName': 'Midtjylland',
#   'ConnectionPointLatitude': 56.30362,
#   'ConnectionPointLongitude': 10.31031,
#   'NetCompanyName': 'Konstant Nord',
#   'region_code': 'dk_mun_706'},
#  {'_id': 882,
#   'ConnectionPointCode': 'TOR',
#   'ConnectionPointName': 'Torslunde',
#   'MunicipalityNo': '316',
#   'Municipality': 'Holbæk',
#   'RegionName': 'Sjælland',
#   'ConnectionPointLatitude': 55.717711,
#   'ConnectionPointLongitude': 11.491859,
#   'NetCompanyName': 'SEAS/NVE NET',
#   'region_code': 'dk_mun_316'},
#  {'_id': 883,
#   'ConnectionPointCode': 'TORV',
#   'ConnectionPointName': 'TORSVANG',
#   'MunicipalityNo': '615',
#   'Municipality': 'Horsens',
#   'RegionName': 'Midtjylland',
#   'ConnectionPointLatitude': 55.84503,
#   'ConnectionPointLongitude': 9.83055,
#   'NetCompanyName': 'Konstant Syd',
#   'region_code': 'dk_mun_615'},
#  {'_id': 884,
#   'ConnectionPointCode': 'TRB',
#   'ConnectionPointName': 'Trø¸jborg',
#   'MunicipalityNo': '751',
#   'Municipality': 'Aarhus',
#   'RegionName': 'Midtjylland',
#   'ConnectionPointLatitude': 56.16912,
#   'ConnectionPointLongitude': 10.20934,
#   'NetCompanyName': 'Konstant Nord',
#   'region_code': 'dk_mun_751'},
#  {'_id': 887,
#   'ConnectionPointCode': 'TRI',
#   'ConnectionPointName': 'Trige',
#   'MunicipalityNo': '751',
#   'Municipality': 'Aarhus',
#   'RegionName': 'Midtjylland',
#   'ConnectionPointLatitude': 56.27437,
#   'ConnectionPointLongitude': 10.139784,
#   'NetCompanyName': 'Midtjyske Net A.m.b.a.',
#   'region_code': 'dk_mun_751'},
#  {'_id': 890,
#   'ConnectionPointCode': 'TRP',
#   'ConnectionPointName': 'Torp',
#   'MunicipalityNo': '787',
#   'Municipality': 'Thisted',
#   'RegionName': 'Nordjylland',
#   'ConnectionPointLatitude': 56.95837,
#   'ConnectionPointLongitude': 8.65165,
#   'NetCompanyName': 'Thy-Mors Energi A/S',
#   'region_code': 'dk_mun_787'},
#  {'_id': 891,
#   'ConnectionPointCode': 'TRSV',
#   'ConnectionPointName': 'Trustrup',
#   'MunicipalityNo': '706',
#   'Municipality': 'Syddjurs',
#   'RegionName': 'Midtjylland',
#   'ConnectionPointLatitude': 56.34444,
#   'ConnectionPointLongitude': 10.78758,
#   'NetCompanyName': 'Konstant Nord',
#   'region_code': 'dk_mun_706'},
#  {'_id': 895,
#   'ConnectionPointCode': 'TSTV',
#   'ConnectionPointName': 'Tistrup',
#   'MunicipalityNo': '550',
#   'Municipality': 'Tønder',
#   'RegionName': 'Syddanmark',
#   'ConnectionPointLatitude': 55.1341,
#   'ConnectionPointLongitude': 8.59888,
#   'NetCompanyName': 'N1',
#   'region_code': 'dk_mun_550'},
#  {'_id': 909,
#   'ConnectionPointCode': 'ULLV',
#   'ConnectionPointName': 'Ullerslev',
#   'MunicipalityNo': '450',
#   'Municipality': 'Nyborg',
#   'RegionName': 'Syddanmark',
#   'ConnectionPointLatitude': 55.36018,
#   'ConnectionPointLongitude': 10.68055,
#   'NetCompanyName': 'VORES ELNET A/S',
#   'region_code': 'dk_mun_450'},
#  {'_id': 917,
#   'ConnectionPointCode': 'VAL',
#   'ConnectionPointName': 'Valseværket',
#   'MunicipalityNo': '260',
#   'Municipality': 'Halsnæs',
#   'RegionName': 'Hovedstaden',
#   'ConnectionPointLatitude': 55.961136,
#   'ConnectionPointLongitude': 12.019283,
#   'NetCompanyName': 'REGIONALE NET',
#   'region_code': 'dk_mun_260'},
#  {'_id': 924,
#   'ConnectionPointCode': 'VBYV',
#   'ConnectionPointName': 'Vestbyen',
#   'MunicipalityNo': '540',
#   'Municipality': 'Sønderborg',
#   'RegionName': 'Syddanmark',
#   'ConnectionPointLatitude': 55.05379,
#   'ConnectionPointLongitude': 9.90895,
#   'NetCompanyName': 'N1',
#   'region_code': 'dk_mun_540'},
#  {'_id': 928,
#   'ConnectionPointCode': 'VEH',
#   'ConnectionPointName': 'Vesthavnen',
#   'MunicipalityNo': '400',
#   'Municipality': 'Bornholm',
#   'RegionName': 'Hovedstaden',
#   'ConnectionPointLatitude': 55.0993,
#   'ConnectionPointLongitude': 14.68996,
#   'NetCompanyName': 'Thy-Mors Energi A/S',
#   'region_code': 'dk_mun_400'},
#  {'_id': 929,
#   'ConnectionPointCode': 'VEJ',
#   'ConnectionPointName': 'Vejleå',
#   'MunicipalityNo': '169',
#   'Municipality': 'Høje-Taastrup',
#   'RegionName': 'Hovedstaden',
#   'ConnectionPointLatitude': 55.660772,
#   'ConnectionPointLongitude': 12.319345,
#   'NetCompanyName': 'REGIONALE NET',
#   'region_code': 'dk_mun_169'},
#  {'_id': 938,
#   'ConnectionPointCode': 'VHA',
#   'ConnectionPointName': 'Vesterhassing',
#   'MunicipalityNo': '851',
#   'Municipality': 'Aalborg',
#   'RegionName': 'Nordjylland',
#   'ConnectionPointLatitude': 57.061675,
#   'ConnectionPointLongitude': 10.090948,
#   'NetCompanyName': 'Eltra amba',
#   'region_code': 'dk_mun_851'},
#  {'_id': 942,
#   'ConnectionPointCode': 'VIBV',
#   'ConnectionPointName': 'Vibevej',
#   'MunicipalityNo': '561',
#   'Municipality': 'Esbjerg',
#   'RegionName': 'Syddanmark',
#   'ConnectionPointLatitude': 55.48757,
#   'ConnectionPointLongitude': 8.46283,
#   'NetCompanyName': 'N1',
#   'region_code': 'dk_mun_561'},
#  {'_id': 944,
#   'ConnectionPointCode': 'VID',
#   'ConnectionPointName': 'VidebæK',
#   'MunicipalityNo': '760',
#   'Municipality': 'Ringkøbing-Skjern',
#   'RegionName': 'Midtjylland',
#   'ConnectionPointLatitude': 56.103189,
#   'ConnectionPointLongitude': 8.598395,
#   'NetCompanyName': 'Vestjyske Net A/S',
#   'region_code': 'dk_mun_760'},
#  {'_id': 945,
#   'ConnectionPointCode': 'VIK',
#   'ConnectionPointName': 'Vigerslevkbst.',
#   'MunicipalityNo': '101',
#   'Municipality': 'København',
#   'RegionName': 'Hovedstaden',
#   'ConnectionPointLatitude': 55.66172,
#   'ConnectionPointLongitude': 12.51528,
#   'NetCompanyName': 'KE TRANSMISSION',
#   'region_code': 'dk_mun_101'},
#  {'_id': 946,
#   'ConnectionPointCode': 'VIL',
#   'ConnectionPointName': 'Vilsted',
#   'MunicipalityNo': '820',
#   'Municipality': 'Vesthimmerland',
#   'RegionName': 'Nordjylland',
#   'ConnectionPointLatitude': 56.9178,
#   'ConnectionPointLongitude': 9.299185,
#   'NetCompanyName': 'NV Net Amba',
#   'region_code': 'dk_mun_820'},
#  {'_id': 947,
#   'ConnectionPointCode': 'VIN',
#   'ConnectionPointName': 'Vindingegård',
#   'MunicipalityNo': '265',
#   'Municipality': 'Roskilde',
#   'RegionName': 'Sjælland',
#   'ConnectionPointLatitude': 55.648545,
#   'ConnectionPointLongitude': 12.156752,
#   'NetCompanyName': 'REGIONALE NET',
#   'region_code': 'dk_mun_265'},
#  {'_id': 948,
#   'ConnectionPointCode': 'VINV',
#   'ConnectionPointName': 'Vinderup',
#   'MunicipalityNo': '661',
#   'Municipality': 'Holstebro',
#   'RegionName': 'Midtjylland',
#   'ConnectionPointLatitude': 56.48859,
#   'ConnectionPointLongitude': 8.7854,
#   'NetCompanyName': 'L-Net A/S',
#   'region_code': 'dk_mun_661'},
#  {'_id': 959,
#   'ConnectionPointCode': 'VLO',
#   'ConnectionPointName': 'Vestlolland',
#   'MunicipalityNo': '360',
#   'Municipality': 'Lolland',
#   'RegionName': 'Sjælland',
#   'ConnectionPointLatitude': 54.840392,
#   'ConnectionPointLongitude': 11.188055,
#   'NetCompanyName': 'SEAS/NVE TRANSMISSION',
#   'region_code': 'dk_mun_360'},
#  {'_id': 972,
#   'ConnectionPointCode': 'VORV',
#   'ConnectionPointName': 'Vorup',
#   'MunicipalityNo': '730',
#   'Municipality': 'Randers',
#   'RegionName': 'Midtjylland',
#   'ConnectionPointLatitude': 56.43616,
#   'ConnectionPointLongitude': 10.04829,
#   'NetCompanyName': 'N1Randers',
#   'region_code': 'dk_mun_730'},
#  {'_id': 977,
#   'ConnectionPointCode': 'VRI',
#   'ConnectionPointName': 'Vejlby',
#   'MunicipalityNo': '751',
#   'Municipality': 'Aarhus',
#   'RegionName': 'Midtjylland',
#   'ConnectionPointLatitude': 56.19491,
#   'ConnectionPointLongitude': 10.21725,
#   'NetCompanyName': 'Konstant Nord',
#   'region_code': 'dk_mun_751'},
#  {'_id': 986,
#   'ConnectionPointCode': 'VSTV',
#   'ConnectionPointName': 'Vadstrup',
#   'MunicipalityNo': '741',
#   'Municipality': 'Samsø',
#   'RegionName': 'Midtjylland',
#   'ConnectionPointLatitude': 55.8472,
#   'ConnectionPointLongitude': 10.56036,
#   'NetCompanyName': 'Konstant Nord',
#   'region_code': 'dk_mun_741'},
#  {'_id': 1020,
#   'ConnectionPointCode': 'ÅBØ',
#   'ConnectionPointName': 'Ålborg øst',
#   'MunicipalityNo': '851',
#   'Municipality': 'Aalborg',
#   'RegionName': 'Nordjylland',
#   'ConnectionPointLatitude': 57.048548,
#   'ConnectionPointLongitude': 10.033046,
#   'NetCompanyName': 'NV Net Amba',
#   'region_code': 'dk_mun_851'},
#  {'_id': 1032,
#   'ConnectionPointCode': 'ÅSP',
#   'ConnectionPointName': 'Åstrup',
#   'MunicipalityNo': '707',
#   'Municipality': 'Norddjurs',
#   'RegionName': 'Midtjylland',
#   'ConnectionPointLatitude': 56.421722,
#   'ConnectionPointLongitude': 10.895915,
#   'NetCompanyName': 'Midtjyske Net A.m.b.a.',
#   'region_code': 'dk_mun_707'},
#  {'_id': 1010,
#   'ConnectionPointCode': 'ØSH',
#   'ConnectionPointName': 'Østerholm',
#   'MunicipalityNo': '370',
#   'Municipality': 'Næstved',
#   'RegionName': 'Sjælland',
#   'ConnectionPointLatitude': 55.20493,
#   'ConnectionPointLongitude': 11.742552,
#   'NetCompanyName': 'SEAS/NVE TRANSMISSION',
#   'region_code': 'dk_mun_370'}]

# %%
metadata = service.fetch_metadata()
data = service.fetch_data()

# %%
connection_points = {
    row["ConnectionPointCode"] : row for row in data
}

# %%
{k: v for k, v in connection_points.items() if "strup" in v["ConnectionPointName"].lower()}
# Out:
# {'ESK': {'_id': 171,
#   'ConnectionPointCode': 'ESK',
#   'ConnectionPointName': 'Eskilstrup',
#   'MunicipalityNo': '376',
#   'Municipality': 'Guldborgsund',
#   'RegionName': 'Sjælland',
#   'ConnectionPointLatitude': 54.849705,
#   'ConnectionPointLongitude': 11.893968,
#   'NetCompanyName': 'SEAS/NVE TRANSMISSION',
#   'region_code': 'dk_mun_376'},
#  'EST': {'_id': 173,
#   'ConnectionPointCode': 'EST',
#   'ConnectionPointName': 'Estrupvej',
#   'MunicipalityNo': '561',
#   'Municipality': 'Esbjerg',
#   'RegionName': 'Syddanmark',
#   'ConnectionPointLatitude': 55.462691,
#   'ConnectionPointLongitude': 8.474662,
#   'NetCompanyName': 'Vestjyske Net A/S',
#   'region_code': 'dk_mun_561'},
#  'FARV': {'_id': 180,
#   'ConnectionPointCode': 'FARV',
#   'ConnectionPointName': 'Farstrup',
#   'MunicipalityNo': '480',
#   'Municipality': 'Nordfyn',
#   'RegionName': 'Syddanmark',
#   'ConnectionPointLatitude': 55.46349,
#   'ConnectionPointLongitude': 10.1906,
#   'NetCompanyName': 'VORES ELNET A/S',
#   'region_code': 'dk_mun_480'},
#  'HUP': {'_id': 359,
#   'ConnectionPointCode': 'HUP',
#   'ConnectionPointName': 'Hunstrup',
#   'MunicipalityNo': '787',
#   'Municipality': 'Thisted',
#   'RegionName': 'Nordjylland',
#   'ConnectionPointLatitude': 57.04151,
#   'ConnectionPointLongitude': 8.8117,
#   'NetCompanyName': 'Thy-Mors Energi A/S',
#   'region_code': 'dk_mun_787'},
#  'IDE': {'_id': 382,
#   'ConnectionPointCode': 'IDE',
#   'ConnectionPointName': 'Idestrup',
#   'MunicipalityNo': '376',
#   'Municipality': 'Guldborgsund',
#   'RegionName': 'Sjælland',
#   'ConnectionPointLatitude': 54.751226,
#   'ConnectionPointLongitude': 11.946306,
#   'NetCompanyName': 'SEAS/NVE TRANSMISSION',
#   'region_code': 'dk_mun_376'},
#  'KAK': {'_id': 405,
#   'ConnectionPointCode': 'KAK',
#   'ConnectionPointName': 'Kastrup',
#   'MunicipalityNo': '185',
#   'Municipality': 'Tårnby',
#   'RegionName': 'Hovedstaden',
#   'ConnectionPointLatitude': 55.631542,
#   'ConnectionPointLongitude': 12.657965,
#   'NetCompanyName': 'KE TRANSMISSION',
#   'region_code': 'dk_mun_185'},
#  'KAM': {'_id': 406,
#   'ConnectionPointCode': 'KAM',
#   'ConnectionPointName': 'Kamstrup',
#   'MunicipalityNo': '265',
#   'Municipality': 'Roskilde',
#   'RegionName': 'Sjælland',
#   'ConnectionPointLatitude': 55.608542,
#   'ConnectionPointLongitude': 12.073195,
#   'NetCompanyName': 'REGIONALE NET',
#   'region_code': 'dk_mun_265'},
#  'KIN': {'_id': 428,
#   'ConnectionPointCode': 'KIN',
#   'ConnectionPointName': 'Kingstrup',
#   'MunicipalityNo': '410',
#   'Municipality': 'Middelfart',
#   'RegionName': 'Syddanmark',
#   'ConnectionPointLatitude': 55.411047,
#   'ConnectionPointLongitude': 9.968659,
#   'NetCompanyName': 'FynsNet a.m.b.a.',
#   'region_code': 'dk_mun_410'},
#  'KRL': {'_id': 450,
#   'ConnectionPointCode': 'KRL',
#   'ConnectionPointName': 'Karlstrup',
#   'MunicipalityNo': '269',
#   'Municipality': 'Solrød',
#   'RegionName': 'Sjælland',
#   'ConnectionPointLatitude': 55.54376,
#   'ConnectionPointLongitude': 12.20485,
#   'NetCompanyName': 'Konstant Syd',
#   'region_code': 'dk_mun_269'},
#  'MKS': {'_id': 544,
#   'ConnectionPointCode': 'MKS',
#   'ConnectionPointName': 'Studstrup',
#   'MunicipalityNo': '751',
#   'Municipality': 'Aarhus',
#   'RegionName': 'Midtjylland',
#   'ConnectionPointLatitude': 56.25165,
#   'ConnectionPointLongitude': 10.34222,
#   'NetCompanyName': 'Midtjyske Net A.m.b.a.',
#   'region_code': 'dk_mun_751'},
#  'NSP': {'_id': 596,
#   'ConnectionPointCode': 'NSP',
#   'ConnectionPointName': 'Nibstrup',
#   'MunicipalityNo': '810',
#   'Municipality': 'Brønderslev',
#   'RegionName': 'Nordjylland',
#   'ConnectionPointLatitude': 57.267212,
#   'ConnectionPointLongitude': 9.979697,
#   'NetCompanyName': 'NV Net Amba',
#   'region_code': 'dk_mun_810'},
#  'PDS': {'_id': 650,
#   'ConnectionPointCode': 'PDS',
#   'ConnectionPointName': 'Pindstrup',
#   'MunicipalityNo': '706',
#   'Municipality': 'Syddjurs',
#   'RegionName': 'Midtjylland',
#   'ConnectionPointLatitude': 56.386,
#   'ConnectionPointLongitude': 10.41618,
#   'NetCompanyName': 'Konstant Nord',
#   'region_code': 'dk_mun_706'},
#  'SPR': {'_id': 798,
#   'ConnectionPointCode': 'SPR',
#   'ConnectionPointName': 'Sperrestrupgård',
#   'MunicipalityNo': '240',
#   'Municipality': 'Egedal',
#   'RegionName': 'Hovedstaden',
#   'ConnectionPointLatitude': 55.789084,
#   'ConnectionPointLongitude': 12.18442,
#   'NetCompanyName': 'REGIONALE NET',
#   'region_code': 'dk_mun_240'},
#  'STEV': {'_id': 807,
#   'ConnectionPointCode': 'STEV',
#   'ConnectionPointName': 'Stenstrup',
#   'MunicipalityNo': '479',
#   'Municipality': 'Svendborg',
#   'RegionName': 'Syddanmark',
#   'ConnectionPointLatitude': 55.12069,
#   'ConnectionPointLongitude': 10.51975,
#   'NetCompanyName': 'FLOW ELNET A/S',
#   'region_code': 'dk_mun_479'},
#  'TEG': {'_id': 861,
#   'ConnectionPointCode': 'TEG',
#   'ConnectionPointName': 'Teglstrupgård',
#   'MunicipalityNo': '217',
#   'Municipality': 'Helsingør',
#   'RegionName': 'Hovedstaden',
#   'ConnectionPointLatitude': 56.028681,
#   'ConnectionPointLongitude': 12.563658,
#   'NetCompanyName': 'REGIONALE NET',
#   'region_code': 'dk_mun_217'},
#  'TRSV': {'_id': 891,
#   'ConnectionPointCode': 'TRSV',
#   'ConnectionPointName': 'Trustrup',
#   'MunicipalityNo': '706',
#   'Municipality': 'Syddjurs',
#   'RegionName': 'Midtjylland',
#   'ConnectionPointLatitude': 56.34444,
#   'ConnectionPointLongitude': 10.78758,
#   'NetCompanyName': 'Konstant Nord',
#   'region_code': 'dk_mun_706'},
#  'TSTV': {'_id': 895,
#   'ConnectionPointCode': 'TSTV',
#   'ConnectionPointName': 'Tistrup',
#   'MunicipalityNo': '550',
#   'Municipality': 'Tønder',
#   'RegionName': 'Syddanmark',
#   'ConnectionPointLatitude': 55.1341,
#   'ConnectionPointLongitude': 8.59888,
#   'NetCompanyName': 'N1',
#   'region_code': 'dk_mun_550'},
#  'VSTV': {'_id': 986,
#   'ConnectionPointCode': 'VSTV',
#   'ConnectionPointName': 'Vadstrup',
#   'MunicipalityNo': '741',
#   'Municipality': 'Samsø',
#   'RegionName': 'Midtjylland',
#   'ConnectionPointLatitude': 55.8472,
#   'ConnectionPointLongitude': 10.56036,
#   'NetCompanyName': 'Konstant Nord',
#   'region_code': 'dk_mun_741'},
#  'ÅSP': {'_id': 1032,
#   'ConnectionPointCode': 'ÅSP',
#   'ConnectionPointName': 'Åstrup',
#   'MunicipalityNo': '707',
#   'Municipality': 'Norddjurs',
#   'RegionName': 'Midtjylland',
#   'ConnectionPointLatitude': 56.421722,
#   'ConnectionPointLongitude': 10.895915,
#   'NetCompanyName': 'Midtjyske Net A.m.b.a.',
#   'region_code': 'dk_mun_707'}}

# %%
# ws = openpyxl.load_workbook("../Energinet Extra Codes.xlsx").active

# [column_names, *rows] = list(ws.values)
# extra_station_codes = {}
# for row in rows:
#     d = dict(zip(column_names, row))
#     if d["Code"] is not None:
#         extra_station_codes[d["Name"]] = d["Code"]

# %%
# extra_station_codes

# %%
extra_station_codes = {
    'A2': 'BJS',
    'AMF_132_F': 'AMV',
    'HASØ132_F': 'HAS',
    'ISHN132_N-$': 'ISH',
    'MRP1': 'TEG',
    'VSAK132_S1': 'VAL',
    'BIX_150_S1': 'BIL',
    'FRX_150_S1': 'FRT',
    'I4': 'ABS',
    'KLT_150_S1': 'KLF',
    'VKHI012_SFIK': 'VKE',
    'term_KT51-HT3': 'TJE'
}

# %%
import io
import urllib.request

# %%
netdata_url = "https://energinet.dk/-/media/76C3D434A7E2499F94E7DB66D3A2DE21.xlsx?la=da&hash=638E165AA57F627409CB9394D56D53614F5D7336"

with urllib.request.urlopen(netdata_url) as fileobj:
    buf = io.BytesIO()
    buf.write(fileobj.read())

buf.seek(0)
wb = openpyxl.load_workbook(buf)

# %%
wb.sheetnames
# Out:
# ['Bus',
#  'Line',
#  'Transformer2',
#  'Transformer3',
#  'Generator',
#  'Load',
#  'Shunt',
#  'HVDC',
#  'PFModelInfo',
#  'Ark1',
#  'Ark2',
#  'Ark3']

# %%
import networkx as nx

# %%
def get_sheet_data(ws):
    [_1, _2, _3, header, *rows] = ws.values
    for row in rows:
        yield {k: v for k, v in zip(header, row)}

# %%
import re
def match_bus_to_code(d, codes, extra_codes):
    extensions = {
        "ENDKW": "V",
        "ENDKE": "Ø"
    }
    name = d["Bus Name"]
    if name in extra_codes and extra_codes[name] in codes:
        return extra_codes[name]
    name_regex = re.compile(r"([^0-9_]+)_?(\d*)_?(.*)")
    match = name_regex.match(name)
    if not match:
        return
    bus_code = match.groups()[0]
    if bus_code in codes:
        return bus_code
    if d["Location Name"] in extensions:
        area_code = bus_code + extensions[d["Location Name"]]
        if area_code in codes:
            return area_code

# %%
energy_grid = nx.Graph()

# %%
bus_labels = {}
for d in get_sheet_data(wb["Bus"]):
    node_label = ("Bus", d["Bus Name"])
    bus_labels[d["Bus Index"]] = node_label
    attributes = {k: v for k, v in d.items()}
    connection_code = match_bus_to_code(d, list(connection_points), extra_station_codes)
    if connection_code is not None:
        attributes.update(connection_points[connection_code])
    energy_grid.add_nodes_from([(node_label, attributes)])

# %%
for d in get_sheet_data(wb["Line"]):
    energy_grid.add_edges_from([(bus_labels[d["Node 1"]], bus_labels[d["Node 2"]], d)])

# %%
for d in get_sheet_data(wb["Transformer2"]):
    node_label = ("Transformer3", d["2-Transformer Name"])    
    energy_grid.add_nodes_from([(node_label, d)])
    energy_grid.add_edges_from([
        (bus_labels[d["High.V Bus Index"]], node_label), 
        (bus_labels[d["Low.V Bus Index"]], node_label)
    ])

# %%
for d in get_sheet_data(wb["Transformer3"]):
    node_label = ("Transformer3", d["3_Transformer Name"])
    energy_grid.add_nodes_from([(node_label, d)])
    edges = [
        (bus_labels[d["High.V Bus Index"]], node_label),
        (bus_labels[d["Mid.V Bus Index"]], node_label),        
        (bus_labels[d["Low.V Bus Index"]], node_label)
    ]
    energy_grid.add_edges_from(edges)

# %%
for d in get_sheet_data(wb["Generator"]):
    node_label = ("Generator", d["Generator Name"])
    energy_grid.add_nodes_from([(node_label, d)])
    energy_grid.add_edge(node_label, bus_labels[d["Bus Index"]])

# %%
for d in get_sheet_data(wb["Load"]):
    node_label = ("Load", d["Load Name"])
    energy_grid.add_nodes_from([(node_label, d)])
    energy_grid.add_edge(node_label, bus_labels[d["Load Index"]])

# %%
for d in get_sheet_data(wb["Shunt"]):
    node_label = ("Shunt", d["Shunt Name"])
    energy_grid.add_nodes_from([(node_label, d)])
    energy_grid.add_edge(node_label, bus_labels[d["Bus Index"]])

# %%
for d in get_sheet_data(wb["HVDC"]):
    node_label = ("HVDC", d["HVDC Name"])
    energy_grid.add_nodes_from([(node_label, d)])
    energy_grid.add_edge(node_label, bus_labels[d["Bus Index"]])

# %%
[len(x) for x in nx.connected_components(energy_grid)]
# Out:
# [451, 561, 1, 1]

# %%
[x for x in nx.connected_components(energy_grid) if len(x) == 1]
# Out:
# [{('Bus', 'EDR_400_NIE1')}, {('Bus', 'EDR_400_NIE1(1)')}]

# %%
municipality_nodes = {k: v["region_code"] for k, v in energy_grid.nodes.items() if "region_code" in v}
municipality_nodes
# Out:
# {('Bus', 'A2'): 'dk_mun_259',
#  ('Bus', 'ABS_150_S2-'): 'dk_mun_420',
#  ('Bus', 'ADL_150_S1'): 'dk_mun_851',
#  ('Bus', 'ALL_132_F1'): 'dk_mun_201',
#  ('Bus', 'AMF_132_F'): 'dk_mun_101',
#  ('Bus', 'AMK_132_A'): 'dk_mun_101',
#  ('Bus', 'AMV_010_SFIK'): 'dk_mun_101',
#  ('Bus', 'AMV_0173_SFIK'): 'dk_mun_101',
#  ('Bus', 'AMV_132_A'): 'dk_mun_101',
#  ('Bus', 'AND_150_S2'): 'dk_mun_575',
#  ('Bus', 'ASR_150_S2'): 'dk_mun_756',
#  ('Bus', 'ASR_400-ZL-'): 'dk_mun_756',
#  ('Bus', 'ASR_400_S1'): 'dk_mun_756',
#  ('Bus', 'ASV_0122_SFIK'): 'dk_mun_326',
#  ('Bus', 'ASV_0215_SFIK'): 'dk_mun_326',
#  ('Bus', 'ASV_132_F'): 'dk_mun_326',
#  ('Bus', 'ASV_4001_SFIK'): 'dk_mun_326',
#  ('Bus', 'ASV_400_K'): 'dk_mun_326',
#  ('Bus', 'AVV_0122_SFIK'): 'dk_mun_167',
#  ('Bus', 'AVV_0123_SFIK'): 'dk_mun_167',
#  ('Bus', 'AVV_0171_SFIK'): 'dk_mun_167',
#  ('Bus', 'AVV_0201_SFIK'): 'dk_mun_167',
#  ('Bus', 'AVV_132_F'): 'dk_mun_167',
#  ('Bus', 'AVV_132_SFIK'): 'dk_mun_167',
#  ('Bus', 'AVV_400_SK.K'): 'dk_mun_167',
#  ('Bus', 'BAG_132_F'): 'dk_mun_159',
#  ('Bus', 'BBR_150_S1'): 'dk_mun_550',
#  ('Bus', 'BDK_150_S1'): 'dk_mun_860',
#  ('Bus', 'BDR_150_S1'): 'dk_mun_621',
#  ('Bus', 'BED_150_N'): 'dk_mun_787',
#  ('Bus', 'BJS_016'): 'dk_mun_259',
#  ('Bus', 'BJS_132_SFIK'): 'dk_mun_259',
#  ('Bus', 'BJS_220_SFIK'): 'dk_mun_259',
#  ('Bus', 'BJS_400_K'): 'dk_mun_259',
#  ('Bus', 'BLA_132_F'): 'dk_mun_370',
#  ('Bus', 'BOR_132_F'): 'dk_mun_219',
#  ('Bus', 'DYB_150_SA'): 'dk_mun_813',
#  ('Bus', 'EBY'): 'dk_mun_161',
#  ('Bus', 'EBY_132_F'): 'dk_mun_161',
#  ('Bus', 'EDR_015_SFIK'): 'dk_mun_561',
#  ('Bus', 'EDR_150_SV'): 'dk_mun_561',
#  ('Bus', 'EDR_150_SØ2'): 'dk_mun_561',
#  ('Bus', 'EDR_220_S1'): 'dk_mun_561',
#  ('Bus', 'EDR_400_NIE1'): 'dk_mun_561',
#  ('Bus', 'EDR_400_NIE1(1)'): 'dk_mun_561',
#  ('Bus', 'EDR_400_S1'): 'dk_mun_561',
#  ('Bus', 'ESK_132_F'): 'dk_mun_376',
#  ('Bus', 'EST_150_SFIK'): 'dk_mun_561',
#  ('Bus', 'FER_150_S1'): 'dk_mun_851',
#  ('Bus', 'FER_400_S1'): 'dk_mun_851',
#  ('Bus', 'FGD_010_S1'): 'dk_mun_461',
#  ('Bus', 'FGD_016'): 'dk_mun_461',
#  ('Bus', 'FGD_150_S1'): 'dk_mun_461',
#  ('Bus', 'FGD_400_S1'): 'dk_mun_461',
#  ('Bus', 'FNM_132_F1'): 'dk_mun_370',
#  ('Bus', 'FRD_150_S1'): 'dk_mun_849',
#  ('Bus', 'FVO_010_SFIK'): 'dk_mun_461',
#  ('Bus', 'FVO_021A_SFIK'): 'dk_mun_461',
#  ('Bus', 'FVO_150_S1'): 'dk_mun_461',
#  ('Bus', 'FVO_400_SFIK'): 'dk_mun_461',
#  ('Bus', 'GLN_010D_SFIK1'): 'dk_mun_159',
#  ('Bus', 'GLN_010D_SFIK2'): 'dk_mun_159',
#  ('Bus', 'GLN_132_F'): 'dk_mun_159',
#  ('Bus', 'GLN_400_SK.L'): 'dk_mun_159',
#  ('Bus', 'GRN_132_F1'): 'dk_mun_159',
#  ('Bus', 'GRP_150_S1'): 'dk_mun_410',
#  ('Bus', 'GØR_132_F'): 'dk_mun_219',
#  ('Bus', 'GØR_132_SFIK'): 'dk_mun_219',
#  ('Bus', 'GØR_400_SKM2'): 'dk_mun_219',
#  ('Bus', 'HCV_132_A'): 'dk_mun_101',
#  ('Bus', 'HCV_400_SK.A'): 'dk_mun_101',
#  ('Bus', 'HMA_132_F1'): 'dk_mun_370',
#  ('Bus', 'HNB_150_S1'): 'dk_mun_730',
#  ('Bus', 'HOD_150_SØ'): 'dk_mun_575',
#  ('Bus', 'HRA_150_S1'): 'dk_mun_573',
#  ('Bus', 'HRB_150_S1'): 'dk_mun_561',
#  ('Bus', 'HVE_132_F'): 'dk_mun_240',
#  ('Bus', 'HVE_400_'): 'dk_mun_240',
#  ('Bus', 'HVO_150_S1'): 'dk_mun_851',
#  ('Bus', 'HVV_150_S1'): 'dk_mun_851',
#  ('Bus', 'HØN_150_S1'): 'dk_mun_746',
#  ('Bus', 'I4'): 'dk_mun_420',
#  ('Bus', 'IDE_132_F'): 'dk_mun_376',
#  ('Bus', 'IDU_150_N'): 'dk_mun_661',
#  ('Bus', 'IDU_400_S1'): 'dk_mun_661',
#  ('Bus', 'ISHN132_N-$'): 'dk_mun_183',
#  ('Bus', 'ISH_132_F'): 'dk_mun_183',
#  ('Bus', 'ISH_220_S1'): 'dk_mun_183',
#  ('Bus', 'ISH_400_SK.K'): 'dk_mun_183',
#  ('Bus', 'KAE_150_N'): 'dk_mun_573',
#  ('Bus', 'KAG_150_S1'): 'dk_mun_846',
#  ('Bus', 'KAK_132_A'): 'dk_mun_185',
#  ('Bus', 'KAM_132_F'): 'dk_mun_265',
#  ('Bus', 'KAS_150_SA'): 'dk_mun_580',
#  ('Bus', 'KAS_400_S1'): 'dk_mun_580',
#  ('Bus', 'KBG_132_SFIK1'): 'dk_mun_326',
#  ('Bus', 'KBG_132_SFIK2'): 'dk_mun_326',
#  ('Bus', 'KIN_150_S1'): 'dk_mun_410',
#  ('Bus', 'KIN_400_S1'): 'dk_mun_410',
#  ('Bus', 'KNA_150_S1'): 'dk_mun_630',
#  ('Bus', 'KRL_132-WA1'): 'dk_mun_269',
#  ('Bus', 'KSV_132_F'): 'dk_mun_350',
#  ('Bus', 'KYV_0102_SFIK'): 'dk_mun_250',
#  ('Bus', 'KYV_0103_SFIK'): 'dk_mun_250',
#  ('Bus', 'KYV_0181_SFIK'): 'dk_mun_250',
#  ('Bus', 'KYV_0182_SFIK'): 'dk_mun_250',
#  ('Bus', 'KYV_132_SK.F'): 'dk_mun_250',
#  ('Bus', 'LAG_150_S1'): 'dk_mun_621',
#  ('Bus', 'LAG_400_S1'): 'dk_mun_621',
#  ('Bus', 'LUP_132_F'): 'dk_mun_250',
#  ('Bus', 'LYK_150_NORD'): 'dk_mun_561',
#  ('Bus', 'MAL_150_S1'): 'dk_mun_751',
#  ('Bus', 'MAL_400_S1'): 'dk_mun_751',
#  ('Bus', 'MAV_132_F'): 'dk_mun_390',
#  ('Bus', 'MES_150_SK1'): 'dk_mun_706',
#  ('Bus', 'MKS_019A_SFIK'): 'dk_mun_751',
#  ('Bus', 'MKS_019B_SFIK'): 'dk_mun_751',
#  ('Bus', 'MKS_150_S1'): 'dk_mun_751',
#  ('Bus', 'MKS_400_SFIK'): 'dk_mun_751',
#  ('Bus', 'MLP_150_S1'): 'dk_mun_751',
#  ('Bus', 'MLU_150_S1'): 'dk_mun_730',
#  ('Bus', 'MOSØ132_WA2'): 'dk_mun_253',
#  ('Bus', 'MRP1'): 'dk_mun_217',
#  ('Bus', 'MÅLØ132_F'): 'dk_mun_151',
#  ('Bus', 'NAM_132_F'): 'dk_mun_306',
#  ('Bus', 'NOR_150_S1'): 'dk_mun_787',
#  ('Bus', 'NSP_150_SA'): 'dk_mun_810',
#  ('Bus', 'NSV_132_F'): 'dk_mun_370',
#  ('Bus', 'NVV_021A_SFIK'): 'dk_mun_851',
#  ('Bus', 'NVV_021B_SFIK'): 'dk_mun_851',
#  ('Bus', 'NVV_150_S1'): 'dk_mun_851',
#  ('Bus', 'NVV_400_S1'): 'dk_mun_851',
#  ('Bus', 'NYR_132_F'): 'dk_mun_340',
#  ('Bus', 'ORH_132_F1'): 'dk_mun_376',
#  ('Bus', 'OST_132_F'): 'dk_mun_350',
#  ('Bus', 'OSØ_150_S1'): 'dk_mun_461',
#  ('Bus', 'RAM_150_S1'): 'dk_mun_665',
#  ('Bus', 'RDS_132_SFIK'): 'dk_mun_376',
#  ('Bus', 'RIB_150_S1'): 'dk_mun_561',
#  ('Bus', 'RIL_132_F'): 'dk_mun_370',
#  ('Bus', 'RYT_150_S1'): 'dk_mun_607',
#  ('Bus', 'SBA_150_S1'): 'dk_mun_813',
#  ('Bus', 'SFE_150_SEK1'): 'dk_mun_657',
#  ('Bus', 'SHE_021_SFIK'): 'dk_mun_580',
#  ('Bus', 'SHE_150_SV1'): 'dk_mun_580',
#  ('Bus', 'SIB_132_F'): 'dk_mun_350',
#  ('Bus', 'SKA_150_SFIK'): 'dk_mun_851',
#  ('Bus', 'SMK_132_A'): 'dk_mun_101',
#  ('Bus', 'SOS_132_F'): 'dk_mun_326',
#  ('Bus', 'SPR_132_F'): 'dk_mun_240',
#  ('Bus', 'STR_150_SV'): 'dk_mun_671',
#  ('Bus', 'STSØ132_F1'): 'dk_mun_326',
#  ('Bus', 'SVB_150_S1'): 'dk_mun_479',
#  ('Bus', 'SVS_021_SFIK'): 'dk_mun_607',
#  ('Bus', 'SVS_150_S1'): 'dk_mun_607',
#  ('Bus', 'SVS_400_SFIK'): 'dk_mun_607',
#  ('Bus', 'SØN_150_VEST'): 'dk_mun_540',
#  ('Bus', 'TAN_150_SK1'): 'dk_mun_791',
#  ('Bus', 'THØ_150_S1'): 'dk_mun_846',
#  ('Bus', 'TJE_010_S3'): 'dk_mun_791',
#  ('Bus', 'TJE_013_SFIK'): 'dk_mun_791',
#  ('Bus', 'TJE_150_S1'): 'dk_mun_791',
#  ('Bus', 'TJE_150_S11'): 'dk_mun_791',
#  ('Bus', 'TJE_400_S1'): 'dk_mun_791',
#  ('Bus', 'TOR_132_F'): 'dk_mun_316',
#  ('Bus', 'TRI_150_S1'): 'dk_mun_751',
#  ('Bus', 'TRI_220_S1'): 'dk_mun_751',
#  ('Bus', 'TRI_400_S1'): 'dk_mun_751',
#  ('Bus', 'VAL_132_WA2'): 'dk_mun_260',
#  ('Bus', 'VEJ_132_F'): 'dk_mun_169',
#  ('Bus', 'VHA_010_SFIK'): 'dk_mun_851',
#  ('Bus', 'VHA_012_SFIK'): 'dk_mun_851',
#  ('Bus', 'VHA_150_S1-'): 'dk_mun_851',
#  ('Bus', 'VHA_400_S1'): 'dk_mun_851',
#  ('Bus', 'VID_150_N'): 'dk_mun_760',
#  ('Bus', 'VIK_132_A'): 'dk_mun_101',
#  ('Bus', 'VIL_150_S1'): 'dk_mun_820',
#  ('Bus', 'VIN_132_F'): 'dk_mun_265',
#  ('Bus', 'VLO_132_F'): 'dk_mun_360',
#  ('Bus', 'VSAK132_S1'): 'dk_mun_260',
#  ('Bus', 'term_KT51-HT3'): 'dk_mun_791',
#  ('Bus', 'ÅBØ_150_S1'): 'dk_mun_851',
#  ('Bus', 'ÅSP_150_S1'): 'dk_mun_707',
#  ('Bus', 'ØLS_132_F'): 'dk_mun_240',
#  ('Bus', 'ØSH_132_F'): 'dk_mun_370'}

# %%
municipality_connections = set()
for n1, n2 in energy_grid.edges:
    try:
        m1 = municipality_nodes[n1]
        m2 = municipality_nodes[n2]
        if m2 < m1:
            m1, m2 = m2, m1
        municipality_connections.add((m1, m2))
    except KeyError:
        pass
municipality_connections
# Out:
# {('dk_mun_101', 'dk_mun_101'),
#  ('dk_mun_101', 'dk_mun_159'),
#  ('dk_mun_101', 'dk_mun_167'),
#  ('dk_mun_101', 'dk_mun_185'),
#  ('dk_mun_151', 'dk_mun_240'),
#  ('dk_mun_159', 'dk_mun_159'),
#  ('dk_mun_159', 'dk_mun_161'),
#  ('dk_mun_159', 'dk_mun_240'),
#  ('dk_mun_161', 'dk_mun_161'),
#  ('dk_mun_167', 'dk_mun_183'),
#  ('dk_mun_169', 'dk_mun_183'),
#  ('dk_mun_169', 'dk_mun_240'),
#  ('dk_mun_169', 'dk_mun_265'),
#  ('dk_mun_169', 'dk_mun_350'),
#  ('dk_mun_183', 'dk_mun_240'),
#  ('dk_mun_183', 'dk_mun_259'),
#  ('dk_mun_183', 'dk_mun_265'),
#  ('dk_mun_201', 'dk_mun_217'),
#  ('dk_mun_201', 'dk_mun_219'),
#  ('dk_mun_217', 'dk_mun_219'),
#  ('dk_mun_217', 'dk_mun_260'),
#  ('dk_mun_219', 'dk_mun_219'),
#  ('dk_mun_219', 'dk_mun_240'),
#  ('dk_mun_219', 'dk_mun_260'),
#  ('dk_mun_240', 'dk_mun_240'),
#  ('dk_mun_240', 'dk_mun_250'),
#  ('dk_mun_240', 'dk_mun_259'),
#  ('dk_mun_250', 'dk_mun_250'),
#  ('dk_mun_250', 'dk_mun_350'),
#  ('dk_mun_253', 'dk_mun_269'),
#  ('dk_mun_260', 'dk_mun_260'),
#  ('dk_mun_265', 'dk_mun_265'),
#  ('dk_mun_265', 'dk_mun_350'),
#  ('dk_mun_306', 'dk_mun_316'),
#  ('dk_mun_316', 'dk_mun_326'),
#  ('dk_mun_316', 'dk_mun_350'),
#  ('dk_mun_326', 'dk_mun_326'),
#  ('dk_mun_326', 'dk_mun_350'),
#  ('dk_mun_340', 'dk_mun_350'),
#  ('dk_mun_370', 'dk_mun_370'),
#  ('dk_mun_370', 'dk_mun_376'),
#  ('dk_mun_370', 'dk_mun_390'),
#  ('dk_mun_376', 'dk_mun_376'),
#  ('dk_mun_376', 'dk_mun_390'),
#  ('dk_mun_410', 'dk_mun_410'),
#  ('dk_mun_410', 'dk_mun_461'),
#  ('dk_mun_410', 'dk_mun_607'),
#  ('dk_mun_410', 'dk_mun_621'),
#  ('dk_mun_420', 'dk_mun_479'),
#  ('dk_mun_420', 'dk_mun_540'),
#  ('dk_mun_461', 'dk_mun_461'),
#  ('dk_mun_461', 'dk_mun_479'),
#  ('dk_mun_461', 'dk_mun_621'),
#  ('dk_mun_540', 'dk_mun_580'),
#  ('dk_mun_550', 'dk_mun_561'),
#  ('dk_mun_550', 'dk_mun_580'),
#  ('dk_mun_561', 'dk_mun_561'),
#  ('dk_mun_561', 'dk_mun_573'),
#  ('dk_mun_561', 'dk_mun_575'),
#  ('dk_mun_573', 'dk_mun_573'),
#  ('dk_mun_573', 'dk_mun_657'),
#  ('dk_mun_575', 'dk_mun_575'),
#  ('dk_mun_575', 'dk_mun_621'),
#  ('dk_mun_580', 'dk_mun_580'),
#  ('dk_mun_580', 'dk_mun_621'),
#  ('dk_mun_607', 'dk_mun_607'),
#  ('dk_mun_607', 'dk_mun_621'),
#  ('dk_mun_621', 'dk_mun_621'),
#  ('dk_mun_621', 'dk_mun_630'),
#  ('dk_mun_621', 'dk_mun_751'),
#  ('dk_mun_661', 'dk_mun_665'),
#  ('dk_mun_661', 'dk_mun_671'),
#  ('dk_mun_661', 'dk_mun_760'),
#  ('dk_mun_661', 'dk_mun_791'),
#  ('dk_mun_665', 'dk_mun_671'),
#  ('dk_mun_671', 'dk_mun_787'),
#  ('dk_mun_706', 'dk_mun_707'),
#  ('dk_mun_706', 'dk_mun_751'),
#  ('dk_mun_707', 'dk_mun_751'),
#  ('dk_mun_730', 'dk_mun_751'),
#  ('dk_mun_730', 'dk_mun_846'),
#  ('dk_mun_746', 'dk_mun_751'),
#  ('dk_mun_751', 'dk_mun_751'),
#  ('dk_mun_751', 'dk_mun_791'),
#  ('dk_mun_751', 'dk_mun_851'),
#  ('dk_mun_756', 'dk_mun_791'),
#  ('dk_mun_787', 'dk_mun_787'),
#  ('dk_mun_791', 'dk_mun_791'),
#  ('dk_mun_791', 'dk_mun_851'),
#  ('dk_mun_810', 'dk_mun_851'),
#  ('dk_mun_810', 'dk_mun_860'),
#  ('dk_mun_813', 'dk_mun_813'),
#  ('dk_mun_813', 'dk_mun_851'),
#  ('dk_mun_846', 'dk_mun_846'),
#  ('dk_mun_846', 'dk_mun_851'),
#  ('dk_mun_849', 'dk_mun_851'),
#  ('dk_mun_851', 'dk_mun_851'),
#  ('dk_mun_851', 'dk_mun_860')}

# %%
energy_grid.nodes[list(municipality_nodes)[0]]
# Out:
# {'Bus Index': 76,
#  'Bus Name': 'A2',
#  'Station Full Name': 'Bjæverskov',
#  'Location Name': 'ENDKE',
#  'Voltage base[kV]': '232,0',
#  'Voltage min[pu]': '0,00',
#  'Voltage max[pu]': '1,05',
#  '_id': 76,
#  'ConnectionPointCode': 'BJS',
#  'ConnectionPointName': 'Bjæverskov',
#  'MunicipalityNo': '259',
#  'Municipality': 'Køge',
#  'RegionName': 'Sjælland',
#  'ConnectionPointLatitude': 55.45053,
#  'ConnectionPointLongitude': 12.00791,
#  'NetCompanyName': 'SEAS/NVE TRANSMISSION',
#  'region_code': 'dk_mun_259'}

# %%
import sqltables
db = sqltables.Database()
latlon = db.create_table(column_names=["region_code", "lat", "lon"])
latlon.insert([[x["region_code"], x["ConnectionPointLatitude"], x["ConnectionPointLongitude"]] 
               for x in (energy_grid.nodes[k] for k in municipality_nodes.keys())])

# %%
mun_latlon = latlon.table("""select region_code, avg(lat) as lat, avg(lon) as lon from _ group by region_code""")
mun_points = {row.region_code: (row.lat, row.lon) for row in mun_latlon}

# %%
mun_points
# Out:
# {'dk_mun_101': (55.67414544444444, 12.590287444444444),
#  'dk_mun_151': (55.744171, 12.32608),
#  'dk_mun_159': (55.7501205, 12.485704),
#  'dk_mun_161': (55.686573, 12.397478),
#  'dk_mun_167': (55.604988999999996, 12.480812),
#  'dk_mun_169': (55.660772, 12.319345),
#  'dk_mun_183': (55.6346, 12.32171),
#  'dk_mun_185': (55.631542, 12.657965),
#  'dk_mun_201': (55.885227, 12.338456),
#  'dk_mun_217': (56.028681, 12.563658),
#  'dk_mun_219': (55.8955735, 12.196541750000002),
#  'dk_mun_240': (55.755691, 12.198973),
#  'dk_mun_250': (55.80958483333333, 11.896245666666665),
#  'dk_mun_253': (55.585099, 12.258356),
#  'dk_mun_259': (55.45053, 12.00791),
#  'dk_mun_260': (55.961136, 12.019283),
#  'dk_mun_265': (55.6285435, 12.1149735),
#  'dk_mun_269': (55.54376, 12.20485),
#  'dk_mun_306': (55.871017, 11.603077),
#  'dk_mun_316': (55.717711, 11.491859),
#  'dk_mun_326': (55.66188011111111, 11.087549777777777),
#  'dk_mun_340': (55.545725, 11.641376),
#  'dk_mun_350': (55.645783333333334, 11.932815666666668),
#  'dk_mun_360': (54.840392, 11.188055),
#  'dk_mun_370': (55.2519275, 11.774001333333333),
#  'dk_mun_376': (54.959536, 11.174958250000001),
#  'dk_mun_390': (54.995765, 11.881601),
#  'dk_mun_410': (55.431521000000004, 9.980076666666667),
#  'dk_mun_420': (55.249257, 10.168535),
#  'dk_mun_461': (55.395611111111116, 10.45324588888889),
#  'dk_mun_479': (55.07023, 10.57612),
#  'dk_mun_540': (54.923616, 9.785672),
#  'dk_mun_550': (55.053378, 8.836996),
#  'dk_mun_561': (55.507125, 8.57783),
#  'dk_mun_573': (55.5797085, 8.224657),
#  'dk_mun_575': (55.496068, 9.0819125),
#  'dk_mun_580': (55.027822, 9.351661499999999),
#  'dk_mun_607': (55.53232200000001, 9.638878250000001),
#  'dk_mun_621': (55.545798999999995, 9.514843999999998),
#  'dk_mun_630': (55.712496, 9.489462),
#  'dk_mun_657': (55.952752, 8.797765),
#  'dk_mun_661': (56.352613, 8.552965),
#  'dk_mun_665': (56.49206, 8.218299),
#  'dk_mun_671': (56.483126, 8.575286),
#  'dk_mun_706': (56.366732, 10.498075),
#  'dk_mun_707': (56.421722, 10.895915),
#  'dk_mun_730': (56.449552499999996, 10.0378765),
#  'dk_mun_746': (56.076675, 10.028266),
#  'dk_mun_751': (56.21375709999999, 10.226045300000001),
#  'dk_mun_756': (55.929066, 9.182534),
#  'dk_mun_760': (56.103189, 8.598395),
#  'dk_mun_787': (56.920664, 8.5579575),
#  'dk_mun_791': (56.46265328571428, 9.570112714285715),
#  'dk_mun_810': (57.267212, 9.979697),
#  'dk_mun_813': (57.372611000000006, 10.419545),
#  'dk_mun_820': (56.9178, 9.299185),
#  'dk_mun_846': (56.670914499999995, 9.886837),
#  'dk_mun_849': (57.114087, 9.502717),
#  'dk_mun_851': (57.050576466666676, 10.003492533333334),
#  'dk_mun_860': (57.450695, 10.026742)}

# %%
connection_points = {(m1, m2): (mun_points[m1], mun_points[m2]) for m1, m2 in municipality_connections}

# %%
import json
with open("connection_points.json", "w+") as fileobj:
    json.dump(list(connection_points.values()), fileobj)
