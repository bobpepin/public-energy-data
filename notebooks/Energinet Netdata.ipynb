# %%
import sys
if ".." not in sys.path:
    sys.path.append("..")
import openpyxl
from energydata import energinet

import importlib
energinet = importlib.reload(energinet)

# %%
descriptor = {"resource_id": "connectionpointsingrid"}
service = energinet.EnergiDataServiceDk(descriptor)

# %%
list(energinet.fetch_edh(descriptor, 1))
# Out:
# [{'help': 'https://api.energidataservice.dk/help_show?name=datastore_search',
#   'success': True,
#   'result': {'include_total': True,
#    'resource_id': '2feb8df3-d3c3-4586-a485-19782797cc45',
#    'fields': [{'type': 'int', 'id': '_id'},
#     {'info': {'notes': 'Abbreviation for stations in the electricity grid.'},
#      'type': 'text',
#      'id': 'ConnectionPointCode'},
#     {'info': {'notes': 'Long name for stations in the electricity grid.'},
#      'type': 'text',
#      'id': 'ConnectionPointName'},
#     {'info': {'notes': 'Each of the 98 Danish municipalities has a unique number, ranging from 101 Copenhagen to 860 Hjørring.'},
#      'type': 'text',
#      'id': 'MunicipalityNo'},
#     {'info': {'notes': 'Name of municipality  in Denmark'},
#      'type': 'text',
#      'id': 'Municipality'},
#     {'info': {'notes': 'Administrative regions in Denmark'},
#      'type': 'text',
#      'id': 'RegionName'},
#     {'info': {'notes': 'EPSG:4326'},
#      'type': 'float8',
#      'id': 'ConnectionPointLatitude'},
#     {'info': {'notes': 'EPSG:4326'},
#      'type': 'float8',
#      'id': 'ConnectionPointLongitude'},
#     {'info': {'notes': 'The netcompany area in which a connection point is placed'},
#      'type': 'text',
#      'id': 'NetCompanyName'}],
#    'records_format': 'lists',
#    'records': [[1044,
#      'ALMV',
#      'Alminde',
#      '621',
#      'Kolding',
#      'Syddanmark',
#      55.572477,
#      9.48877,
#      'TREFOR']],
#    'limit': 1,
#    'offset': 0,
#    '_links': {'start': '/datastore_search?resource_id=connectionpointsingrid&limit=1&records_format=lists',
#     'next': '/datastore_search?resource_id=connectionpointsingrid&limit=1&records_format=lists&offset=1'},
#    'total': 1136}},
#  {'help': 'https://api.energidataservice.dk/help_show?name=datastore_search',
#   'success': True,
#   'result': {'include_total': True,
#    'resource_id': '2feb8df3-d3c3-4586-a485-19782797cc45',
#    'fields': [{'type': 'int', 'id': '_id'},
#     {'info': {'notes': 'Abbreviation for stations in the electricity grid.'},
#      'type': 'text',
#      'id': 'ConnectionPointCode'},
#     {'info': {'notes': 'Long name for stations in the electricity grid.'},
#      'type': 'text',
#      'id': 'ConnectionPointName'},
#     {'info': {'notes': 'Each of the 98 Danish municipalities has a unique number, ranging from 101 Copenhagen to 860 Hjørring.'},
#      'type': 'text',
#      'id': 'MunicipalityNo'},
#     {'info': {'notes': 'Name of municipality  in Denmark'},
#      'type': 'text',
#      'id': 'Municipality'},
#     {'info': {'notes': 'Administrative regions in Denmark'},
#      'type': 'text',
#      'id': 'RegionName'},
#     {'info': {'notes': 'EPSG:4326'},
#      'type': 'float8',
#      'id': 'ConnectionPointLatitude'},
#     {'info': {'notes': 'EPSG:4326'},
#      'type': 'float8',
#      'id': 'ConnectionPointLongitude'},
#     {'info': {'notes': 'The netcompany area in which a connection point is placed'},
#      'type': 'text',
#      'id': 'NetCompanyName'}],
#    'records_format': 'lists',
#    'records': [[20,
#      'AMK',
#      'Amager koblingsstation',
#      '101',
#      'København',
#      'Hovedstaden',
#      55.641284,
#      12.609259,
#      'Radius Elnet']],
#    'limit': 1,
#    'offset': 1,
#    '_links': {'start': '/datastore_search?resource_id=connectionpointsingrid&limit=1&records_format=lists',
#     'next': '/datastore_search?resource_id=connectionpointsingrid&limit=1&records_format=lists&offset=2'},
#    'total': 1136}},
#  {'help': 'https://api.energidataservice.dk/help_show?name=datastore_search',
#   'success': True,
#   'result': {'include_total': True,
#    'resource_id': '2feb8df3-d3c3-4586-a485-19782797cc45',
#    'fields': [{'type': 'int', 'id': '_id'},
#     {'info': {'notes': 'Abbreviation for stations in the electricity grid.'},
#      'type': 'text',
#      'id': 'ConnectionPointCode'},
#     {'info': {'notes': 'Long name for stations in the electricity grid.'},
#      'type': 'text',
#      'id': 'ConnectionPointName'},
#     {'info': {'notes': 'Each of the 98 Danish municipalities has a unique number, ranging from 101 Copenhagen to 860 Hjørring.'},
#      'type': 'text',
#      'id': 'MunicipalityNo'},
#     {'info': {'notes': 'Name of municipality  in Denmark'},
#      'type': 'text',
#      'id': 'Municipality'},
#     {'info': {'notes': 'Administrative regions in Denmark'},
#      'type': 'text',
#      'id': 'RegionName'},
#     {'info': {'notes': 'EPSG:4326'},
#      'type': 'float8',
#      'id': 'ConnectionPointLatitude'},
#     {'info': {'notes': 'EPSG:4326'},
#      'type': 'float8',
#      'id': 'ConnectionPointLongitude'},
#     {'info': {'notes': 'The netcompany area in which a connection point is placed'},
#      'type': 'text',
#      'id': 'NetCompanyName'}],
#    'records_format': 'lists',
#    'records': [[22,
#      'AMV',
#      'Amagerværket',
#      '101',
#      'København',
#      'Hovedstaden',
#      55.685241,
#      12.624494,
#      'Radius Elnet']],
#    'limit': 1,
#    'offset': 2,
#    '_links': {'start': '/datastore_search?resource_id=connectionpointsingrid&limit=1&records_format=lists',
#     'prev': '/datastore_search?resource_id=connectionpointsingrid&limit=1&records_format=lists&offset=1',
#     'next': '/datastore_search?resource_id=connectionpointsingrid&limit=1&records_format=lists&offset=3'},
#    'total': 1136}},
#  {'help': 'https://api.energidataservice.dk/help_show?name=datastore_search',
#   'success': True,
#   'result': {'include_total': True,
#    'resource_id': '2feb8df3-d3c3-4586-a485-19782797cc45',
#    'fields': [{'type': 'int', 'id': '_id'},
#     {'info': {'notes': 'Abbreviation for stations in the electricity grid.'},
#      'type': 'text',
#      'id': 'ConnectionPointCode'},
#     {'info': {'notes': 'Long name for stations in the electricity grid.'},
#      'type': 'text',
#      'id': 'ConnectionPointName'},
#     {'info': {'notes': 'Each of the 98 Danish municipalities has a unique number, ranging from 101 Copenhagen to 860 Hjørring.'},
#      'type': 'text',
#      'id': 'MunicipalityNo'},
#     {'info': {'notes': 'Name of municipality  in Denmark'},
#      'type': 'text',
#      'id': 'Municipality'},
#     {'info': {'notes': 'Administrative regions in Denmark'},
#      'type': 'text',
#      'id': 'RegionName'},
#     {'info': {'notes': 'EPSG:4326'},
#      'type': 'float8',
#      'id': 'ConnectionPointLatitude'},
#     {'info': {'notes': 'EPSG:4326'},
#      'type': 'float8',
#      'id': 'ConnectionPointLongitude'},
#     {'info': {'notes': 'The netcompany area in which a connection point is placed'},
#      'type': 'text',
#      'id': 'NetCompanyName'}],
#    'records_format': 'lists',
#    'records': [[23,
#      'AND',
#      'Andst',
#      '575',
#      'Vejen',
#      'Syddanmark',
#      55.472217,
#      9.246799,
#      'Sydøstjyske Net A/S']],
#    'limit': 1,
#    'offset': 3,
#    '_links': {'start': '/datastore_search?resource_id=connectionpointsingrid&limit=1&records_format=lists',
#     'prev': '/datastore_search?resource_id=connectionpointsingrid&limit=1&records_format=lists&offset=2',
#     'next': '/datastore_search?resource_id=connectionpointsingrid&limit=1&records_format=lists&offset=4'},
#    'total': 1136}},
#  {'help': 'https://api.energidataservice.dk/help_show?name=datastore_search',
#   'success': True,
#   'result': {'include_total': True,
#    'resource_id': '2feb8df3-d3c3-4586-a485-19782797cc45',
#    'fields': [{'type': 'int', 'id': '_id'},
#     {'info': {'notes': 'Abbreviation for stations in the electricity grid.'},
#      'type': 'text',
#      'id': 'ConnectionPointCode'},
#     {'info': {'notes': 'Long name for stations in the electricity grid.'},
#      'type': 'text',
#      'id': 'ConnectionPointName'},
#     {'info': {'notes': 'Each of the 98 Danish municipalities has a unique number, ranging from 101 Copenhagen to 860 Hjørring.'},
#      'type': 'text',
#      'id': 'MunicipalityNo'},
#     {'info': {'notes': 'Name of municipality  in Denmark'},
#      'type': 'text',
#      'id': 'Municipality'},
#     {'info': {'notes': 'Administrative regions in Denmark'},
#      'type': 'text',
#      'id': 'RegionName'},
#     {'info': {'notes': 'EPSG:4326'},
#      'type': 'float8',
#      'id': 'ConnectionPointLatitude'},
#     {'info': {'notes': 'EPSG:4326'},
#      'type': 'float8',
#      'id': 'ConnectionPointLongitude'},
#     {'info': {'notes': 'The netcompany area in which a connection point is placed'},
#      'type': 'text',
#      'id': 'NetCompanyName'}],
#    'records_format': 'lists',
#    'records': [[1045,
#      'ANSV',
#      'Ansager',
#      '573',
#      'Varde',
#      'Syddanmark',
#      55.715322,
#      8.742647,
#      'N1']],
#    'limit': 1,
#    'offset': 4,
#    '_links': {'start': '/datastore_search?resource_id=connectionpointsingrid&limit=1&records_format=lists',
#     'prev': '/datastore_search?resource_id=connectionpointsingrid&limit=1&records_format=lists&offset=3',
#     'next': '/datastore_search?resource_id=connectionpointsingrid&limit=1&records_format=lists&offset=5'},
#    'total': 1136}},
#  {'help': 'https://api.energidataservice.dk/help_show?name=datastore_search',
#   'success': True,
#   'result': {'include_total': True,
#    'resource_id': '2feb8df3-d3c3-4586-a485-19782797cc45',
#    'fields': [{'type': 'int', 'id': '_id'},
#     {'info': {'notes': 'Abbreviation for stations in the electricity grid.'},
#      'type': 'text',
#      'id': 'ConnectionPointCode'},
#     {'info': {'notes': 'Long name for stations in the electricity grid.'},
#      'type': 'text',
#      'id': 'ConnectionPointName'},
#     {'info': {'notes': 'Each of the 98 Danish municipalities has a unique number, ranging from 101 Copenhagen to 860 Hjørring.'},
#      'type': 'text',
#      'id': 'MunicipalityNo'},
#     {'info': {'notes': 'Name of municipality  in Denmark'},
#      'type': 'text',
#      'id': 'Municipality'},
#     {'info': {'notes': 'Administrative regions in Denmark'},
#      'type': 'text',
#      'id': 'RegionName'},
#     {'info': {'notes': 'EPSG:4326'},
#      'type': 'float8',
#      'id': 'ConnectionPointLatitude'},
#     {'info': {'notes': 'EPSG:4326'},
#      'type': 'float8',
#      'id': 'ConnectionPointLongitude'},
#     {'info': {'notes': 'The netcompany area in which a connection point is placed'},
#      'type': 'text',
#      'id': 'NetCompanyName'}],
#    'records_format': 'lists',
#    'records': [[25,
#      'APH',
#      'Apholm',
#      '813',
#      'Frederikshavn',
#      'Nordjylland',
#      57.45701,
#      10.521611,
#      'Elinord']],
#    'limit': 1,
#    'offset': 5,
#    '_links': {'start': '/datastore_search?resource_id=connectionpointsingrid&limit=1&records_format=lists',
#     'prev': '/datastore_search?resource_id=connectionpointsingrid&limit=1&records_format=lists&offset=4',
#     'next': '/datastore_search?resource_id=connectionpointsingrid&limit=1&records_format=lists&offset=6'},
#    'total': 1136}}]

# %%
list(service.fetch_data())
# Out:
# [{'_id': 1044,
#   'ConnectionPointCode': 'ALMV',
#   'ConnectionPointName': 'Alminde',
#   'MunicipalityNo': '621',
#   'Municipality': 'Kolding',
#   'RegionName': 'Syddanmark',
#   'ConnectionPointLatitude': 55.572477,
#   'ConnectionPointLongitude': 9.48877,
#   'NetCompanyName': 'TREFOR',
#   'region_code': 'dk_mun_621'},
#  {'_id': 20,
#   'ConnectionPointCode': 'AMK',
#   'ConnectionPointName': 'Amager koblingsstation',
#   'MunicipalityNo': '101',
#   'Municipality': 'København',
#   'RegionName': 'Hovedstaden',
#   'ConnectionPointLatitude': 55.641284,
#   'ConnectionPointLongitude': 12.609259,
#   'NetCompanyName': 'Radius Elnet',
#   'region_code': 'dk_mun_101'},
#  {'_id': 22,
#   'ConnectionPointCode': 'AMV',
#   'ConnectionPointName': 'Amagerværket',
#   'MunicipalityNo': '101',
#   'Municipality': 'København',
#   'RegionName': 'Hovedstaden',
#   'ConnectionPointLatitude': 55.685241,
#   'ConnectionPointLongitude': 12.624494,
#   'NetCompanyName': 'Radius Elnet',
#   'region_code': 'dk_mun_101'},
#  {'_id': 23,
#   'ConnectionPointCode': 'AND',
#   'ConnectionPointName': 'Andst',
#   'MunicipalityNo': '575',
#   'Municipality': 'Vejen',
#   'RegionName': 'Syddanmark',
#   'ConnectionPointLatitude': 55.472217,
#   'ConnectionPointLongitude': 9.246799,
#   'NetCompanyName': 'Sydøstjyske Net A/S',
#   'region_code': 'dk_mun_575'},
#  {'_id': 1045,
#   'ConnectionPointCode': 'ANSV',
#   'ConnectionPointName': 'Ansager',
#   'MunicipalityNo': '573',
#   'Municipality': 'Varde',
#   'RegionName': 'Syddanmark',
#   'ConnectionPointLatitude': 55.715322,
#   'ConnectionPointLongitude': 8.742647,
#   'NetCompanyName': 'N1',
#   'region_code': 'dk_mun_573'},
#  {'_id': 25,
#   'ConnectionPointCode': 'APH',
#   'ConnectionPointName': 'Apholm',
#   'MunicipalityNo': '813',
#   'Municipality': 'Frederikshavn',
#   'RegionName': 'Nordjylland',
#   'ConnectionPointLatitude': 57.45701,
#   'ConnectionPointLongitude': 10.521611,
#   'NetCompanyName': 'Elinord',
#   'region_code': 'dk_mun_813'},
#  {'_id': 27,
#   'ConnectionPointCode': 'ASB',
#   'ConnectionPointName': 'Asserballe',
#   'MunicipalityNo': '540',
#   'Municipality': 'Sønderborg',
#   'RegionName': 'Syddanmark',
#   'ConnectionPointLatitude': 54.962133,
#   'ConnectionPointLongitude': 9.947739,
#   'NetCompanyName': 'N1',
#   'region_code': 'dk_mun_540'},
#  {'_id': 28,
#   'ConnectionPointCode': 'ASK',
#   'ConnectionPointName': 'Askov',
#   'MunicipalityNo': '575',
#   'Municipality': 'Vejen',
#   'RegionName': 'Syddanmark',
#   'ConnectionPointLatitude': 55.455879,
#   'ConnectionPointLongitude': 9.09718,
#   'NetCompanyName': 'N1',
#   'region_code': 'dk_mun_575'},
#  {'_id': 29,
#   'ConnectionPointCode': 'ASR',
#   'ConnectionPointName': 'Askær',
#   'MunicipalityNo': '657',
#   'Municipality': 'Herning',
#   'RegionName': 'Midtjylland',
#   'ConnectionPointLatitude': 55.929066,
#   'ConnectionPointLongitude': 9.182534,
#   'NetCompanyName': 'Sydøstjyske Net A/S',
#   'region_code': 'dk_mun_657'},
#  {'_id': 30,
#   'ConnectionPointCode': 'ASTV',
#   'ConnectionPointName': 'Agersted',
#   'MunicipalityNo': '810',
#   'Municipality': 'Brønderslev',
#   'RegionName': 'Nordjylland',
#   'ConnectionPointLatitude': 57.21253,
#   'ConnectionPointLongitude': 10.380956,
#   'NetCompanyName': 'Nord Energi',
#   'region_code': 'dk_mun_810'},
#  {'_id': 32,
#   'ConnectionPointCode': 'ASV',
#   'ConnectionPointName': 'Asnæsværket',
#   'MunicipalityNo': '326',
#   'Municipality': 'Kalundborg',
#   'RegionName': 'Sjælland',
#   'ConnectionPointLatitude': 55.662748,
#   'ConnectionPointLongitude': 11.069824,
#   'NetCompanyName': 'SEAS/NVE NET',
#   'region_code': 'dk_mun_326'},
#  {'_id': 1046,
#   'ConnectionPointCode': 'ASÅ',
#   'ConnectionPointName': 'Asaa',
#   'MunicipalityNo': '810',
#   'Municipality': 'Brønderslev',
#   'RegionName': 'Nordjylland',
#   'ConnectionPointLatitude': 57.168755,
#   'ConnectionPointLongitude': 10.408854,
#   'NetCompanyName': 'Nord Energi',
#   'region_code': 'dk_mun_810'},
#  {'_id': 34,
#   'ConnectionPointCode': 'AUG',
#   'ConnectionPointName': 'Augustenborg',
#   'MunicipalityNo': '540',
#   'Municipality': 'Sønderborg',
#   'RegionName': 'Syddanmark',
#   'ConnectionPointLatitude': 54.957666,
#   'ConnectionPointLongitude': 9.873597,
#   'NetCompanyName': 'N1',
#   'region_code': 'dk_mun_540'},
#  {'_id': 35,
#   'ConnectionPointCode': 'AUL',
#   'ConnectionPointName': 'Aulum',
#   'MunicipalityNo': '657',
#   'Municipality': 'Herning',
#   'RegionName': 'Midtjylland',
#   'ConnectionPointLatitude': 56.269924,
#   'ConnectionPointLongitude': 8.80802,
#   'NetCompanyName': 'N1',
#   'region_code': 'dk_mun_657'},
#  {'_id': 36,
#   'ConnectionPointCode': 'AUN',
#   'ConnectionPointName': 'Auning',
#   'MunicipalityNo': '706',
#   'Municipality': 'Syddjurs',
#   'RegionName': 'Midtjylland',
#   'ConnectionPointLatitude': 56.43204,
#   'ConnectionPointLongitude': 10.359509,
#   'NetCompanyName': 'N1',
#   'region_code': 'dk_mun_706'},
#  {'_id': 37,
#   'ConnectionPointCode': 'AVB',
#   'ConnectionPointName': 'Avnbøl',
#   'MunicipalityNo': '540',
#   'Municipality': 'Sønderborg',
#   'RegionName': 'Syddanmark',
#   'ConnectionPointLatitude': 54.95779,
#   'ConnectionPointLongitude': 9.621058,
#   'NetCompanyName': 'N1',
#   'region_code': 'dk_mun_540'},
#  {'_id': 38,
#   'ConnectionPointCode': 'AVE',
#   'ConnectionPointName': 'Avedøregård',
#   'MunicipalityNo': '153',
#   'Municipality': 'Brøndby',
#   'RegionName': 'Hovedstaden',
#   'ConnectionPointLatitude': 55.610761,
#   'ConnectionPointLongitude': 12.475582,
#   'NetCompanyName': 'Radius Elnet',
#   'region_code': 'dk_mun_153'},
#  {'_id': 39,
#   'ConnectionPointCode': 'AVV',
#   'ConnectionPointName': 'Avedøreværket',
#   'MunicipalityNo': '153',
#   'Municipality': 'Brøndby',
#   'RegionName': 'Hovedstaden',
#   'ConnectionPointLatitude': 55.604989,
#   'ConnectionPointLongitude': 12.480812,
#   'NetCompanyName': 'REGIONALE NET',
#   'region_code': 'dk_mun_153'},
#  {'_id': 41,
#   'ConnectionPointCode': 'BAG',
#   'ConnectionPointName': 'Bagsværdgård',
#   'MunicipalityNo': '159',
#   'Municipality': 'Gladsaxe',
#   'RegionName': 'Hovedstaden',
#   'ConnectionPointLatitude': 55.757222,
#   'ConnectionPointLongitude': 12.45374,
#   'NetCompanyName': 'Radius Elnet',
#   'region_code': 'dk_mun_159'},
#  {'_id': 42,
#   'ConnectionPointCode': 'BAJ',
#   'ConnectionPointName': 'Bajstrup',
#   'MunicipalityNo': '580',
#   'Municipality': 'Aabenraa',
#   'RegionName': 'Syddanmark',
#   'ConnectionPointLatitude': 54.900446,
#   'ConnectionPointLongitude': 9.304361,
#   'NetCompanyName': 'N1',
#   'region_code': 'dk_mun_580'},
#  {'_id': 1047,
#   'ConnectionPointCode': 'BAL***',
#   'ConnectionPointName': 'Ballerupgård',
#   'MunicipalityNo': '151',
#   'Municipality': 'Ballerup',
#   'RegionName': 'Hovedstaden',
#   'ConnectionPointLatitude': 55.723584,
#   'ConnectionPointLongitude': 12.368664,
#   'NetCompanyName': 'Radius Elnet',
#   'region_code': 'dk_mun_151'},
#  {'_id': 43,
#   'ConnectionPointCode': 'BALV',
#   'ConnectionPointName': 'Ballum',
#   'MunicipalityNo': '550',
#   'Municipality': 'Tønder',
#   'RegionName': 'Syddanmark',
#   'ConnectionPointLatitude': 55.05743,
#   'ConnectionPointLongitude': 8.69692,
#   'NetCompanyName': 'N1',
#   'region_code': 'dk_mun_550'},
#  {'_id': 45,
#   'ConnectionPointCode': 'BAR',
#   'ConnectionPointName': 'Barrit',
#   'MunicipalityNo': '766',
#   'Municipality': 'Hedensted',
#   'RegionName': 'Midtjylland',
#   'ConnectionPointLatitude': 55.72334,
#   'ConnectionPointLongitude': 9.89668,
#   'NetCompanyName': 'Konstant Syd',
#   'region_code': 'dk_mun_766'},
#  {'_id': 46,
#   'ConnectionPointCode': 'BAS',
#   'ConnectionPointName': 'Basballe',
#   'MunicipalityNo': '706',
#   'Municipality': 'Syddjurs',
#   'RegionName': 'Midtjylland',
#   'ConnectionPointLatitude': 56.247095,
#   'ConnectionPointLongitude': 10.545989,
#   'NetCompanyName': 'Konstant Nord',
#   'region_code': 'dk_mun_706'},
#  {'_id': 48,
#   'ConnectionPointCode': 'BBJ',
#   'ConnectionPointName': 'Borbjerg',
#   'MunicipalityNo': '657',
#   'Municipality': 'Herning',
#   'RegionName': 'Midtjylland',
#   'ConnectionPointLatitude': 56.40942,
#   'ConnectionPointLongitude': 8.745552,
#   'NetCompanyName': 'NOE Net A/S',
#   'region_code': 'dk_mun_657'},
#  {'_id': 49,
#   'ConnectionPointCode': 'BBR',
#   'ConnectionPointName': 'Bredebro',
#   'MunicipalityNo': '550',
#   'Municipality': 'Tønder',
#   'RegionName': 'Syddanmark',
#   'ConnectionPointLatitude': 55.053378,
#   'ConnectionPointLongitude': 8.836996,
#   'NetCompanyName': 'N1',
#   'region_code': 'dk_mun_550'},
#  {'_id': 50,
#   'ConnectionPointCode': 'BBY',
#   'ConnectionPointName': 'Brandsby',
#   'MunicipalityNo': '480',
#   'Municipality': 'Nordfyn',
#   'RegionName': 'Syddanmark',
#   'ConnectionPointLatitude': 55.527329,
#   'ConnectionPointLongitude': 10.367397,
#   'NetCompanyName': 'VORES ELNET A/S',
#   'region_code': 'dk_mun_480'},
#  {'_id': 51,
#   'ConnectionPointCode': 'BDE',
#   'ConnectionPointName': 'Brande',
#   'MunicipalityNo': '657',
#   'Municipality': 'Herning',
#   'RegionName': 'Midtjylland',
#   'ConnectionPointLatitude': 55.950106,
#   'ConnectionPointLongitude': 9.13248,
#   'NetCompanyName': 'RAH net',
#   'region_code': 'dk_mun_657'},
#  {'_id': 52,
#   'ConnectionPointCode': 'BDK',
#   'ConnectionPointName': 'Bredkær',
#   'MunicipalityNo': '860',
#   'Municipality': 'Hjørring',
#   'RegionName': 'Nordjylland',
#   'ConnectionPointLatitude': 57.450695,
#   'ConnectionPointLongitude': 10.026742,
#   'NetCompanyName': 'Nord Energi',
#   'region_code': 'dk_mun_860'},
#  {'_id': 53,
#   'ConnectionPointCode': 'BDR',
#   'ConnectionPointName': 'Bramdrup',
#   'MunicipalityNo': '621',
#   'Municipality': 'Kolding',
#   'RegionName': 'Syddanmark',
#   'ConnectionPointLatitude': 55.510641,
#   'ConnectionPointLongitude': 9.462136,
#   'NetCompanyName': 'TREFOR',
#   'region_code': 'dk_mun_621'},
#  {'_id': 55,
#   'ConnectionPointCode': 'BDV',
#   'ConnectionPointName': 'Bredstrupvej',
#   'MunicipalityNo': '607',
#   'Municipality': 'Fredericia',
#   'RegionName': 'Syddanmark',
#   'ConnectionPointLatitude': 55.570779,
#   'ConnectionPointLongitude': 9.709639,
#   'NetCompanyName': 'TREFOR',
#   'region_code': 'dk_mun_607'},
#  {'_id': 56,
#   'ConnectionPointCode': 'BED',
#   'ConnectionPointName': 'Bedsted',
#   'MunicipalityNo': '787',
#   'Municipality': 'Thisted',
#   'RegionName': 'Nordjylland',
#   'ConnectionPointLatitude': 56.810406,
#   'ConnectionPointLongitude': 8.415304,
#   'NetCompanyName': 'Vestjyske Net 60 kV A/S',
#   'region_code': 'dk_mun_787'},
#  {'_id': 57,
#   'ConnectionPointCode': 'BEG',
#   'ConnectionPointName': 'Begtrup',
#   'MunicipalityNo': '706',
#   'Municipality': 'Syddjurs',
#   'RegionName': 'Midtjylland',
#   'ConnectionPointLatitude': 56.18787,
#   'ConnectionPointLongitude': 10.5192,
#   'NetCompanyName': 'Konstant Nord',
#   'region_code': 'dk_mun_706'},
#  {'_id': 1048,
#   'ConnectionPointCode': 'BEL**',
#   'ConnectionPointName': 'Bellahøjkbst',
#   'MunicipalityNo': '101',
#   'Municipality': 'København',
#   'RegionName': 'Hovedstaden',
#   'ConnectionPointLatitude': 55.705109,
#   'ConnectionPointLongitude': 12.519474,
#   'NetCompanyName': 'Radius Elnet',
#   'region_code': 'dk_mun_101'},
#  {'_id': 58,
#   'ConnectionPointCode': 'BELV',
#   'ConnectionPointName': 'Bellinge',
#   'MunicipalityNo': '461',
#   'Municipality': 'Odense',
#   'RegionName': 'Syddanmark',
#   'ConnectionPointLatitude': 55.32802,
#   'ConnectionPointLongitude': 10.28828,
#   'NetCompanyName': 'VORES ELNET A/S',
#   'region_code': 'dk_mun_461'},
#  {'_id': 60,
#   'ConnectionPointCode': 'BER',
#   'ConnectionPointName': 'Beder',
#   'MunicipalityNo': '727',
#   'Municipality': 'Odder',
#   'RegionName': 'Midtjylland',
#   'ConnectionPointLatitude': 56.049982,
#   'ConnectionPointLongitude': 10.193351,
#   'NetCompanyName': 'Dinel',
#   'region_code': 'dk_mun_727'},
#  {'_id': 61,
#   'ConnectionPointCode': 'BEV',
#   'ConnectionPointName': 'Bevtoft',
#   'MunicipalityNo': '510',
#   'Municipality': 'Haderslev',
#   'RegionName': 'Syddanmark',
#   'ConnectionPointLatitude': 55.194146,
#   'ConnectionPointLongitude': 9.20712,
#   'NetCompanyName': 'N1',
#   'region_code': 'dk_mun_510'},
#  {'_id': 1049,
#   'ConnectionPointCode': 'BGÅ',
#   'ConnectionPointName': 'Brogård',
#   'MunicipalityNo': '621',
#   'Municipality': 'Kolding',
#   'RegionName': 'Syddanmark',
#   'ConnectionPointLatitude': 55.506816,
#   'ConnectionPointLongitude': 9.446913,
#   'NetCompanyName': 'TREFOR',
#   'region_code': 'dk_mun_621'},
#  {'_id': 63,
#   'ConnectionPointCode': 'BHG',
#   'ConnectionPointName': 'Boens Hage',
#   'MunicipalityNo': '813',
#   'Municipality': 'Frederikshavn',
#   'RegionName': 'Nordjylland',
#   'ConnectionPointLatitude': 57.434721,
#   'ConnectionPointLongitude': 10.538189,
#   'NetCompanyName': 'Elinord',
#   'region_code': 'dk_mun_813'},
#  {'_id': 64,
#   'ConnectionPointCode': 'BHM',
#   'ConnectionPointName': 'Broholm',
#   'MunicipalityNo': '420',
#   'Municipality': 'Assens',
#   'RegionName': 'Syddanmark',
#   'ConnectionPointLatitude': 55.356063,
#   'ConnectionPointLongitude': 10.201142,
#   'NetCompanyName': 'VORES ELNET A/S',
#   'region_code': 'dk_mun_420'},
#  {'_id': 65,
#   'ConnectionPointCode': 'BIB',
#   'ConnectionPointName': 'Bindeballe',
#   'MunicipalityNo': '630',
#   'Municipality': 'Vejle',
#   'RegionName': 'Syddanmark',
#   'ConnectionPointLatitude': 55.67594,
#   'ConnectionPointLongitude': 9.24662,
#   'NetCompanyName': 'N1',
#   'region_code': 'dk_mun_630'},
#  {'_id': 66,
#   'ConnectionPointCode': 'BID',
#   'ConnectionPointName': 'Billund',
#   'MunicipalityNo': '530',
#   'Municipality': 'Billund',
#   'RegionName': 'Syddanmark',
#   'ConnectionPointLatitude': 55.719249,
#   'ConnectionPointLongitude': 9.111525,
#   'NetCompanyName': 'N1',
#   'region_code': 'dk_mun_530'},
#  {'_id': 67,
#   'ConnectionPointCode': 'BIL',
#   'ConnectionPointName': 'Bilstrup',
#   'MunicipalityNo': '661',
#   'Municipality': 'Holstebro',
#   'RegionName': 'Midtjylland',
#   'ConnectionPointLatitude': 56.533883,
#   'ConnectionPointLongitude': 9.004559,
#   'NetCompanyName': 'N1',
#   'region_code': 'dk_mun_661'},
#  {'_id': 68,
#   'ConnectionPointCode': 'BIN',
#   'ConnectionPointName': 'Bindslev',
#   'MunicipalityNo': '813',
#   'Municipality': 'Frederikshavn',
#   'RegionName': 'Nordjylland',
#   'ConnectionPointLatitude': 57.552616,
#   'ConnectionPointLongitude': 10.19058,
#   'NetCompanyName': 'Nord Energi',
#   'region_code': 'dk_mun_813'},
#  {'_id': 69,
#   'ConnectionPointCode': 'BIO',
#   'ConnectionPointName': 'Billund Nord',
#   'MunicipalityNo': '530',
#   'Municipality': 'Billund',
#   'RegionName': 'Syddanmark',
#   'ConnectionPointLatitude': 55.724359,
#   'ConnectionPointLongitude': 9.14229,
#   'NetCompanyName': 'N1',
#   'region_code': 'dk_mun_530'},
#  {'_id': 70,
#   'ConnectionPointCode': 'BIRV',
#   'ConnectionPointName': 'Birkelse',
#   'MunicipalityNo': '810',
#   'Municipality': 'Brønderslev',
#   'RegionName': 'Nordjylland',
#   'ConnectionPointLatitude': 57.14337,
#   'ConnectionPointLongitude': 9.67849,
#   'NetCompanyName': 'N1',
#   'region_code': 'dk_mun_810'},
#  {'_id': 71,
#   'ConnectionPointCode': 'BIRØ',
#   'ConnectionPointName': 'Birkerødgård',
#   'MunicipalityNo': '190',
#   'Municipality': 'Furesø',
#   'RegionName': 'Hovedstaden',
#   'ConnectionPointLatitude': 55.838903,
#   'ConnectionPointLongitude': 12.405372,
#   'NetCompanyName': 'Radius Elnet',
#   'region_code': 'dk_mun_190'},
#  {'_id': 1050,
#   'ConnectionPointCode': 'BISV',
#   'ConnectionPointName': 'Billund Syd',
#   'MunicipalityNo': '530',
#   'Municipality': 'Billund',
#   'RegionName': 'Syddanmark',
#   'ConnectionPointLatitude': 55.718611,
#   'ConnectionPointLongitude': 9.132061,
#   'NetCompanyName': 'N1',
#   'region_code': 'dk_mun_530'},
#  {'_id': 73,
#   'ConnectionPointCode': 'BJB',
#   'ConnectionPointName': 'Bjerringbro',
#   'MunicipalityNo': '710',
#   'Municipality': 'Favrskov',
#   'RegionName': 'Midtjylland',
#   'ConnectionPointLatitude': 56.383825,
#   'ConnectionPointLongitude': 9.671108,
#   'NetCompanyName': 'N1',
#   'region_code': 'dk_mun_710'},
#  {'_id': 74,
#   'ConnectionPointCode': 'BJEV',
#   'ConnectionPointName': 'Bjerre',
#   'MunicipalityNo': '615',
#   'Municipality': 'Horsens',
#   'RegionName': 'Midtjylland',
#   'ConnectionPointLatitude': 55.77997,
#   'ConnectionPointLongitude': 9.84898,
#   'NetCompanyName': 'Konstant Syd',
#   'region_code': 'dk_mun_615'},
#  {'_id': 75,
#   'ConnectionPointCode': 'BJH',
#   'ConnectionPointName': 'Bjørnholt',
#   'MunicipalityNo': '740',
#   'Municipality': 'Silkeborg',
#   'RegionName': 'Midtjylland',
#   'ConnectionPointLatitude': 56.20447,
#   'ConnectionPointLongitude': 9.560741,
#   'NetCompanyName': 'N1',
#   'region_code': 'dk_mun_740'},
#  {'_id': 76,
#   'ConnectionPointCode': 'BJS',
#   'ConnectionPointName': 'Bjæverskov',
#   'MunicipalityNo': '259',
#   'Municipality': 'Køge',
#   'RegionName': 'Sjælland',
#   'ConnectionPointLatitude': 55.45053,
#   'ConnectionPointLongitude': 12.00791,
#   'NetCompanyName': 'SEAS/NVE TRANSMISSION',
#   'region_code': 'dk_mun_259'},
#  {'_id': 78,
#   'ConnectionPointCode': 'BKT',
#   'ConnectionPointName': 'Birketved',
#   'MunicipalityNo': '440',
#   'Municipality': 'Kerteminde',
#   'RegionName': 'Syddanmark',
#   'ConnectionPointLatitude': 55.395277,
#   'ConnectionPointLongitude': 10.551558,
#   'NetCompanyName': 'RAVDEX',
#   'region_code': 'dk_mun_440'},
#  {'_id': 79,
#   'ConnectionPointCode': 'BLA',
#   'ConnectionPointName': 'Blangslev',
#   'MunicipalityNo': '370',
#   'Municipality': 'Næstved',
#   'RegionName': 'Sjælland',
#   'ConnectionPointLatitude': 55.167546,
#   'ConnectionPointLongitude': 11.901284,
#   'NetCompanyName': 'Cerius',
#   'region_code': 'dk_mun_370'},
#  {'_id': 80,
#   'ConnectionPointCode': 'BLD',
#   'ConnectionPointName': 'Boldrup',
#   'MunicipalityNo': '840',
#   'Municipality': 'Rebild',
#   'RegionName': 'Nordjylland',
#   'ConnectionPointLatitude': 56.690286,
#   'ConnectionPointLongitude': 9.644041,
#   'NetCompanyName': 'N1',
#   'region_code': 'dk_mun_840'},
#  {'_id': 81,
#   'ConnectionPointCode': 'BLI',
#   'ConnectionPointName': 'Blirup',
#   'MunicipalityNo': '615',
#   'Municipality': 'Horsens',
#   'RegionName': 'Midtjylland',
#   'ConnectionPointLatitude': 55.886823,
#   'ConnectionPointLongitude': 9.933627,
#   'NetCompanyName': 'N1',
#   'region_code': 'dk_mun_615'},
#  {'_id': 82,
#   'ConnectionPointCode': 'BLL',
#   'ConnectionPointName': 'Balling',
#   'MunicipalityNo': '779',
#   'Municipality': 'Skive',
#   'RegionName': 'Midtjylland',
#   'ConnectionPointLatitude': 56.613869,
#   'ConnectionPointLongitude': 8.867874,
#   'NetCompanyName': 'N1',
#   'region_code': 'dk_mun_779'},
#  {'_id': 83,
#   'ConnectionPointCode': 'BLN',
#   'ConnectionPointName': 'Blans',
#   'MunicipalityNo': '540',
#   'Municipality': 'Sønderborg',
#   'RegionName': 'Syddanmark',
#   'ConnectionPointLatitude': 54.981313,
#   'ConnectionPointLongitude': 9.654621,
#   'NetCompanyName': 'N1',
#   'region_code': 'dk_mun_540'},
#  {'_id': 85,
#   'ConnectionPointCode': 'BLS',
#   'ConnectionPointName': 'Bolderslev',
#   'MunicipalityNo': '580',
#   'Municipality': 'Aabenraa',
#   'RegionName': 'Syddanmark',
#   'ConnectionPointLatitude': 54.986867,
#   'ConnectionPointLongitude': 9.284261,
#   'NetCompanyName': 'N1',
#   'region_code': 'dk_mun_580'},
#  {'_id': 86,
#   'ConnectionPointCode': 'BLU',
#   'ConnectionPointName': 'Barslund',
#   'MunicipalityNo': '657',
#   'Municipality': 'Herning',
#   'RegionName': 'Midtjylland',
#   'ConnectionPointLatitude': 55.898882,
#   'ConnectionPointLongitude': 8.988415,
#   'NetCompanyName': 'RAH net',
#   'region_code': 'dk_mun_657'},
#  {'_id': 1051,
#   'ConnectionPointCode': 'BLØ',
#   'ConnectionPointName': 'Barløse',
#   'MunicipalityNo': '420',
#   'Municipality': 'Assens',
#   'RegionName': 'Syddanmark',
#   'ConnectionPointLatitude': 55.33118,
#   'ConnectionPointLongitude': 9.975338,
#   'NetCompanyName': 'VORES ELNET A/S',
#   'region_code': 'dk_mun_420'},
#  {'_id': 88,
#   'ConnectionPointCode': 'BMB',
#   'ConnectionPointName': 'Bækmarksbro',
#   'MunicipalityNo': '665',
#   'Municipality': 'Lemvig',
#   'RegionName': 'Midtjylland',
#   'ConnectionPointLatitude': 56.408207,
#   'ConnectionPointLongitude': 8.279649,
#   'NetCompanyName': 'NOE Net A/S',
#   'region_code': 'dk_mun_665'},
#  {'_id': 90,
#   'ConnectionPointCode': 'BMØ',
#   'ConnectionPointName': 'Bramminge Øst',
#   'MunicipalityNo': '561',
#   'Municipality': 'Esbjerg',
#   'RegionName': 'Syddanmark',
#   'ConnectionPointLatitude': 55.470195,
#   'ConnectionPointLongitude': 8.725633,
#   'NetCompanyName': 'N1',
#   'region_code': 'dk_mun_561'},
#  {'_id': 91,
#   'ConnectionPointCode': 'BNT',
#   'ConnectionPointName': 'Bønnet',
#   'MunicipalityNo': '360',
#   'Municipality': 'Lolland',
#   'RegionName': 'Sjælland',
#   'ConnectionPointLatitude': 54.903148,
#   'ConnectionPointLongitude': 11.292241,
#   'NetCompanyName': 'Cerius',
#   'region_code': 'dk_mun_360'},
#  {'_id': 1052,
#   'ConnectionPointCode': 'BODØ',
#   'ConnectionPointName': 'Bodilsker',
#   'MunicipalityNo': '400',
#   'Municipality': 'Bornholm',
#   'RegionName': 'Hovedstaden',
#   'ConnectionPointLatitude': 55.063225,
#   'ConnectionPointLongitude': 15.066096,
#   'NetCompanyName': 'Trefor El-Net Øst',
#   'region_code': 'dk_mun_400'},
#  {'_id': 93,
#   'ConnectionPointCode': 'BOG',
#   'ConnectionPointName': 'Bogense',
#   'MunicipalityNo': '480',
#   'Municipality': 'Nordfyn',
#   'RegionName': 'Syddanmark',
#   'ConnectionPointLatitude': 55.545226,
#   'ConnectionPointLongitude': 10.079238,
#   'NetCompanyName': 'VORES ELNET A/S',
#   'region_code': 'dk_mun_480'},
#  {'_id': 94,
#   'ConnectionPointCode': 'BOR',
#   'ConnectionPointName': 'Borup',
#   'MunicipalityNo': '219',
#   'Municipality': 'Hillerød',
#   'RegionName': 'Hovedstaden',
#   'ConnectionPointLatitude': 55.908136,
#   'ConnectionPointLongitude': 12.178718,
#   'NetCompanyName': 'Radius Elnet',
#   'region_code': 'dk_mun_219'},
#  {'_id': 95,
#   'ConnectionPointCode': 'BOU',
#   'ConnectionPointName': 'Bouet',
#   'MunicipalityNo': '851',
#   'Municipality': 'Aalborg',
#   'RegionName': 'Nordjylland',
#   'ConnectionPointLatitude': 57.085768,
#   'ConnectionPointLongitude': 9.96507,
#   'NetCompanyName': 'Nord Energi',
#   'region_code': 'dk_mun_851'},
#  {'_id': 97,
#   'ConnectionPointCode': 'BRAV',
#   'ConnectionPointName': 'Brabrand',
#   'MunicipalityNo': '751',
#   'Municipality': 'Aarhus',
#   'RegionName': 'Midtjylland',
#   'ConnectionPointLatitude': 56.15544,
#   'ConnectionPointLongitude': 10.13816,
#   'NetCompanyName': 'Dinel',
#   'region_code': 'dk_mun_751'},
#  {'_id': 98,
#   'ConnectionPointCode': 'BRD',
#   'ConnectionPointName': 'Brædstrup',
#   'MunicipalityNo': '615',
#   'Municipality': 'Horsens',
#   'RegionName': 'Midtjylland',
#   'ConnectionPointLatitude': 55.981686,
#   'ConnectionPointLongitude': 9.591076,
#   'NetCompanyName': 'N1',
#   'region_code': 'dk_mun_615'},
#  {'_id': 99,
#   'ConnectionPointCode': 'BRE',
#   'ConnectionPointName': 'Bregninge',
#   'MunicipalityNo': '479',
#   'Municipality': 'Svendborg',
#   'RegionName': 'Syddanmark',
#   'ConnectionPointLatitude': 55.01842,
#   'ConnectionPointLongitude': 10.59745,
#   'NetCompanyName': 'FLOW ELNET A/S',
#   'region_code': 'dk_mun_479'},
#  {'_id': 100,
#   'ConnectionPointCode': 'BRG',
#   'ConnectionPointName': 'Broager Nord',
#   'MunicipalityNo': '540',
#   'Municipality': 'Sønderborg',
#   'RegionName': 'Syddanmark',
#   'ConnectionPointLatitude': 54.906756,
#   'ConnectionPointLongitude': 9.675357,
#   'NetCompanyName': 'N1',
#   'region_code': 'dk_mun_540'},
#  {'_id': 101,
#   'ConnectionPointCode': 'BRL',
#   'ConnectionPointName': 'Bredlund',
#   'MunicipalityNo': '740',
#   'Municipality': 'Silkeborg',
#   'RegionName': 'Midtjylland',
#   'ConnectionPointLatitude': 56.037549,
#   'ConnectionPointLongitude': 9.359918,
#   'NetCompanyName': 'N1',
#   'region_code': 'dk_mun_740'},
#  {'_id': 102,
#   'ConnectionPointCode': 'BRM',
#   'ConnectionPointName': 'Bramminge',
#   'MunicipalityNo': '561',
#   'Municipality': 'Esbjerg',
#   'RegionName': 'Syddanmark',
#   'ConnectionPointLatitude': 55.481544,
#   'ConnectionPointLongitude': 8.656908,
#   'NetCompanyName': 'N1',
#   'region_code': 'dk_mun_561'},
#  {'_id': 103,
#   'ConnectionPointCode': 'BRN',
#   'ConnectionPointName': 'Birn',
#   'MunicipalityNo': '657',
#   'Municipality': 'Herning',
#   'RegionName': 'Midtjylland',
#   'ConnectionPointLatitude': 56.367335,
#   'ConnectionPointLongitude': 8.576465,
#   'NetCompanyName': 'NOE Net A/S',
#   'region_code': 'dk_mun_657'},
#  {'_id': 104,
#   'ConnectionPointCode': 'BRP',
#   'ConnectionPointName': 'Brandstrup',
#   'MunicipalityNo': '740',
#   'Municipality': 'Silkeborg',
#   'RegionName': 'Midtjylland',
#   'ConnectionPointLatitude': 56.355988,
#   'ConnectionPointLongitude': 9.499246,
#   'NetCompanyName': 'N1',
#   'region_code': 'dk_mun_740'},
#  {'_id': 105,
#   'ConnectionPointCode': 'BRS',
#   'ConnectionPointName': 'Brøns',
#   'MunicipalityNo': '550',
#   'Municipality': 'Tønder',
#   'RegionName': 'Syddanmark',
#   'ConnectionPointLatitude': 55.198128,
#   'ConnectionPointLongitude': 8.727395,
#   'NetCompanyName': 'N1',
#   'region_code': 'dk_mun_550'},
#  {'_id': 107,
#   'ConnectionPointCode': 'BRV',
#   'ConnectionPointName': 'Brovst',
#   'MunicipalityNo': '849',
#   'Municipality': 'Jammerbugt',
#   'RegionName': 'Nordjylland',
#   'ConnectionPointLatitude': 57.095861,
#   'ConnectionPointLongitude': 9.501704,
#   'NetCompanyName': 'N1',
#   'region_code': 'dk_mun_849'},
#  {'_id': 1053,
#   'ConnectionPointCode': 'BRY*',
#   'ConnectionPointName': 'Brøndbygård',
#   'MunicipalityNo': '153',
#   'Municipality': 'Brøndby',
#   'RegionName': 'Hovedstaden',
#   'ConnectionPointLatitude': 55.631155,
#   'ConnectionPointLongitude': 12.407886,
#   'NetCompanyName': 'Radius Elnet',
#   'region_code': 'dk_mun_153'},
#  {'_id': 108,
#   'ConnectionPointCode': 'BRYV',
#   'ConnectionPointName': 'Bryrup',
#   'MunicipalityNo': '615',
#   'Municipality': 'Horsens',
#   'RegionName': 'Midtjylland',
#   'ConnectionPointLatitude': 56.01916,
#   'ConnectionPointLongitude': 9.57011,
#   'NetCompanyName': 'N1',
#   'region_code': 'dk_mun_615'},
#  {'_id': 110,
#   'ConnectionPointCode': 'BRÆ',
#   'ConnectionPointName': 'Brænderigården',
#   'MunicipalityNo': '849',
#   'Municipality': 'Jammerbugt',
#   'RegionName': 'Nordjylland',
#   'ConnectionPointLatitude': 57.086215,
#   'ConnectionPointLongitude': 9.244322,
#   'NetCompanyName': 'N1',
#   'region_code': 'dk_mun_849'},
#  {'_id': 111,
#   'ConnectionPointCode': 'BRØ',
#   'ConnectionPointName': 'Brørup',
#   'MunicipalityNo': '575',
#   'Municipality': 'Vejen',
#   'RegionName': 'Syddanmark',
#   'ConnectionPointLatitude': 55.484473,
#   'ConnectionPointLongitude': 9.001671,
#   'NetCompanyName': 'N1',
#   'region_code': 'dk_mun_575'},
#  {'_id': 112,
#   'ConnectionPointCode': 'BSG',
#   'ConnectionPointName': 'Brendstrupgårdsvej',
#   'MunicipalityNo': '751',
#   'Municipality': 'Aarhus',
#   'RegionName': 'Midtjylland',
#   'ConnectionPointLatitude': 56.19175,
#   'ConnectionPointLongitude': 10.1815,
#   'NetCompanyName': 'Konstant Nord',
#   'region_code': 'dk_mun_751'},
#  {'_id': 113,
#   'ConnectionPointCode': 'BSY',
#   'ConnectionPointName': 'Broager Syd',
#   'MunicipalityNo': '540',
#   'Municipality': 'Sønderborg',
#   'RegionName': 'Syddanmark',
#   'ConnectionPointLatitude': 54.887793,
#   'ConnectionPointLongitude': 9.687074,
#   'NetCompanyName': 'N1',
#   'region_code': 'dk_mun_540'},
#  {'_id': 114,
#   'ConnectionPointCode': 'BTØ',
#   'ConnectionPointName': 'Bøtø',
#   'MunicipalityNo': '376',
#   'Municipality': 'Guldborgsund',
#   'RegionName': 'Sjælland',
#   'ConnectionPointLatitude': 54.678517,
#   'ConnectionPointLongitude': 11.936455,
#   'NetCompanyName': 'Cerius',
#   'region_code': 'dk_mun_376'},
#  {'_id': 115,
#   'ConnectionPointCode': 'BUL',
#   'ConnectionPointName': 'Bullerup',
#   'MunicipalityNo': '461',
#   'Municipality': 'Odense',
#   'RegionName': 'Syddanmark',
#   'ConnectionPointLatitude': 55.430828,
#   'ConnectionPointLongitude': 10.478242,
#   'NetCompanyName': 'RAVDEX',
#   'region_code': 'dk_mun_461'},
#  {'_id': 1054,
#   'ConnectionPointCode': 'BUPØ',
#   'ConnectionPointName': 'Balstrup',
#   'MunicipalityNo': '329',
#   'Municipality': 'Ringsted',
#   'RegionName': 'Sjælland',
#   'ConnectionPointLatitude': 55.435184,
#   'ConnectionPointLongitude': 11.80874,
#   'NetCompanyName': 'Cerius',
#   'region_code': 'dk_mun_329'},
#  {'_id': 117,
#   'ConnectionPointCode': 'BVD',
#   'ConnectionPointName': 'Bredevad',
#   'MunicipalityNo': '580',
#   'Municipality': 'Aabenraa',
#   'RegionName': 'Syddanmark',
#   'ConnectionPointLatitude': 54.978577,
#   'ConnectionPointLongitude': 9.141066,
#   'NetCompanyName': 'N1',
#   'region_code': 'dk_mun_580'},
#  {'_id': 118,
#   'ConnectionPointCode': 'BYG',
#   'ConnectionPointName': 'Bygholm',
#   'MunicipalityNo': '615',
#   'Municipality': 'Horsens',
#   'RegionName': 'Midtjylland',
#   'ConnectionPointLatitude': 55.86179,
#   'ConnectionPointLongitude': 9.82403,
#   'NetCompanyName': 'Konstant Syd',
#   'region_code': 'dk_mun_615'},
#  {'_id': 119,
#   'ConnectionPointCode': 'BYN',
#   'ConnectionPointName': 'Byen, Aarhus',
#   'MunicipalityNo': '751',
#   'Municipality': 'Aarhus',
#   'RegionName': 'Midtjylland',
#   'ConnectionPointLatitude': 56.15407,
#   'ConnectionPointLongitude': 10.18114,
#   'NetCompanyName': 'Konstant Nord',
#   'region_code': 'dk_mun_751'},
#  {'_id': 1055,
#   'ConnectionPointCode': 'BÆK',
#   'ConnectionPointName': 'Bække',
#   'MunicipalityNo': '575',
#   'Municipality': 'Vejen',
#   'RegionName': 'Syddanmark',
#   'ConnectionPointLatitude': 55.560328,
#   'ConnectionPointLongitude': 9.153242,
#   'NetCompanyName': 'TREFOR',
#   'region_code': 'dk_mun_575'},
#  {'_id': 120,
#   'ConnectionPointCode': 'BØR',
#   'ConnectionPointName': 'Børglum',
#   'MunicipalityNo': '810',
#   'Municipality': 'Brønderslev',
#   'RegionName': 'Nordjylland',
#   'ConnectionPointLatitude': 57.371092,
#   'ConnectionPointLongitude': 9.817293,
#   'NetCompanyName': 'N1',
#   'region_code': 'dk_mun_810'},
#  {'_id': 121,
#   'ConnectionPointCode': 'CFD',
#   'ConnectionPointName': 'Christiansfeld',
#   'MunicipalityNo': '510',
#   'Municipality': 'Haderslev',
#   'RegionName': 'Syddanmark',
#   'ConnectionPointLatitude': 55.357559,
#   'ConnectionPointLongitude': 9.473074,
#   'NetCompanyName': 'N1',
#   'region_code': 'dk_mun_510'},
#  {'_id': 122,
#   'ConnectionPointCode': 'CHB',
#   'ConnectionPointName': 'Christiansbjerg',
#   'MunicipalityNo': '751',
#   'Municipality': 'Aarhus',
#   'RegionName': 'Midtjylland',
#   'ConnectionPointLatitude': 56.19175,
#   'ConnectionPointLongitude': 10.18695,
#   'NetCompanyName': 'Konstant Nord',
#   'region_code': 'dk_mun_751'},
#  {'_id': 123,
#   'ConnectionPointCode': 'CHH',
#   'ConnectionPointName': 'Christianshede',
#   'MunicipalityNo': '740',
#   'Municipality': 'Silkeborg',
#   'RegionName': 'Midtjylland',
#   'ConnectionPointLatitude': 56.097259,
#   'ConnectionPointLongitude': 9.400899,
#   'NetCompanyName': 'N1',
#   'region_code': 'dk_mun_740'},
#  {'_id': 124,
#   'ConnectionPointCode': 'DAG',
#   'ConnectionPointName': 'Dageløkkegård',
#   'MunicipalityNo': '210',
#   'Municipality': 'Fredensborg',
#   'RegionName': 'Hovedstaden',
#   'ConnectionPointLatitude': 55.957353,
#   'ConnectionPointLongitude': 12.494292,
#   'NetCompanyName': 'Radius Elnet',
#   'region_code': 'dk_mun_210'},
#  {'_id': 126,
#   'ConnectionPointCode': 'DALV',
#   'ConnectionPointName': 'Dallerup',
#   'MunicipalityNo': '710',
#   'Municipality': 'Favrskov',
#   'RegionName': 'Midtjylland',
#   'ConnectionPointLatitude': 56.174471,
#   'ConnectionPointLongitude': 9.801889,
#   'NetCompanyName': 'Dinel',
#   'region_code': 'dk_mun_710'},
#  {'_id': 1056,
#   'ConnectionPointCode': 'DALØ',
#   'ConnectionPointName': 'Dalmose',
#   'MunicipalityNo': '330',
#   'Municipality': 'Slagelse',
#   'RegionName': 'Sjælland',
#   'ConnectionPointLatitude': 55.266406,
#   'ConnectionPointLongitude': 11.453134,
#   'NetCompanyName': 'Cerius',
#   'region_code': 'dk_mun_330'},
#  {'_id': 127,
#   'ConnectionPointCode': 'DAN',
#   'ConnectionPointName': 'Dania',
#   'MunicipalityNo': '846',
#   'Municipality': 'Mariagerfjord',
#   'RegionName': 'Nordjylland',
#   'ConnectionPointLatitude': 56.686624,
#   'ConnectionPointLongitude': 10.04781,
#   'NetCompanyName': 'N1',
#   'region_code': 'dk_mun_846'},
#  {'_id': 129,
#   'ConnectionPointCode': 'DGA',
#   'ConnectionPointName': 'Dalgas Allé, Herning',
#   'MunicipalityNo': '657',
#   'Municipality': 'Herning',
#   'RegionName': 'Midtjylland',
#   'ConnectionPointLatitude': 56.134813,
#   'ConnectionPointLongitude': 8.964781,
#   'NetCompanyName': 'N1',
#   'region_code': 'dk_mun_657'},
#  {'_id': 131,
#   'ConnectionPointCode': 'DLS',
#   'ConnectionPointName': 'Dalslunde afgreningspunkt',
#   'MunicipalityNo': '400',
#   'Municipality': 'Bornholm',
#   'RegionName': 'Hovedstaden',
#   'ConnectionPointLatitude': 55.11495,
#   'ConnectionPointLongitude': 15.03155,
#   'NetCompanyName': 'Trefor El-Net Øst',
#   'region_code': 'dk_mun_400'},
#  {'_id': 132,
#   'ConnectionPointCode': 'DNF',
#   'ConnectionPointName': 'Danfoss',
#   'MunicipalityNo': '540',
#   'Municipality': 'Sønderborg',
#   'RegionName': 'Syddanmark',
#   'ConnectionPointLatitude': 55.035336,
#   'ConnectionPointLongitude': 9.811789,
#   'NetCompanyName': 'N1',
#   'region_code': 'dk_mun_540'},
#  {'_id': 134,
#   'ConnectionPointCode': 'DRB',
#   'ConnectionPointName': 'Dronningborg',
#   'MunicipalityNo': '730',
#   'Municipality': 'Randers',
#   'RegionName': 'Midtjylland',
#   'ConnectionPointLatitude': 56.46885,
#   'ConnectionPointLongitude': 10.069444,
#   'NetCompanyName': 'N1Randers',
#   'region_code': 'dk_mun_730'},
#  {'_id': 136,
#   'ConnectionPointCode': 'DRL',
#   'ConnectionPointName': 'Dronninglund',
#   'MunicipalityNo': '810',
#   'Municipality': 'Brønderslev',
#   'RegionName': 'Nordjylland',
#   'ConnectionPointLatitude': 57.159813,
#   'ConnectionPointLongitude': 10.307954,
#   'NetCompanyName': 'Nord Energi',
#   'region_code': 'dk_mun_810'},
#  {'_id': 1057,
#   'ConnectionPointCode': 'DRS',
#   'ConnectionPointName': 'Dragstrup',
#   'MunicipalityNo': '773',
#   'Municipality': 'Morsø',
#   'RegionName': 'Nordjylland',
#   'ConnectionPointLatitude': 56.814841,
#   'ConnectionPointLongitude': 8.679789,
#   'NetCompanyName': 'Thy-Mors Energi A/S',
#   'region_code': 'dk_mun_773'},
#  {'_id': 139,
#   'ConnectionPointCode': 'DUR',
#   'ConnectionPointName': 'Durup',
#   'MunicipalityNo': '779',
#   'Municipality': 'Skive',
#   'RegionName': 'Midtjylland',
#   'ConnectionPointLatitude': 56.739326,
#   'ConnectionPointLongitude': 8.981031,
#   'NetCompanyName': 'N1',
#   'region_code': 'dk_mun_779'},
#  {'_id': 140,
#   'ConnectionPointCode': 'DYB',
#   'ConnectionPointName': 'Dybvad',
#   'MunicipalityNo': '810',
#   'Municipality': 'Brønderslev',
#   'RegionName': 'Nordjylland',
#   'ConnectionPointLatitude': 57.287356,
#   'ConnectionPointLongitude': 10.380106,
#   'NetCompanyName': 'Nord Energi',
#   'region_code': 'dk_mun_810'},
#  {'_id': 1058,
#   'ConnectionPointCode': 'DYR*',
#   'ConnectionPointName': 'Dyregård',
#   'MunicipalityNo': '151',
#   'Municipality': 'Ballerup',
#   'RegionName': 'Hovedstaden',
#   'ConnectionPointLatitude': 55.732615,
#   'ConnectionPointLongitude': 12.394964,
#   'NetCompanyName': 'Radius Elnet',
#   'region_code': 'dk_mun_151'},
#  {'_id': 141,
#   'ConnectionPointCode': 'DYRV',
#   'ConnectionPointName': 'Dyrup',
#   'MunicipalityNo': '461',
#   'Municipality': 'Odense',
#   'RegionName': 'Syddanmark',
#   'ConnectionPointLatitude': 55.35296,
#   'ConnectionPointLongitude': 10.33307,
#   'NetCompanyName': 'VORES ELNET A/S',
#   'region_code': 'dk_mun_461'},
#  {'_id': 1059,
#   'ConnectionPointCode': 'DØR',
#   'ConnectionPointName': 'Dørslund',
#   'MunicipalityNo': '756',
#   'Municipality': 'Ikast-Brande',
#   'RegionName': 'Midtjylland',
#   'ConnectionPointLatitude': 55.958768,
#   'ConnectionPointLongitude': 9.153084,
#   'NetCompanyName': 'RAH net',
#   'region_code': 'dk_mun_756'},
#  {'_id': 143,
#   'ConnectionPointCode': 'EBB',
#   'ConnectionPointName': 'Ebbeløkke',
#   'MunicipalityNo': '306',
#   'Municipality': 'Odsherred',
#   'RegionName': 'Sjælland',
#   'ConnectionPointLatitude': 55.951465,
#   'ConnectionPointLongitude': 11.491276,
#   'NetCompanyName': 'Cerius',
#   'region_code': 'dk_mun_306'},
#  {'_id': 144,
#   'ConnectionPointCode': 'EBE',
#   'ConnectionPointName': 'Egebjerg, Hjørring',
#   'MunicipalityNo': '860',
#   'Municipality': 'Hjørring',
#   'RegionName': 'Nordjylland',
#   'ConnectionPointLatitude': 57.440835,
#   'ConnectionPointLongitude': 10.125359,
#   'NetCompanyName': 'Nord Energi',
#   'region_code': 'dk_mun_860'},
#  {'_id': 145,
#   'ConnectionPointCode': 'EBG',
#   'ConnectionPointName': 'Eskebjerg',
#   'MunicipalityNo': '326',
#   'Municipality': 'Kalundborg',
#   'RegionName': 'Sjælland',
#   'ConnectionPointLatitude': 55.702839,
#   'ConnectionPointLongitude': 11.305055,
#   'NetCompanyName': 'Cerius',
#   'region_code': 'dk_mun_326'},
#  {'_id': 146,
#   'ConnectionPointCode': 'EBJ',
#   'ConnectionPointName': 'Egebjerg, Horsens',
#   'MunicipalityNo': '615',
#   'Municipality': 'Horsens',
#   'RegionName': 'Midtjylland',
#   'ConnectionPointLatitude': 55.89749,
#   'ConnectionPointLongitude': 9.835325,
#   'NetCompanyName': 'N1',
#   'region_code': 'dk_mun_615'},
#  {'_id': 147,
#   'ConnectionPointCode': 'EBR',
#   'ConnectionPointName': 'Egåbro',
#   'MunicipalityNo': '751',
#   'Municipality': 'Aarhus',
#   'RegionName': 'Midtjylland',
#   'ConnectionPointLatitude': 56.20482,
#   'ConnectionPointLongitude': 10.25069,
#   'NetCompanyName': 'Konstant Nord',
#   'region_code': 'dk_mun_751'},
#  {'_id': 148,
#   'ConnectionPointCode': 'EBT',
#   'ConnectionPointName': 'Ebeltoft',
#   'MunicipalityNo': '706',
#   'Municipality': 'Syddjurs',
#   'RegionName': 'Midtjylland',
#   'ConnectionPointLatitude': 56.20616,
#   'ConnectionPointLongitude': 10.68448,
#   'NetCompanyName': 'Konstant Nord',
#   'region_code': 'dk_mun_706'},
#  {'_id': 149,
#   'ConnectionPointCode': 'EBY',
#   'ConnectionPointName': 'Ejbygård',
#   'MunicipalityNo': '161',
#   'Municipality': 'Glostrup',
#   'RegionName': 'Hovedstaden',
#   'ConnectionPointLatitude': 55.686573,
#   'ConnectionPointLongitude': 12.397478,
#   'NetCompanyName': 'Radius Elnet',
#   'region_code': 'dk_mun_161'},
#  {'_id': 150,
#   'ConnectionPointCode': 'EDR',
#   'ConnectionPointName': 'Endrup',
#   'MunicipalityNo': '561',
#   'Municipality': 'Esbjerg',
#   'RegionName': 'Syddanmark',
#   'ConnectionPointLatitude': 55.531823,
#   'ConnectionPointLongitude': 8.707872,
#   'NetCompanyName': 'Vestjyske Net A/S',
#   'region_code': 'dk_mun_561'},
#  {'_id': 151,
#   'ConnectionPointCode': 'EGB',
#   'ConnectionPointName': 'Egebjerg, Vinderup',
#   'MunicipalityNo': '657',
#   'Municipality': 'Herning',
#   'RegionName': 'Midtjylland',
#   'ConnectionPointLatitude': 56.53247,
#   'ConnectionPointLongitude': 8.81633,
#   'NetCompanyName': 'N1',
#   'region_code': 'dk_mun_657'},
#  {'_id': 152,
#   'ConnectionPointCode': 'EGE',
#   'ConnectionPointName': 'Egeskovvej, Fredericia',
#   'MunicipalityNo': '607',
#   'Municipality': 'Fredericia',
#   'RegionName': 'Syddanmark',
#   'ConnectionPointLatitude': 55.58995,
#   'ConnectionPointLongitude': 9.752776,
#   'NetCompanyName': 'TREFOR',
#   'region_code': 'dk_mun_607'},
#  {'_id': 153,
#   'ConnectionPointCode': 'EGR',
#   'ConnectionPointName': 'Egeris',
#   'MunicipalityNo': '661',
#   'Municipality': 'Holstebro',
#   'RegionName': 'Midtjylland',
#   'ConnectionPointLatitude': 56.543894,
#   'ConnectionPointLongitude': 9.02962,
#   'NetCompanyName': 'N1',
#   'region_code': 'dk_mun_661'},
#  {'_id': 154,
#   'ConnectionPointCode': 'EGS',
#   'ConnectionPointName': 'Egernsund',
#   'MunicipalityNo': '540',
#   'Municipality': 'Sønderborg',
#   'RegionName': 'Syddanmark',
#   'ConnectionPointLatitude': 54.905217,
#   'ConnectionPointLongitude': 9.617801,
#   'NetCompanyName': 'N1',
#   'region_code': 'dk_mun_540'},
#  {'_id': 155,
#   'ConnectionPointCode': 'EGT',
#   'ConnectionPointName': 'Egtved',
#   'MunicipalityNo': '621',
#   'Municipality': 'Kolding',
#   'RegionName': 'Syddanmark',
#   'ConnectionPointLatitude': 55.611513,
#   'ConnectionPointLongitude': 9.29972,
#   'NetCompanyName': 'TREFOR',
#   'region_code': 'dk_mun_621'},
#  {'_id': 156,
#   'ConnectionPointCode': 'EGU',
#   'ConnectionPointName': 'Egum',
#   'MunicipalityNo': '607',
#   'Municipality': 'Fredericia',
#   'RegionName': 'Syddanmark',
#   'ConnectionPointLatitude': 55.589687,
#   'ConnectionPointLongitude': 9.713044,
#   'NetCompanyName': 'TREFOR',
#   'region_code': 'dk_mun_607'},
#  {'_id': 157,
#   'ConnectionPointCode': 'EGÅ',
#   'ConnectionPointName': 'Egå',
#   'MunicipalityNo': '751',
#   'Municipality': 'Aarhus',
#   'RegionName': 'Midtjylland',
#   'ConnectionPointLatitude': 56.22846,
#   'ConnectionPointLongitude': 10.27295,
#   'NetCompanyName': 'Konstant Nord',
#   'region_code': 'dk_mun_751'},
#  {'_id': 158,
#   'ConnectionPointCode': 'EHA',
#   'ConnectionPointName': 'Esbjerg Havn',
#   'MunicipalityNo': '561',
#   'Municipality': 'Esbjerg',
#   'RegionName': 'Syddanmark',
#   'ConnectionPointLatitude': 55.476093,
#   'ConnectionPointLongitude': 8.430089,
#   'NetCompanyName': 'N1',
#   'region_code': 'dk_mun_561'},
#  {'_id': 160,
#   'ConnectionPointCode': 'EJB',
#   'ConnectionPointName': 'Ejby',
#   'MunicipalityNo': '410',
#   'Municipality': 'Middelfart',
#   'RegionName': 'Syddanmark',
#   'ConnectionPointLatitude': 55.447357,
#   'ConnectionPointLongitude': 9.94568,
#   'NetCompanyName': 'VORES ELNET A/S',
#   'region_code': 'dk_mun_410'},
#  {'_id': 162,
#   'ConnectionPointCode': 'EJEV',
#   'ConnectionPointName': 'Ejer',
#   'MunicipalityNo': '615',
#   'Municipality': 'Horsens',
#   'RegionName': 'Midtjylland',
#   'ConnectionPointLatitude': 55.989797,
#   'ConnectionPointLongitude': 9.829648,
#   'NetCompanyName': 'Dinel',
#   'region_code': 'dk_mun_615'},
#  {'_id': 1060,
#   'ConnectionPointCode': 'EJEØ',
#   'ConnectionPointName': 'Ejegod',
#   'MunicipalityNo': '376',
#   'Municipality': 'Guldborgsund',
#   'RegionName': 'Sjælland',
#   'ConnectionPointLatitude': 54.788431,
#   'ConnectionPointLongitude': 11.867673,
#   'NetCompanyName': 'Cerius',
#   'region_code': 'dk_mun_376'},
#  {'_id': 163,
#   'ConnectionPointCode': 'EJS',
#   'ConnectionPointName': 'Ejstrupholm',
#   'MunicipalityNo': '756',
#   'Municipality': 'Ikast-Brande',
#   'RegionName': 'Midtjylland',
#   'ConnectionPointLatitude': 55.980121,
#   'ConnectionPointLongitude': 9.299122,
#   'NetCompanyName': 'RAH net',
#   'region_code': 'dk_mun_756'},
#  {'_id': 164,
#   'ConnectionPointCode': 'ELB',
#   'ConnectionPointName': 'Elbæk',
#   'MunicipalityNo': '615',
#   'Municipality': 'Horsens',
#   'RegionName': 'Midtjylland',
#   'ConnectionPointLatitude': 55.918326,
#   'ConnectionPointLongitude': 10.011055,
#   'NetCompanyName': 'N1',
#   'region_code': 'dk_mun_615'},
#  {'_id': 165,
#   'ConnectionPointCode': 'ELE',
#   'ConnectionPointName': 'Elev',
#   'MunicipalityNo': '751',
#   'Municipality': 'Aarhus',
#   'RegionName': 'Midtjylland',
#   'ConnectionPointLatitude': 56.23243,
#   'ConnectionPointLongitude': 10.21047,
#   'NetCompanyName': 'Konstant Nord',
#   'region_code': 'dk_mun_751'},
#  {'_id': 166,
#   'ConnectionPointCode': 'ELI',
#   'ConnectionPointName': 'Ellinge',
#   'MunicipalityNo': '440',
#   'Municipality': 'Kerteminde',
#   'RegionName': 'Syddanmark',
#   'ConnectionPointLatitude': 55.311975,
#   'ConnectionPointLongitude': 10.660725,
#   'NetCompanyName': 'VORES ELNET A/S',
#   'region_code': 'dk_mun_440'},
#  {'_id': 167,
#   'ConnectionPointCode': 'ENB',
#   'ConnectionPointName': 'Engbjerg',
#   'MunicipalityNo': '665',
#   'Municipality': 'Lemvig',
#   'RegionName': 'Midtjylland',
#   'ConnectionPointLatitude': 56.56708,
#   'ConnectionPointLongitude': 8.20198,
#   'NetCompanyName': 'NOE Net A/S',
#   'region_code': 'dk_mun_665'},
#  {'_id': 168,
#   'ConnectionPointCode': 'ENG',
#   'ConnectionPointName': 'Engeldrup',
#   'MunicipalityNo': '480',
#   'Municipality': 'Nordfyn',
#   'RegionName': 'Syddanmark',
#   'ConnectionPointLatitude': 55.542449,
#   'ConnectionPointLongitude': 10.247579,
#   'NetCompanyName': 'VORES ELNET A/S',
#   'region_code': 'dk_mun_480'},
#  {'_id': 169,
#   'ConnectionPointCode': 'ENS',
#   'ConnectionPointName': 'Enslev',
#   'MunicipalityNo': '751',
#   'Municipality': 'Aarhus',
#   'RegionName': 'Midtjylland',
#   'ConnectionPointLatitude': 56.08919,
#   'ConnectionPointLongitude': 10.081896,
#   'NetCompanyName': 'Dinel',
#   'region_code': 'dk_mun_751'},
#  {'_id': 170,
#   'ConnectionPointCode': 'ERR',
#   'ConnectionPointName': 'Erritsø, Kabelovergangsstation',
#   'MunicipalityNo': '607',
#   'Municipality': 'Fredericia',
#   'RegionName': 'Syddanmark',
#   'ConnectionPointLatitude': 55.543257,
#   'ConnectionPointLongitude': 9.689087,
#   'NetCompanyName': 'TREFOR',
#   'region_code': 'dk_mun_607'},
#  {'_id': 171,
#   'ConnectionPointCode': 'ESK',
#   'ConnectionPointName': 'Eskilstrup',
#   'MunicipalityNo': '376',
#   'Municipality': 'Guldborgsund',
#   'RegionName': 'Sjælland',
#   'ConnectionPointLatitude': 54.849705,
#   'ConnectionPointLongitude': 11.893968,
#   'NetCompanyName': 'Cerius',
#   'region_code': 'dk_mun_376'},
#  {'_id': 172,
#   'ConnectionPointCode': 'ESP',
#   'ConnectionPointName': 'Espe',
#   'MunicipalityNo': '430',
#   'Municipality': 'Faaborg-Midtfyn',
#   'RegionName': 'Syddanmark',
#   'ConnectionPointLatitude': 55.217586,
#   'ConnectionPointLongitude': 10.432214,
#   'NetCompanyName': 'VORES ELNET A/S',
#   'region_code': 'dk_mun_430'},
#  {'_id': 173,
#   'ConnectionPointCode': 'EST',
#   'ConnectionPointName': 'Estrupvej',
#   'MunicipalityNo': '561',
#   'Municipality': 'Esbjerg',
#   'RegionName': 'Syddanmark',
#   'ConnectionPointLatitude': 55.462691,
#   'ConnectionPointLongitude': 8.474662,
#   'NetCompanyName': 'N1',
#   'region_code': 'dk_mun_561'},
#  {'_id': 175,
#   'ConnectionPointCode': 'EVG',
#   'ConnectionPointName': 'Engesvang',
#   'MunicipalityNo': '740',
#   'Municipality': 'Silkeborg',
#   'RegionName': 'Midtjylland',
#   'ConnectionPointLatitude': 56.165249,
#   'ConnectionPointLongitude': 9.345819,
#   'NetCompanyName': 'N1',
#   'region_code': 'dk_mun_740'},
#  {'_id': 176,
#   'ConnectionPointCode': 'EVJ',
#   'ConnectionPointName': 'Engvej',
#   'MunicipalityNo': '851',
#   'Municipality': 'Aalborg',
#   'RegionName': 'Nordjylland',
#   'ConnectionPointLatitude': 57.059715,
#   'ConnectionPointLongitude': 9.937834,
#   'NetCompanyName': 'N1',
#   'region_code': 'dk_mun_851'},
#  {'_id': 179,
#   'ConnectionPointCode': 'FAN',
#   'ConnectionPointName': 'Fanefjord',
#   'MunicipalityNo': '390',
#   'Municipality': 'Vordingborg',
#   'RegionName': 'Sjælland',
#   'ConnectionPointLatitude': 54.909405,
#   'ConnectionPointLongitude': 12.180011,
#   'NetCompanyName': 'Cerius',
#   'region_code': 'dk_mun_390'},
#  {'_id': 180,
#   'ConnectionPointCode': 'FARV',
#   'ConnectionPointName': 'Farstrup',
#   'MunicipalityNo': '480',
#   'Municipality': 'Nordfyn',
#   'RegionName': 'Syddanmark',
#   'ConnectionPointLatitude': 55.46349,
#   'ConnectionPointLongitude': 10.1906,
#   'NetCompanyName': 'VORES ELNET A/S',
#   'region_code': 'dk_mun_480'},
#  {'_id': 181,
#   'ConnectionPointCode': 'FARØ',
#   'ConnectionPointName': 'Farum Gydegård',
#   'MunicipalityNo': '190',
#   'Municipality': 'Furesø',
#   'RegionName': 'Hovedstaden',
#   'ConnectionPointLatitude': 55.819215,
#   'ConnectionPointLongitude': 12.363353,
#   'NetCompanyName': 'Radius Elnet',
#   'region_code': 'dk_mun_190'},
#  {'_id': 182,
#   'ConnectionPointCode': 'FAS',
#   'ConnectionPointName': 'Fasterholt',
#   'MunicipalityNo': '657',
#   'Municipality': 'Herning',
#   'RegionName': 'Midtjylland',
#   'ConnectionPointLatitude': 56.009635,
#   'ConnectionPointLongitude': 9.100641,
#   'NetCompanyName': 'N1',
#   'region_code': 'dk_mun_657'},
#  {'_id': 183,
#   'ConnectionPointCode': 'FBG',
#   'ConnectionPointName': 'Fredensborggård',
#   'MunicipalityNo': '210',
#   'Municipality': 'Fredensborg',
#   'RegionName': 'Hovedstaden',
#   'ConnectionPointLatitude': 55.964641,
#   'ConnectionPointLongitude': 12.401364,
#   'NetCompanyName': 'Radius Elnet',
#   'region_code': 'dk_mun_210'},
#  {'_id': 184,
#   'ConnectionPointCode': 'FBV',
#   'ConnectionPointName': 'Faaborg Vest',
#   'MunicipalityNo': '430',
#   'Municipality': 'Faaborg-Midtfyn',
#   'RegionName': 'Syddanmark',
#   'ConnectionPointLatitude': 55.11374,
#   'ConnectionPointLongitude': 10.229352,
#   'NetCompanyName': 'VORES ELNET A/S',
#   'region_code': 'dk_mun_430'},
#  {'_id': 185,
#   'ConnectionPointCode': 'FBY',
#   'ConnectionPointName': 'Faaborg By',
#   'MunicipalityNo': '430',
#   'Municipality': 'Faaborg-Midtfyn',
#   'RegionName': 'Syddanmark',
#   'ConnectionPointLatitude': 55.095972,
#   'ConnectionPointLongitude': 10.249017,
#   'NetCompanyName': 'VORES ELNET A/S',
#   'region_code': 'dk_mun_430'},
#  {'_id': 186,
#   'ConnectionPointCode': 'FEL',
#   'ConnectionPointName': 'Felsted',
#   'MunicipalityNo': '580',
#   'Municipality': 'Aabenraa',
#   'RegionName': 'Syddanmark',
#   'ConnectionPointLatitude': 54.981591,
#   'ConnectionPointLongitude': 9.497113,
#   'NetCompanyName': 'N1',
#   'region_code': 'dk_mun_580'},
#  {'_id': 188,
#   'ConnectionPointCode': 'FER',
#   'ConnectionPointName': 'Ferslev',
#   'MunicipalityNo': '840',
#   'Municipality': 'Rebild',
#   'RegionName': 'Nordjylland',
#   'ConnectionPointLatitude': 56.957586,
#   'ConnectionPointLongitude': 9.881441,
#   'NetCompanyName': 'N1',
#   'region_code': 'dk_mun_840'},
#  {'_id': 189,
#   'ConnectionPointCode': 'FFT',
#   'ConnectionPointName': 'Frifelt',
#   'MunicipalityNo': '550',
#   'Municipality': 'Tønder',
#   'RegionName': 'Syddanmark',
#   'ConnectionPointLatitude': 55.209043,
#   'ConnectionPointLongitude': 8.84368,
#   'NetCompanyName': 'N1',
#   'region_code': 'dk_mun_550'},
#  {'_id': 190,
#   'ConnectionPointCode': 'FGD',
#   'ConnectionPointName': 'Fraugde',
#   'MunicipalityNo': '461',
#   'Municipality': 'Odense',
# ...
#   'ConnectionPointLongitude': 10.21725,
#   'NetCompanyName': 'Konstant Nord',
#   'region_code': 'dk_mun_751'},
#  {'_id': 978,
#   'ConnectionPointCode': 'VRJ',
#   'ConnectionPointName': 'Vestre Ringvej, Fredericia',
#   'MunicipalityNo': '607',
#   'Municipality': 'Fredericia',
#   'RegionName': 'Syddanmark',
#   'ConnectionPointLatitude': 55.587706,
#   'ConnectionPointLongitude': 9.747645,
#   'NetCompanyName': 'TREFOR',
#   'region_code': 'dk_mun_607'},
#  {'_id': 979,
#   'ConnectionPointCode': 'VRÅ',
#   'ConnectionPointName': 'Vrå',
#   'MunicipalityNo': '810',
#   'Municipality': 'Brønderslev',
#   'RegionName': 'Nordjylland',
#   'ConnectionPointLatitude': 57.344959,
#   'ConnectionPointLongitude': 9.931237,
#   'NetCompanyName': 'N1',
#   'region_code': 'dk_mun_810'},
#  {'_id': 981,
#   'ConnectionPointCode': 'VSB',
#   'ConnectionPointName': 'Vissenbjerg',
#   'MunicipalityNo': '420',
#   'Municipality': 'Assens',
#   'RegionName': 'Syddanmark',
#   'ConnectionPointLatitude': 55.39115,
#   'ConnectionPointLongitude': 10.150242,
#   'NetCompanyName': 'VORES ELNET A/S',
#   'region_code': 'dk_mun_420'},
#  {'_id': 982,
#   'ConnectionPointCode': 'VSK',
#   'ConnectionPointName': 'Vester Skerninge',
#   'MunicipalityNo': '430',
#   'Municipality': 'Faaborg-Midtfyn',
#   'RegionName': 'Syddanmark',
#   'ConnectionPointLatitude': 55.065003,
#   'ConnectionPointLongitude': 10.435337,
#   'NetCompanyName': 'FLOW ELNET A/S',
#   'region_code': 'dk_mun_430'},
#  {'_id': 983,
#   'ConnectionPointCode': 'VSN',
#   'ConnectionPointName': 'Vojens Nord',
#   'MunicipalityNo': '510',
#   'Municipality': 'Haderslev',
#   'RegionName': 'Syddanmark',
#   'ConnectionPointLatitude': 55.2562,
#   'ConnectionPointLongitude': 9.267836,
#   'NetCompanyName': 'N1',
#   'region_code': 'dk_mun_510'},
#  {'_id': 985,
#   'ConnectionPointCode': 'VSP',
#   'ConnectionPointName': 'Vester Sottrup',
#   'MunicipalityNo': '540',
#   'Municipality': 'Sønderborg',
#   'RegionName': 'Syddanmark',
#   'ConnectionPointLatitude': 54.939242,
#   'ConnectionPointLongitude': 9.69576,
#   'NetCompanyName': 'N1',
#   'region_code': 'dk_mun_540'},
#  {'_id': 986,
#   'ConnectionPointCode': 'VSTV',
#   'ConnectionPointName': 'Vadstrup, Samsø',
#   'MunicipalityNo': '741',
#   'Municipality': 'Samsø',
#   'RegionName': 'Midtjylland',
#   'ConnectionPointLatitude': 55.8472,
#   'ConnectionPointLongitude': 10.56036,
#   'NetCompanyName': 'Konstant Nord',
#   'region_code': 'dk_mun_741'},
#  {'_id': 987,
#   'ConnectionPointCode': 'VSTØ',
#   'ConnectionPointName': 'Vestgård',
#   'MunicipalityNo': '153',
#   'Municipality': 'Brøndby',
#   'RegionName': 'Hovedstaden',
#   'ConnectionPointLatitude': 55.656382,
#   'ConnectionPointLongitude': 12.455653,
#   'NetCompanyName': 'Radius Elnet',
#   'region_code': 'dk_mun_153'},
#  {'_id': 988,
#   'ConnectionPointCode': 'VVA',
#   'ConnectionPointName': 'Vester Vandet',
#   'MunicipalityNo': '787',
#   'Municipality': 'Thisted',
#   'RegionName': 'Nordjylland',
#   'ConnectionPointLatitude': 57.001647,
#   'ConnectionPointLongitude': 8.546989,
#   'NetCompanyName': 'Thy-Mors Energi A/S',
#   'region_code': 'dk_mun_787'},
#  {'_id': 989,
#   'ConnectionPointCode': 'VÆL',
#   'ConnectionPointName': 'Vælds',
#   'MunicipalityNo': '791',
#   'Municipality': 'Viborg',
#   'RegionName': 'Midtjylland',
#   'ConnectionPointLatitude': 56.471743,
#   'ConnectionPointLongitude': 9.586054,
#   'NetCompanyName': 'N1',
#   'region_code': 'dk_mun_791'},
#  {'_id': 990,
#   'ConnectionPointCode': 'VÅR',
#   'ConnectionPointName': 'Vårst',
#   'MunicipalityNo': '840',
#   'Municipality': 'Rebild',
#   'RegionName': 'Nordjylland',
#   'ConnectionPointLatitude': 56.939152,
#   'ConnectionPointLongitude': 10.061285,
#   'NetCompanyName': 'N1',
#   'region_code': 'dk_mun_840'},
#  {'_id': 1133,
#   'ConnectionPointCode': 'WSØ',
#   'ConnectionPointName': 'Ollerupvej',
#   'MunicipalityNo': '851',
#   'Municipality': 'Aalborg',
#   'RegionName': 'Nordjylland',
#   'ConnectionPointLatitude': 57.030243,
#   'ConnectionPointLongitude': 10.013733,
#   'NetCompanyName': 'N1',
#   'region_code': 'dk_mun_851'},
#  {'_id': 991,
#   'ConnectionPointCode': 'WUN',
#   'ConnectionPointName': 'Udbyneder',
#   'MunicipalityNo': '846',
#   'Municipality': 'Mariagerfjord',
#   'RegionName': 'Nordjylland',
#   'ConnectionPointLatitude': 56.66567,
#   'ConnectionPointLongitude': 10.292714,
#   'NetCompanyName': 'N1',
#   'region_code': 'dk_mun_846'},
#  {'_id': 1134,
#   'ConnectionPointCode': 'WVE',
#   'ConnectionPointName': 'Vedersø',
#   'MunicipalityNo': '760',
#   'Municipality': 'Ringkøbing-Skjern',
#   'RegionName': 'Midtjylland',
#   'ConnectionPointLatitude': 56.220888,
#   'ConnectionPointLongitude': 8.234118,
#   'NetCompanyName': 'RAH Net A/S',
#   'region_code': 'dk_mun_760'},
#  {'_id': 992,
#   'ConnectionPointCode': 'YDN',
#   'ConnectionPointName': 'Ydernæs',
#   'MunicipalityNo': '370',
#   'Municipality': 'Næstved',
#   'RegionName': 'Sjælland',
#   'ConnectionPointLatitude': 55.209113,
#   'ConnectionPointLongitude': 11.740208,
#   'NetCompanyName': 'Cerius',
#   'region_code': 'dk_mun_370'},
#  {'_id': 993,
#   'ConnectionPointCode': 'YRJ',
#   'ConnectionPointName': 'Ydre Ringvej, Fredericia',
#   'MunicipalityNo': '607',
#   'Municipality': 'Fredericia',
#   'RegionName': 'Syddanmark',
#   'ConnectionPointLatitude': 55.598426,
#   'ConnectionPointLongitude': 9.742048,
#   'NetCompanyName': 'TREFOR',
#   'region_code': 'dk_mun_607'},
#  {'_id': 994,
#   'ConnectionPointCode': 'ØAS',
#   'ConnectionPointName': 'Øster Assels',
#   'MunicipalityNo': '773',
#   'Municipality': 'Morsø',
#   'RegionName': 'Nordjylland',
#   'ConnectionPointLatitude': 56.695015,
#   'ConnectionPointLongitude': 8.657533,
#   'NetCompanyName': 'Thy-Mors Energi A/S',
#   'region_code': 'dk_mun_773'},
#  {'_id': 996,
#   'ConnectionPointCode': 'ØBI',
#   'ConnectionPointName': 'Østbirk',
#   'MunicipalityNo': '615',
#   'Municipality': 'Horsens',
#   'RegionName': 'Midtjylland',
#   'ConnectionPointLatitude': 55.967233,
#   'ConnectionPointLongitude': 9.767937,
#   'NetCompanyName': 'N1',
#   'region_code': 'dk_mun_615'},
#  {'_id': 997,
#   'ConnectionPointCode': 'ØBO',
#   'ConnectionPointName': 'Øster Bording',
#   'MunicipalityNo': '740',
#   'Municipality': 'Silkeborg',
#   'RegionName': 'Midtjylland',
#   'ConnectionPointLatitude': 56.185711,
#   'ConnectionPointLongitude': 9.477866,
#   'NetCompanyName': 'N1',
#   'region_code': 'dk_mun_740'},
#  {'_id': 999,
#   'ConnectionPointCode': 'ØGL',
#   'ConnectionPointName': 'Øster Gejl',
#   'MunicipalityNo': '580',
#   'Municipality': 'Aabenraa',
#   'RegionName': 'Syddanmark',
#   'ConnectionPointLatitude': 54.887463,
#   'ConnectionPointLongitude': 9.408532,
#   'NetCompanyName': 'N1',
#   'region_code': 'dk_mun_580'},
#  {'_id': 1000,
#   'ConnectionPointCode': 'ØLG',
#   'ConnectionPointName': 'Ølgod',
#   'MunicipalityNo': '760',
#   'Municipality': 'Ringkøbing-Skjern',
#   'RegionName': 'Midtjylland',
#   'ConnectionPointLatitude': 55.813451,
#   'ConnectionPointLongitude': 8.642682,
#   'NetCompanyName': 'N1',
#   'region_code': 'dk_mun_760'},
#  {'_id': 1001,
#   'ConnectionPointCode': 'ØLS',
#   'ConnectionPointName': 'Ølstykkegård',
#   'MunicipalityNo': '240',
#   'Municipality': 'Egedal',
#   'RegionName': 'Hovedstaden',
#   'ConnectionPointLatitude': 55.77148,
#   'ConnectionPointLongitude': 12.143712,
#   'NetCompanyName': 'Radius Elnet',
#   'region_code': 'dk_mun_240'},
#  {'_id': 1002,
#   'ConnectionPointCode': 'ØLSV',
#   'ConnectionPointName': 'Ølst',
#   'MunicipalityNo': '710',
#   'Municipality': 'Favrskov',
#   'RegionName': 'Midtjylland',
#   'ConnectionPointLatitude': 56.378105,
#   'ConnectionPointLongitude': 10.076116,
#   'NetCompanyName': 'N1',
#   'region_code': 'dk_mun_710'},
#  {'_id': 1003,
#   'ConnectionPointCode': 'ØMA',
#   'ConnectionPointName': 'Ølsemagle',
#   'MunicipalityNo': '259',
#   'Municipality': 'Køge',
#   'RegionName': 'Sjælland',
#   'ConnectionPointLatitude': 55.497769,
#   'ConnectionPointLongitude': 12.170069,
#   'NetCompanyName': 'Cerius',
#   'region_code': 'dk_mun_259'},
#  {'_id': 1135,
#   'ConnectionPointCode': 'ØRB',
#   'ConnectionPointName': 'Østerby',
#   'MunicipalityNo': '813',
#   'Municipality': 'Frederikshavn',
#   'RegionName': 'Nordjylland',
#   'ConnectionPointLatitude': 57.72159,
#   'ConnectionPointLongitude': 10.598371,
#   'NetCompanyName': 'Nord Energi',
#   'region_code': 'dk_mun_813'},
#  {'_id': 1004,
#   'ConnectionPointCode': 'ØRG',
#   'ConnectionPointName': 'Ørumgård',
#   'MunicipalityNo': '766',
#   'Municipality': 'Hedensted',
#   'RegionName': 'Midtjylland',
#   'ConnectionPointLatitude': 55.728,
#   'ConnectionPointLongitude': 9.75453,
#   'NetCompanyName': 'Konstant Syd',
#   'region_code': 'dk_mun_766'},
#  {'_id': 1005,
#   'ConnectionPointCode': 'ØRK',
#   'ConnectionPointName': 'Ørbæk',
#   'MunicipalityNo': '430',
#   'Municipality': 'Faaborg-Midtfyn',
#   'RegionName': 'Syddanmark',
#   'ConnectionPointLatitude': 55.254436,
#   'ConnectionPointLongitude': 10.682539,
#   'NetCompanyName': 'VORES ELNET A/S',
#   'region_code': 'dk_mun_430'},
#  {'_id': 1006,
#   'ConnectionPointCode': 'ØRN',
#   'ConnectionPointName': 'Ørnegård',
#   'MunicipalityNo': '157',
#   'Municipality': 'Gentofte',
#   'RegionName': 'Hovedstaden',
#   'ConnectionPointLatitude': 55.756802,
#   'ConnectionPointLongitude': 12.521159,
#   'NetCompanyName': 'Radius Elnet',
#   'region_code': 'dk_mun_157'},
#  {'_id': 1007,
#   'ConnectionPointCode': 'ØRU',
#   'ConnectionPointName': 'Ørum',
#   'MunicipalityNo': '779',
#   'Municipality': 'Skive',
#   'RegionName': 'Midtjylland',
#   'ConnectionPointLatitude': 56.56438,
#   'ConnectionPointLongitude': 9.226302,
#   'NetCompanyName': 'N1',
#   'region_code': 'dk_mun_779'},
#  {'_id': 1008,
#   'ConnectionPointCode': 'ØSB',
#   'ConnectionPointName': 'Øsby',
#   'MunicipalityNo': '510',
#   'Municipality': 'Haderslev',
#   'RegionName': 'Syddanmark',
#   'ConnectionPointLatitude': 55.247537,
#   'ConnectionPointLongitude': 9.637262,
#   'NetCompanyName': 'N1',
#   'region_code': 'dk_mun_510'},
#  {'_id': 1136,
#   'ConnectionPointCode': 'ØSG*********',
#   'ConnectionPointName': 'Østengårdskov',
#   'MunicipalityNo': '630',
#   'Municipality': 'Vejle',
#   'RegionName': 'Syddanmark',
#   'ConnectionPointLatitude': 55.722518,
#   'ConnectionPointLongitude': 9.468814,
#   'NetCompanyName': 'N1',
#   'region_code': 'dk_mun_630'},
#  {'_id': 1010,
#   'ConnectionPointCode': 'ØSH',
#   'ConnectionPointName': 'Østerholm',
#   'MunicipalityNo': '370',
#   'Municipality': 'Næstved',
#   'RegionName': 'Sjælland',
#   'ConnectionPointLatitude': 55.20493,
#   'ConnectionPointLongitude': 11.742552,
#   'NetCompanyName': 'Cerius',
#   'region_code': 'dk_mun_370'},
#  {'_id': 1011,
#   'ConnectionPointCode': 'ØSL',
#   'ConnectionPointName': 'Østerlars på Bornholm',
#   'MunicipalityNo': '400',
#   'Municipality': 'Bornholm',
#   'RegionName': 'Hovedstaden',
#   'ConnectionPointLatitude': 55.16532,
#   'ConnectionPointLongitude': 14.96558,
#   'NetCompanyName': 'Trefor El-Net Øst',
#   'region_code': 'dk_mun_400'},
#  {'_id': 1013,
#   'ConnectionPointCode': 'ØTB',
#   'ConnectionPointName': 'Øster Toreby',
#   'MunicipalityNo': '376',
#   'Municipality': 'Guldborgsund',
#   'RegionName': 'Sjælland',
#   'ConnectionPointLatitude': 54.753569,
#   'ConnectionPointLongitude': 11.828558,
#   'NetCompanyName': 'Cerius',
#   'region_code': 'dk_mun_376'},
#  {'_id': 1137,
#   'ConnectionPointCode': 'ØTH',
#   'ConnectionPointName': 'Øster Thorsted',
#   'MunicipalityNo': '630',
#   'Municipality': 'Vejle',
#   'RegionName': 'Syddanmark',
#   'ConnectionPointLatitude': 55.595226,
#   'ConnectionPointLongitude': 9.231355,
#   'NetCompanyName': 'TREFOR',
#   'region_code': 'dk_mun_630'},
#  {'_id': 1138,
#   'ConnectionPointCode': 'ÅBK',
#   'ConnectionPointName': 'Ålbæk',
#   'MunicipalityNo': '813',
#   'Municipality': 'Frederikshavn',
#   'RegionName': 'Nordjylland',
#   'ConnectionPointLatitude': 57.604449,
#   'ConnectionPointLongitude': 10.383519,
#   'NetCompanyName': 'Nord Energi',
#   'region_code': 'dk_mun_813'},
#  {'_id': 1016,
#   'ConnectionPointCode': 'ÅBN',
#   'ConnectionPointName': 'Aabenraa Nord',
#   'MunicipalityNo': '580',
#   'Municipality': 'Aabenraa',
#   'RegionName': 'Syddanmark',
#   'ConnectionPointLatitude': 55.063873,
#   'ConnectionPointLongitude': 9.381327,
#   'NetCompanyName': 'N1',
#   'region_code': 'dk_mun_580'},
#  {'_id': 1017,
#   'ConnectionPointCode': 'ÅBO',
#   'ConnectionPointName': 'Åboulevarden, Horsens',
#   'MunicipalityNo': '615',
#   'Municipality': 'Horsens',
#   'RegionName': 'Midtjylland',
#   'ConnectionPointLatitude': 55.86064,
#   'ConnectionPointLongitude': 9.85348,
#   'NetCompanyName': 'Konstant Syd',
#   'region_code': 'dk_mun_615'},
#  {'_id': 1018,
#   'ConnectionPointCode': 'ÅBS',
#   'ConnectionPointName': 'Aabenraa Syd',
#   'MunicipalityNo': '580',
#   'Municipality': 'Aabenraa',
#   'RegionName': 'Syddanmark',
#   'ConnectionPointLatitude': 55.034406,
#   'ConnectionPointLongitude': 9.41483,
#   'NetCompanyName': 'N1',
#   'region_code': 'dk_mun_580'},
#  {'_id': 1019,
#   'ConnectionPointCode': 'ÅBY',
#   'ConnectionPointName': 'Åbybro',
#   'MunicipalityNo': '810',
#   'Municipality': 'Brønderslev',
#   'RegionName': 'Nordjylland',
#   'ConnectionPointLatitude': 57.155593,
#   'ConnectionPointLongitude': 9.748023,
#   'NetCompanyName': 'N1',
#   'region_code': 'dk_mun_810'},
#  {'_id': 1020,
#   'ConnectionPointCode': 'ÅBØ',
#   'ConnectionPointName': 'Aalborg Øst',
#   'MunicipalityNo': '851',
#   'Municipality': 'Aalborg',
#   'RegionName': 'Nordjylland',
#   'ConnectionPointLatitude': 57.048548,
#   'ConnectionPointLongitude': 10.033046,
#   'NetCompanyName': 'N1',
#   'region_code': 'dk_mun_851'},
#  {'_id': 1021,
#   'ConnectionPointCode': 'ÅCH',
#   'ConnectionPointName': 'Århus Container Havn',
#   'MunicipalityNo': '751',
#   'Municipality': 'Aarhus',
#   'RegionName': 'Midtjylland',
#   'ConnectionPointLatitude': 56.14482,
#   'ConnectionPointLongitude': 10.23207,
#   'NetCompanyName': 'Konstant Nord',
#   'region_code': 'dk_mun_751'},
#  {'_id': 1022,
#   'ConnectionPointCode': 'ÅDU',
#   'ConnectionPointName': 'Ådum',
#   'MunicipalityNo': '760',
#   'Municipality': 'Ringkøbing-Skjern',
#   'RegionName': 'Midtjylland',
#   'ConnectionPointLatitude': 55.871754,
#   'ConnectionPointLongitude': 8.605894,
#   'NetCompanyName': 'N1',
#   'region_code': 'dk_mun_760'},
#  {'_id': 1023,
#   'ConnectionPointCode': 'ÅGE',
#   'ConnectionPointName': 'Ågerup',
#   'MunicipalityNo': '316',
#   'Municipality': 'Holbæk',
#   'RegionName': 'Sjælland',
#   'ConnectionPointLatitude': 55.655788,
#   'ConnectionPointLongitude': 11.752093,
#   'NetCompanyName': 'Cerius',
#   'region_code': 'dk_mun_316'},
#  {'_id': 1139,
#   'ConnectionPointCode': 'ÅKB',
#   'ConnectionPointName': 'Åkirkeby',
#   'MunicipalityNo': '400',
#   'Municipality': 'Bornholm',
#   'RegionName': 'Hovedstaden',
#   'ConnectionPointLatitude': 55.068155,
#   'ConnectionPointLongitude': 14.897913,
#   'NetCompanyName': 'Trefor El-Net Øst',
#   'region_code': 'dk_mun_400'},
#  {'_id': 1025,
#   'ConnectionPointCode': 'ÅLE',
#   'ConnectionPointName': 'Ålestrup',
#   'MunicipalityNo': '820',
#   'Municipality': 'Vesthimmerland',
#   'RegionName': 'Nordjylland',
#   'ConnectionPointLatitude': 56.704865,
#   'ConnectionPointLongitude': 9.488229,
#   'NetCompanyName': 'N1',
#   'region_code': 'dk_mun_820'},
#  {'_id': 1026,
#   'ConnectionPointCode': 'ÅLG',
#   'ConnectionPointName': 'Ålegård',
#   'MunicipalityNo': '621',
#   'Municipality': 'Kolding',
#   'RegionName': 'Syddanmark',
#   'ConnectionPointLatitude': 55.48859,
#   'ConnectionPointLongitude': 9.468402,
#   'NetCompanyName': 'TREFOR',
#   'region_code': 'dk_mun_621'},
#  {'_id': 1027,
#   'ConnectionPointCode': 'ÅRN',
#   'ConnectionPointName': 'Aars Nord',
#   'MunicipalityNo': '820',
#   'Municipality': 'Vesthimmerland',
#   'RegionName': 'Nordjylland',
#   'ConnectionPointLatitude': 56.819102,
#   'ConnectionPointLongitude': 9.500129,
#   'NetCompanyName': 'N1',
#   'region_code': 'dk_mun_820'},
#  {'_id': 1028,
#   'ConnectionPointCode': 'ÅRP',
#   'ConnectionPointName': 'Årup',
#   'MunicipalityNo': '410',
#   'Municipality': 'Middelfart',
#   'RegionName': 'Syddanmark',
#   'ConnectionPointLatitude': 55.38224,
#   'ConnectionPointLongitude': 10.055981,
#   'NetCompanyName': 'VORES ELNET A/S',
#   'region_code': 'dk_mun_410'},
#  {'_id': 1029,
#   'ConnectionPointCode': 'ÅRR',
#   'ConnectionPointName': 'Årre',
#   'MunicipalityNo': '561',
#   'Municipality': 'Esbjerg',
#   'RegionName': 'Syddanmark',
#   'ConnectionPointLatitude': 55.564502,
#   'ConnectionPointLongitude': 8.704184,
#   'NetCompanyName': 'N1',
#   'region_code': 'dk_mun_561'}]

# %%
metadata = service.fetch_metadata()
data = service.fetch_data()

# %%
connection_points = {
    row["ConnectionPointCode"] : row for row in data
}

# %%
# ws = openpyxl.load_workbook("../Energinet Extra Codes.xlsx").active

# [column_names, *rows] = list(ws.values)
# extra_station_codes = {}
# for row in rows:
#     d = dict(zip(column_names, row))
#     if d["Code"] is not None:
#         extra_station_codes[d["Name"]] = d["Code"]

# %%
# extra_station_codes

# %%
extra_station_codes = {
    'A2': 'BJS',
    'AMF_132_F': 'AMV',
    'HASØ132_F': 'HAS',
    'ISHN132_N-$': 'ISH',
    'MRP1': 'TEG',
    'VSAK132_S1': 'VAL',
    'BIX_150_S1': 'BIL',
    'FRX_150_S1': 'FRT',
    'I4': 'ABS',
    'KLT_150_S1': 'KLF',
    'VKHI012_SFIK': 'VKE',
    'term_KT51-HT3': 'TJE',
}

# %%
import io
import urllib.request

# %%
netdata_url = "https://energinet.dk/-/media/76C3D434A7E2499F94E7DB66D3A2DE21.xlsx?la=da&hash=638E165AA57F627409CB9394D56D53614F5D7336"

with urllib.request.urlopen(netdata_url) as fileobj:
    buf = io.BytesIO()
    buf.write(fileobj.read())

buf.seek(0)
wb = openpyxl.load_workbook(buf)

# %%
wb.sheetnames
# Out:
# ['Bus',
#  'Line',
#  'Transformer2',
#  'Transformer3',
#  'Generator',
#  'Load',
#  'Shunt',
#  'HVDC',
#  'PFModelInfo',
#  'Ark1',
#  'Ark2',
#  'Ark3']

# %%
import networkx as nx

# %%
def get_sheet_data(ws):
    [_1, _2, _3, header, *rows] = ws.values
    for row in rows:
        yield {k: v for k, v in zip(header, row)}

# %%
import re
def match_bus_to_code(d, codes, extra_codes):
    extensions = {
        "ENDKW": "V",
        "ENDKE": "Ø"
    }
    name = d["Bus Name"]
    if name in extra_codes and extra_codes[name] in codes:
        return extra_codes[name]
    name_regex = re.compile(r"([^0-9_]+)_?(\d*)_?(.*)")
    match = name_regex.match(name)
    if not match:
        return
    bus_code = match.groups()[0]
    if bus_code in codes:
        return bus_code
    star_codes = [f"{bus_code}*", f"{bus_code}**", f"{bus_code}***"]
    for star_code in star_codes:
        if star_code in codes:
            return star_code
    if d["Location Name"] in extensions:
        area_code = bus_code + extensions[d["Location Name"]]
        if area_code in codes:
            return area_code

# %%
energy_grid = nx.Graph()

# %%
bus_labels = {}
for d in get_sheet_data(wb["Bus"]):
    node_label = ("Bus", d["Bus Name"])
    bus_labels[d["Bus Index"]] = node_label
    attributes = {k: v for k, v in d.items()}
    connection_code = match_bus_to_code(d, list(connection_points), extra_station_codes)
    if connection_code is not None:
        attributes.update(connection_points[connection_code])
    energy_grid.add_nodes_from([(node_label, attributes)])

# %%
for d in get_sheet_data(wb["Line"]):
    energy_grid.add_edges_from([(bus_labels[d["Node 1"]], bus_labels[d["Node 2"]], d)])

# %%
for d in get_sheet_data(wb["Transformer2"]):
    node_label = ("Transformer3", d["2-Transformer Name"])    
    energy_grid.add_nodes_from([(node_label, d)])
    energy_grid.add_edges_from([
        (bus_labels[d["High.V Bus Index"]], node_label), 
        (bus_labels[d["Low.V Bus Index"]], node_label)
    ])

# %%
for d in get_sheet_data(wb["Transformer3"]):
    node_label = ("Transformer3", d["3_Transformer Name"])
    energy_grid.add_nodes_from([(node_label, d)])
    edges = [
        (bus_labels[d["High.V Bus Index"]], node_label),
        (bus_labels[d["Mid.V Bus Index"]], node_label),        
        (bus_labels[d["Low.V Bus Index"]], node_label)
    ]
    energy_grid.add_edges_from(edges)

# %%
for d in get_sheet_data(wb["Generator"]):
    node_label = ("Generator", d["Generator Name"])
    energy_grid.add_nodes_from([(node_label, d)])
    energy_grid.add_edge(node_label, bus_labels[d["Bus Index"]])

# %%
for d in get_sheet_data(wb["Load"]):
    node_label = ("Load", d["Load Name"])
    energy_grid.add_nodes_from([(node_label, d)])
    energy_grid.add_edge(node_label, bus_labels[d["Load Index"]])

# %%
for d in get_sheet_data(wb["Shunt"]):
    node_label = ("Shunt", d["Shunt Name"])
    energy_grid.add_nodes_from([(node_label, d)])
    energy_grid.add_edge(node_label, bus_labels[d["Bus Index"]])

# %%
for d in get_sheet_data(wb["HVDC"]):
    node_label = ("HVDC", d["HVDC Name"])
    energy_grid.add_nodes_from([(node_label, d)])
    energy_grid.add_edge(node_label, bus_labels[d["Bus Index"]])

# %%
[len(x) for x in nx.connected_components(energy_grid)]
# Out:
# [451, 561, 1, 1]

# %%
[x for x in nx.connected_components(energy_grid) if len(x) == 1]
# Out:
# [{('Bus', 'EDR_400_NIE1')}, {('Bus', 'EDR_400_NIE1(1)')}]

# %%
[(n, v) for n, v in energy_grid.nodes.items() if n[0] == "Bus" and "region_code" not in v and v["Location Name"] in ["ENDKE", "ENDKW"]]
# Out:
# [(('Bus', 'AHA_220_S1'),
#   {'Bus Index': 195,
#    'Bus Name': 'AHA_220_S1',
#    'Station Full Name': 'Anholt Havmøllepark',
#    'Location Name': 'ENDKW',
#    'Voltage base[kV]': '232,0',
#    'Voltage min[pu]': '0,98',
#    'Voltage max[pu]': '1,02'}),
#  (('Bus', 'DDS_1321_SFIK'),
#   {'Bus Index': 85,
#    'Bus Name': 'DDS_1321_SFIK',
#    'Station Full Name': '132 KV STATION STÅLVALSEVÆRKET',
#    'Location Name': 'ENDKE',
#    'Voltage base[kV]': '132,0',
#    'Voltage min[pu]': '0,95',
#    'Voltage max[pu]': '1,05'}),
#  (('Bus', 'DDS_1322_SFIK'),
#   {'Bus Index': 86,
#    'Bus Name': 'DDS_1322_SFIK',
#    'Station Full Name': '132 KV STATION STÅLVALSEVÆRKET',
#    'Location Name': 'ENDKE',
#    'Voltage base[kV]': '132,0',
#    'Voltage min[pu]': '0,95',
#    'Voltage max[pu]': '1,05'}),
#  (('Bus', 'FEM_132_F'),
#   {'Bus Index': 90,
#    'Bus Name': 'FEM_132_F',
#    'Station Full Name': '132 KV STATION FEMERN',
#    'Location Name': 'ENDKE',
#    'Voltage base[kV]': '132,0',
#    'Voltage min[pu]': '0,00',
#    'Voltage max[pu]': '1,05'}),
#  (('Bus', 'HKS_010_S1'),
#   {'Bus Index': 106,
#    'Bus Name': 'HKS_010_S1',
#    'Station Full Name': 'Herslev',
#    'Location Name': 'ENDKE',
#    'Voltage base[kV]': '10,0',
#    'Voltage min[pu]': '0,00',
#    'Voltage max[pu]': '1,05'}),
#  (('Bus', 'HKS_016'),
#   {'Bus Index': 107,
#    'Bus Name': 'HKS_016',
#    'Station Full Name': 'Herslev',
#    'Location Name': 'ENDKE',
#    'Voltage base[kV]': '15,8',
#    'Voltage min[pu]': '0,00',
#    'Voltage max[pu]': '1,05'}),
#  (('Bus', 'HKS_400_S1'),
#   {'Bus Index': 108,
#    'Bus Name': 'HKS_400_S1',
#    'Station Full Name': '400 KV KOBLINGSSTATION HERSLEV',
#    'Location Name': 'ENDKE',
#    'Voltage base[kV]': '400,0',
#    'Voltage min[pu]': '0,95',
#    'Voltage max[pu]': '1,05'}),
#  (('Bus', 'HRC_220_S1'),
#   {'Bus Index': 242,
#    'Bus Name': 'HRC_220_S1',
#    'Station Full Name': 'Horns Rev C',
#    'Location Name': 'ENDKW',
#    'Voltage base[kV]': '232,0',
#    'Voltage min[pu]': '0,00',
#    'Voltage max[pu]': '1,05'}),
#  (('Bus', 'KARA132_F'),
#   {'Bus Index': 126,
#    'Bus Name': 'KARA132_F',
#    'Station Full Name': 'KARA Novoren Roskilde',
#    'Location Name': 'ENDKE',
#    'Voltage base[kV]': '132,0',
#    'Voltage min[pu]': '0,00',
#    'Voltage max[pu]': '1,05'}),
#  (('Bus', 'KFA_220_S1'),
#   {'Bus Index': 129,
#    'Bus Name': 'KFA_220_S1',
#    'Station Full Name': 'Kriegers Flak A',
#    'Location Name': 'ENDKE',
#    'Voltage base[kV]': '232,0',
#    'Voltage min[pu]': '0,00',
#    'Voltage max[pu]': '1,05'}),
#  (('Bus', 'KFB_220_S1'),
#   {'Bus Index': 130,
#    'Bus Name': 'KFB_220_S1',
#    'Station Full Name': 'Kriegers Flak B',
#    'Location Name': 'ENDKE',
#    'Voltage base[kV]': '232,0',
#    'Voltage min[pu]': '0,00',
#    'Voltage max[pu]': '1,05'}),
#  (('Bus', 'KFE_000_S1'),
#   {'Bus Index': 131,
#    'Bus Name': 'KFE_000_S1',
#    'Station Full Name': 'Kriegers Flak C',
#    'Location Name': 'ENDKE',
#    'Voltage base[kV]': '0,4',
#    'Voltage min[pu]': '0,00',
#    'Voltage max[pu]': '1,05'}),
#  (('Bus', 'KFE_010_S1'),
#   {'Bus Index': 132,
#    'Bus Name': 'KFE_010_S1',
#    'Station Full Name': 'Kriegers Flak C',
#    'Location Name': 'ENDKE',
#    'Voltage base[kV]': '10,0',
#    'Voltage min[pu]': '0,00',
#    'Voltage max[pu]': '1,05'}),
#  (('Bus', 'KFE_150_S1'),
#   {'Bus Index': 133,
#    'Bus Name': 'KFE_150_S1',
#    'Station Full Name': 'Kriegers Flak C',
#    'Location Name': 'ENDKE',
#    'Voltage base[kV]': '150,0',
#    'Voltage min[pu]': '0,00',
#    'Voltage max[pu]': '1,05'}),
#  (('Bus', 'KFE_220_S1'),
#   {'Bus Index': 134,
#    'Bus Name': 'KFE_220_S1',
#    'Station Full Name': 'Kriegers Flak C',
#    'Location Name': 'ENDKE',
#    'Voltage base[kV]': '232,0',
#    'Voltage min[pu]': '0,00',
#    'Voltage max[pu]': '1,05'}),
#  (('Bus', 'LKR_150_S2'),
#   {'Bus Index': 263,
#    'Bus Name': 'LKR_150_S2',
#    'Station Full Name': 'Lemkær',
#    'Location Name': 'ENDKW',
#    'Voltage base[kV]': '165,0',
#    'Voltage min[pu]': '0,97',
#    'Voltage max[pu]': '1,01'}),
#  (('Bus', 'NYM_132_SFIK1'),
#   {'Bus Index': 155,
#    'Bus Name': 'NYM_132_SFIK1',
#    'Station Full Name': 'Nymøllegård',
#    'Location Name': 'ENDKE',
#    'Voltage base[kV]': '132,0',
#    'Voltage min[pu]': '0,95',
#    'Voltage max[pu]': '1,05'}),
#  (('Bus', 'NYM_132_SFIK2'),
#   {'Bus Index': 156,
#    'Bus Name': 'NYM_132_SFIK2',
#    'Station Full Name': 'Nymøllegård',
#    'Location Name': 'ENDKE',
#    'Voltage base[kV]': '132,0',
#    'Voltage min[pu]': '0,95',
#    'Voltage max[pu]': '1,05'}),
#  (('Bus', 'OVE_150_S1'),
#   {'Bus Index': 284,
#    'Bus Name': 'OVE_150_S1',
#    'Station Full Name': 'Odense Vest',
#    'Location Name': 'ENDKW',
#    'Voltage base[kV]': '165,0',
#    'Voltage min[pu]': '0,00',
#    'Voltage max[pu]': '1,05'}),
#  (('Bus', 'RDB_132_SFIK'),
#   {'Bus Index': 163,
#    'Bus Name': 'RDB_132_SFIK',
#    'Station Full Name': 'VINDMØLLEPARK RØDSAND 2',
#    'Location Name': 'ENDKE',
#    'Voltage base[kV]': '132,0',
#    'Voltage min[pu]': '0,91',
#    'Voltage max[pu]': '1,10'}),
#  (('Bus', 'REV_400_S1-'),
#   {'Bus Index': 286,
#    'Bus Name': 'REV_400_S1-',
#    'Station Full Name': '400 KV STATION REVSING',
#    'Location Name': 'ENDKW',
#    'Voltage base[kV]': '400,0',
#    'Voltage min[pu]': '0,00',
#    'Voltage max[pu]': '1,05'}),
#  (('Bus', 'SKLØ132_F'),
#   {'Bus Index': 168,
#    'Bus Name': 'SKLØ132_F',
#    'Station Full Name': 'Skuderløse',
#    'Location Name': 'ENDKE',
#    'Voltage base[kV]': '132,0',
#    'Voltage min[pu]': '0,00',
#    'Voltage max[pu]': '1,05'}),
#  (('Bus', 'TOL_220_S1'),
#   {'Bus Index': 178,
#    'Bus Name': 'TOL_220_S1',
#    'Station Full Name': 'Tolstrup Gårde',
#    'Location Name': 'ENDKE',
#    'Voltage base[kV]': '232,0',
#    'Voltage min[pu]': '0,95',
#    'Voltage max[pu]': '1,04'}),
#  (('Bus', 'VKE_019_S1'),
#   {'Bus Index': 337,
#    'Bus Name': 'VKE_019_S1',
#    'Station Full Name': 'VESTKRAFT',
#    'Location Name': 'ENDKW',
#    'Voltage base[kV]': '19,0',
#    'Voltage min[pu]': '1,02',
#    'Voltage max[pu]': '1,03'}),
#  (('Bus', 'VKE_150_S1'),
#   {'Bus Index': 338,
#    'Bus Name': 'VKE_150_S1',
#    'Station Full Name': '150 kV STATION VESTKRAFT',
#    'Location Name': 'ENDKW',
#    'Voltage base[kV]': '165,0',
#    'Voltage min[pu]': '0,88',
#    'Voltage max[pu]': '1,03'}),
#  (('Bus', 'VKHI012_SFIK'),
#   {'Bus Index': 237,
#    'Bus Name': 'VKHI012_SFIK',
#    'Station Full Name': 'VESTKRAFT',
#    'Location Name': 'ENDKW',
#    'Voltage base[kV]': '11,5',
#    'Voltage min[pu]': '1,02',
#    'Voltage max[pu]': '1,03'}),
#  (('Bus', 'VSA_132_S1'),
#   {'Bus Index': 186,
#    'Bus Name': 'VSA_132_S1',
#    'Station Full Name': 'Valseværket smelteri, Vorskla',
#    'Location Name': 'ENDKE',
#    'Voltage base[kV]': '132,0',
#    'Voltage min[pu]': '0,00',
#    'Voltage max[pu]': '1,05'}),
#  (('Bus', 'ØSV_132_F'),
#   {'Bus Index': 189,
#    'Bus Name': 'ØSV_132_F',
#    'Station Full Name': 'Ørslevvester',
#    'Location Name': 'ENDKE',
#    'Voltage base[kV]': '132,0',
#    'Voltage min[pu]': '0,00',
#    'Voltage max[pu]': '1,05'}),
#  (('Bus', 'ØSV_400_F'),
#   {'Bus Index': 190,
#    'Bus Name': 'ØSV_400_F',
#    'Station Full Name': 'Ørslevvester',
#    'Location Name': 'ENDKE',
#    'Voltage base[kV]': '400,0',
#    'Voltage min[pu]': '0,00',
#    'Voltage max[pu]': '1,05'})]

# %%
{k: v for k, v in connection_points.items() if "skuder" in v["ConnectionPointName"].lower()}
# Out:
# {}

# %%
g0 = energy_grid
g = g0.copy()
# split_nodes = [n for n, data in g0.nodes.items() if "region_code" in data]
split_nodes = [n for n, data in g0.nodes.items() if n[0] == "Bus"]
split_mapping = {}
for n in split_nodes:
    edges = g[n]
    data = g.nodes[n]
    g.remove_node(n)
    g.remove_edges_from(n)
    for i, (neighbour, edge_data) in enumerate(edges.items()):
        split_node = (i, n)
        g.add_nodes_from([(split_node, data)])
        g.add_edges_from([(split_node, neighbour, edge_data)])
        split_mapping[split_node] = n

# %%
g_ccs = [g.subgraph(cc) for cc in nx.connected_components(g) if len(cc) > 2]
g_ccs = sorted(g_ccs, key=lambda x: -len(x))
len(g_ccs)
# Out:
# 70

# %%
extra_connections = [set(split_mapping[k] for k, v in cc.nodes.items() if k in split_mapping) for cc in g_ccs]
extra_edges = set(tuple(sorted((a, b))) for x in extra_connections for a in x for b in x if a != b)
extra_edges
# Out:
# {(('Bus', 'A2'), ('Bus', 'BJS_220_SFIK')),
#  (('Bus', 'A2'), ('Bus', 'BJS_400_K')),
#  (('Bus', 'ABS_150_S2-'), ('Bus', 'I4')),
#  (('Bus', 'AMV_010_SFIK'), ('Bus', 'AMV_132_A')),
#  (('Bus', 'AMV_0173_SFIK'), ('Bus', 'AMV_132_A')),
#  (('Bus', 'ASR_150_S2'), ('Bus', 'ASR_400_S1')),
#  (('Bus', 'ASV_0122_SFIK'), ('Bus', 'ASV_132_F')),
#  (('Bus', 'ASV_0215_SFIK'), ('Bus', 'ASV_400_K')),
#  (('Bus', 'ASV_132_F'), ('Bus', 'ASV_4001_SFIK')),
#  (('Bus', 'ASV_4001_SFIK'), ('Bus', 'ASV_400_K')),
#  (('Bus', 'AVV_0122_SFIK'), ('Bus', 'AVV_0123_SFIK')),
#  (('Bus', 'AVV_0122_SFIK'), ('Bus', 'AVV_400_SK.K')),
#  (('Bus', 'AVV_0123_SFIK'), ('Bus', 'AVV_400_SK.K')),
#  (('Bus', 'AVV_0171_SFIK'), ('Bus', 'AVV_132_F')),
#  (('Bus', 'AVV_0201_SFIK'), ('Bus', 'AVV_400_SK.K')),
#  (('Bus', 'AVV_132_F'), ('Bus', 'AVV_132_SFIK')),
#  (('Bus', 'AVV_132_SFIK'), ('Bus', 'AVV_400_SK.K')),
#  (('Bus', 'BJS_016'), ('Bus', 'BJS_400_K')),
#  (('Bus', 'BJS_132_SFIK'), ('Bus', 'BJS_400_K')),
#  (('Bus', 'EBY'), ('Bus', 'LIN_132_F')),
#  (('Bus', 'EDR_015_SFIK'), ('Bus', 'EDR_150_SV')),
#  (('Bus', 'EDR_015_SFIK'), ('Bus', 'EDR_400_S1')),
#  (('Bus', 'EDR_150_SV'), ('Bus', 'EDR_400_S1')),
#  (('Bus', 'EDR_150_SØ2'), ('Bus', 'EDR_400_S1')),
#  (('Bus', 'EDR_220_S1'), ('Bus', 'EDR_400_S1')),
#  (('Bus', 'FER_150_S1'), ('Bus', 'FER_400_S1')),
#  (('Bus', 'FGD_010_S1'), ('Bus', 'FGD_016')),
#  (('Bus', 'FGD_010_S1'), ('Bus', 'FGD_400_S1')),
#  (('Bus', 'FGD_016'), ('Bus', 'FGD_400_S1')),
#  (('Bus', 'FGD_150_S1'), ('Bus', 'FGD_400_S1')),
#  (('Bus', 'FVO_010_SFIK'), ('Bus', 'FVO_150_S1')),
#  (('Bus', 'FVO_021A_SFIK'), ('Bus', 'FVO_400_SFIK')),
#  (('Bus', 'GLN_010D_SFIK1'), ('Bus', 'GLN_132_F')),
#  (('Bus', 'GLN_010D_SFIK1'), ('Bus', 'GLN_400_SK.L')),
#  (('Bus', 'GLN_010D_SFIK2'), ('Bus', 'GLN_132_F')),
#  (('Bus', 'GLN_010D_SFIK2'), ('Bus', 'GLN_400_SK.L')),
#  (('Bus', 'GLN_132_F'), ('Bus', 'GLN_400_SK.L')),
#  (('Bus', 'GØR_132_F'), ('Bus', 'GØR_132_SFIK')),
#  (('Bus', 'GØR_132_SFIK'), ('Bus', 'GØR_400_SKM2')),
#  (('Bus', 'HCV_132_A'), ('Bus', 'HCV_400_SK.A')),
#  (('Bus', 'HKS_010_S1'), ('Bus', 'HKS_016')),
#  (('Bus', 'HKS_010_S1'), ('Bus', 'HKS_400_S1')),
#  (('Bus', 'HKS_016'), ('Bus', 'HKS_400_S1')),
#  (('Bus', 'HVE_132_F'), ('Bus', 'HVE_400_')),
#  (('Bus', 'IDU_150_N'), ('Bus', 'IDU_400_S1')),
#  (('Bus', 'ISH_132_F'), ('Bus', 'ISH_400_SK.K')),
#  (('Bus', 'ISH_220_S1'), ('Bus', 'ISH_400_SK.K')),
#  (('Bus', 'KAS_150_SA'), ('Bus', 'KAS_400_S1')),
#  (('Bus', 'KFE_000_S1'), ('Bus', 'KFE_010_S1')),
#  (('Bus', 'KFE_010_S1'), ('Bus', 'KFE_150_S1')),
#  (('Bus', 'KFE_010_S1'), ('Bus', 'KFE_220_S1')),
#  (('Bus', 'KFE_150_S1'), ('Bus', 'KFE_220_S1')),
#  (('Bus', 'KIN_150_S1'), ('Bus', 'KIN_400_S1')),
#  (('Bus', 'KYV_0102_SFIK'), ('Bus', 'KYV_0103_SFIK')),
#  (('Bus', 'KYV_0102_SFIK'), ('Bus', 'KYV_132_SK.F')),
#  (('Bus', 'KYV_0103_SFIK'), ('Bus', 'KYV_132_SK.F')),
#  (('Bus', 'KYV_0181_SFIK'), ('Bus', 'KYV_132_SK.F')),
#  (('Bus', 'KYV_0182_SFIK'), ('Bus', 'KYV_132_SK.F')),
#  (('Bus', 'LAG_150_S1'), ('Bus', 'LAG_400_S1')),
#  (('Bus', 'MAL_150_S1'), ('Bus', 'MAL_400_S1')),
#  (('Bus', 'MKS_019A_SFIK'), ('Bus', 'MKS_150_S1')),
#  (('Bus', 'MKS_019B_SFIK'), ('Bus', 'MKS_400_SFIK')),
#  (('Bus', 'NVV_021A_SFIK'), ('Bus', 'NVV_400_S1')),
#  (('Bus', 'NVV_021B_SFIK'), ('Bus', 'NVV_150_S1')),
#  (('Bus', 'NVV_150_S1'), ('Bus', 'NVV_400_S1')),
#  (('Bus', 'RAD_009_SFIK'), ('Bus', 'RAD_132_F')),
#  (('Bus', 'SHE_021_SFIK'), ('Bus', 'SHE_150_SV1')),
#  (('Bus', 'SHE_150_SV1'), ('Bus', 'VKHI012_SFIK')),
#  (('Bus', 'STV_0182_SFIK'), ('Bus', 'STV_132_F')),
#  (('Bus', 'SVS_021_SFIK'), ('Bus', 'SVS_400_SFIK')),
#  (('Bus', 'TJE_010_S3'), ('Bus', 'term_KT51-HT3')),
#  (('Bus', 'TJE_013_SFIK'), ('Bus', 'TJE_150_S11')),
#  (('Bus', 'TJE_150_S1'), ('Bus', 'TJE_400_S1')),
#  (('Bus', 'TJE_150_S11'), ('Bus', 'TJE_400_S1')),
#  (('Bus', 'TJE_150_S11'), ('Bus', 'term_KT51-HT3')),
#  (('Bus', 'TJE_400_S1'), ('Bus', 'term_KT51-HT3')),
#  (('Bus', 'TRI_150_S1'), ('Bus', 'TRI_400_S1')),
#  (('Bus', 'TRI_220_S1'), ('Bus', 'TRI_400_S1')),
#  (('Bus', 'VHA_010_SFIK'), ('Bus', 'VHA_012_SFIK')),
#  (('Bus', 'VHA_010_SFIK'), ('Bus', 'VHA_150_S1-')),
#  (('Bus', 'VHA_012_SFIK'), ('Bus', 'VHA_150_S1-')),
#  (('Bus', 'VHA_150_S1-'), ('Bus', 'VHA_400_S1')),
#  (('Bus', 'VKE_019_S1'), ('Bus', 'VKE_150_S1')),
#  (('Bus', 'ØSV_132_F'), ('Bus', 'ØSV_400_F'))}

# %%
g2 = g_ccs[0]
layout = nx.layout.kamada_kawai_layout(g2)

# %%
import plotly.graph_objs as go
import numpy as np

traces = []
lines = []
points = []
node_keys = list(layout.keys())
for k in node_keys:
    points.append(layout[k])
for n1, n2 in g2.edges:
    lines.append(layout[n1])
    lines.append(layout[n2])
    lines.append([np.nan, np.nan])


traces.append({"x": [p[0] for p in lines], "y": [p[1] for p in lines],  "mode": "lines"})
traces.append({"x": [p[0] for p in points], "y": [p[1] for p in points], "text": node_keys, "mode": "markers"})
go.Figure(data=traces).show()
# Out:
# <div>                            <div id="3ab4bd12-afe2-4c9d-9041-3b912f910188" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3ab4bd12-afe2-4c9d-9041-3b912f910188")) {                    Plotly.newPlot(                        "3ab4bd12-afe2-4c9d-9041-3b912f910188",                        [{"mode":"lines","x":[0.48805464824128186,0.2928211244099535,null,0.1438522151699051,0.2928211244099535,null,0.1438522151699051,0.1291268226525941,null,0.1438522151699051,0.24411219206310533,null,0.1438522151699051,0.13823169805062913,null,0.1438522151699051,0.30166242630624945,null,0.1438522151699051,-0.02327649477622786,null,0.1438522151699051,0.03595207546792861,null,0.1438522151699051,-0.03574190734540414,null,-0.19378588636713068,-0.2059575591933053,null,-0.19378588636713068,-0.2683348247600453,null,-0.19378588636713068,-0.0908683358922414,null,-0.2059575591933053,-0.2188040513614583,null,0.43885580992594964,0.2928211244099535,null,-0.7339649492768622,-0.5591169542945701,null,0.1291268226525941,0.2928211244099535,null,0.1291268226525941,-0.04033154695260758,null,0.1291268226525941,0.15695095080854546,null,0.1291268226525941,0.2681667456455776,null,-0.04033154695260758,-0.1818986285770786,null,-0.0908683358922414,-0.16904799547921953,null,-0.16904799547921953,-0.2683348247600453,null,-0.16904799547921953,-0.1818986285770786,null,0.2928211244099535,0.4593263736490358,null,-0.5591169542945701,-0.37598394811460445,null,-0.37598394811460445,-0.1818986285770786,null],"y":[-0.2052445389063574,-0.22287707028122525,null,-0.3419418503110359,-0.22287707028122525,null,-0.3419418503110359,-0.14214825616605903,null,-0.3419418503110359,-0.5142217068896069,null,-0.3419418503110359,-0.5360452063410649,null,-0.3419418503110359,-0.42830566823511707,null,-0.3419418503110359,-0.32586163786077826,null,-0.3419418503110359,-0.5075672977825603,null,-0.3419418503110359,-0.42987327531901665,null,0.6556202357414759,0.8305527086401383,null,0.6556202357414759,0.48693968706486546,null,0.6556202357414759,0.5052830135520636,null,0.8305527086401383,1.0,null,-0.0899846779398599,-0.22287707028122525,null,0.016517269464770747,0.04513533979706557,null,-0.14214825616605903,-0.22287707028122525,null,-0.14214825616605903,-0.013709838365390081,null,-0.14214825616605903,0.011116467379567813,null,-0.14214825616605903,0.0007913924642666112,null,-0.013709838365390081,0.1291876886424876,null,0.5052830135520636,0.3290234780459485,null,0.3290234780459485,0.48693968706486546,null,0.3290234780459485,0.1291876886424876,null,-0.22287707028122525,-0.33150467968625635,null,0.04513533979706557,0.07911842329167794,null,0.07911842329167794,0.1291876886424876,null],"type":"scatter"},{"mode":"markers","text":["('Generator', 'KFA_220')","('Bus', 'TOL_220_S1')","('Bus', 'BA2_150_SFIK')","('Bus', 'BWT_400_SFIK')","('Shunt', 'KFA_220-ZL1')","('Bus', 'KFE_000_S1')","('Bus', 'KFB_220_S1')","('Bus', 'KFE_220_S1')","('Load', 'l_KFB_220')","('Load', 'l_BWT_400')","('Shunt', 'TOL_220-ZL2')","('Bus', 'XDE_DS11')","('Bus', 'KFE_150_S1')","('Bus', 'KFA_220_S1')","('Transformer3', 'KFE_010_000-T12')","('Bus', 'KFE_010_S1')","('Shunt', 'TOL_220-ZL4')","(0, ('Bus', 'ISH_220_S1'))","('Shunt', 'TOL_220-ZL1')","('Shunt', 'TOL_220-ZL3')","('Bus', 'XDE_DS12')","('Load', 'l_KFA_220')","('Transformer3', 'KFE_220_150_010-T31--$')","('Generator', 'KFB_220')","(0, ('Bus', 'BJS_220_SFIK'))"],"x":[0.48805464824128186,0.1438522151699051,-0.19378588636713068,-0.2059575591933053,0.43885580992594964,-0.7339649492768622,0.1291268226525941,-0.04033154695260758,0.2681667456455776,-0.2188040513614583,0.13823169805062913,-0.0908683358922414,-0.16904799547921953,0.2928211244099535,-0.5591169542945701,-0.37598394811460445,-0.02327649477622786,-0.03574190734540414,0.24411219206310533,0.30166242630624 ...

# %%
energy_grid[next(iter(energy_grid.nodes()))]
# Out:
# AtlasView({('Transformer3', 'BJS_220_2201-T31'): {}, ('Transformer3', 'BJS_400_220-T43'): {}})

# %%
cross_municipality_lines = []
for n1, n2 in list(energy_grid.edges) + list(extra_edges):
    try:
        r1 = energy_grid.nodes[n1]["region_code"]
        r2 = energy_grid.nodes[n2]["region_code"]
    except KeyError:
        continue
    if r1 != r2:
        cross_municipality_lines.append((n1, n2))
len(cross_municipality_lines)
# Out:
# 146

# %%
def node_point(node):
    x = energy_grid.nodes[node]
    return (x["ConnectionPointLatitude"], x["ConnectionPointLongitude"])

connection_lines = [(node_point(n1), node_point(n2)) for n1, n2 in cross_municipality_lines]

import json
with open("connection_points.json", "w+") as fileobj:
    json.dump(connection_lines, fileobj)

# %%
municipality_nodes = {k: v["region_code"] for k, v in energy_grid.nodes.items() if "region_code" in v}
municipality_nodes

# %%
municipality_connections = set()
for n1, n2 in energy_grid.edges:
    try:
        m1 = municipality_nodes[n1]
        m2 = municipality_nodes[n2]
        if m2 < m1:
            m1, m2 = m2, m1
        municipality_connections.add((m1, m2))
    except KeyError:
        pass
municipality_connections
# Out:
# {('dk_mun_101', 'dk_mun_101'),
#  ('dk_mun_101', 'dk_mun_159'),
#  ('dk_mun_101', 'dk_mun_167'),
#  ('dk_mun_101', 'dk_mun_185'),
#  ('dk_mun_151', 'dk_mun_240'),
#  ('dk_mun_159', 'dk_mun_159'),
#  ('dk_mun_159', 'dk_mun_161'),
#  ('dk_mun_159', 'dk_mun_240'),
#  ('dk_mun_161', 'dk_mun_161'),
#  ('dk_mun_167', 'dk_mun_183'),
#  ('dk_mun_169', 'dk_mun_183'),
#  ('dk_mun_169', 'dk_mun_240'),
#  ('dk_mun_169', 'dk_mun_265'),
#  ('dk_mun_169', 'dk_mun_350'),
#  ('dk_mun_183', 'dk_mun_240'),
#  ('dk_mun_183', 'dk_mun_259'),
#  ('dk_mun_183', 'dk_mun_265'),
#  ('dk_mun_201', 'dk_mun_217'),
#  ('dk_mun_201', 'dk_mun_219'),
#  ('dk_mun_217', 'dk_mun_219'),
#  ('dk_mun_217', 'dk_mun_260'),
#  ('dk_mun_219', 'dk_mun_219'),
#  ('dk_mun_219', 'dk_mun_240'),
#  ('dk_mun_219', 'dk_mun_260'),
#  ('dk_mun_240', 'dk_mun_240'),
#  ('dk_mun_240', 'dk_mun_250'),
#  ('dk_mun_240', 'dk_mun_259'),
#  ('dk_mun_250', 'dk_mun_250'),
#  ('dk_mun_250', 'dk_mun_350'),
#  ('dk_mun_253', 'dk_mun_269'),
#  ('dk_mun_260', 'dk_mun_260'),
#  ('dk_mun_265', 'dk_mun_265'),
#  ('dk_mun_265', 'dk_mun_350'),
#  ('dk_mun_306', 'dk_mun_316'),
#  ('dk_mun_316', 'dk_mun_326'),
#  ('dk_mun_316', 'dk_mun_350'),
#  ('dk_mun_326', 'dk_mun_326'),
#  ('dk_mun_326', 'dk_mun_350'),
#  ('dk_mun_340', 'dk_mun_350'),
#  ('dk_mun_370', 'dk_mun_370'),
#  ('dk_mun_370', 'dk_mun_376'),
#  ('dk_mun_370', 'dk_mun_390'),
#  ('dk_mun_376', 'dk_mun_376'),
#  ('dk_mun_376', 'dk_mun_390'),
#  ('dk_mun_410', 'dk_mun_410'),
#  ('dk_mun_410', 'dk_mun_461'),
#  ('dk_mun_410', 'dk_mun_607'),
#  ('dk_mun_410', 'dk_mun_621'),
#  ('dk_mun_420', 'dk_mun_479'),
#  ('dk_mun_420', 'dk_mun_540'),
#  ('dk_mun_461', 'dk_mun_461'),
#  ('dk_mun_461', 'dk_mun_479'),
#  ('dk_mun_461', 'dk_mun_621'),
#  ('dk_mun_540', 'dk_mun_580'),
#  ('dk_mun_550', 'dk_mun_561'),
#  ('dk_mun_550', 'dk_mun_580'),
#  ('dk_mun_561', 'dk_mun_561'),
#  ('dk_mun_561', 'dk_mun_573'),
#  ('dk_mun_561', 'dk_mun_575'),
#  ('dk_mun_573', 'dk_mun_573'),
#  ('dk_mun_573', 'dk_mun_657'),
#  ('dk_mun_575', 'dk_mun_575'),
#  ('dk_mun_575', 'dk_mun_621'),
#  ('dk_mun_580', 'dk_mun_580'),
#  ('dk_mun_580', 'dk_mun_621'),
#  ('dk_mun_607', 'dk_mun_607'),
#  ('dk_mun_607', 'dk_mun_621'),
#  ('dk_mun_621', 'dk_mun_621'),
#  ('dk_mun_621', 'dk_mun_630'),
#  ('dk_mun_621', 'dk_mun_751'),
#  ('dk_mun_661', 'dk_mun_665'),
#  ('dk_mun_661', 'dk_mun_671'),
#  ('dk_mun_661', 'dk_mun_760'),
#  ('dk_mun_661', 'dk_mun_791'),
#  ('dk_mun_665', 'dk_mun_671'),
#  ('dk_mun_671', 'dk_mun_787'),
#  ('dk_mun_706', 'dk_mun_707'),
#  ('dk_mun_706', 'dk_mun_751'),
#  ('dk_mun_707', 'dk_mun_751'),
#  ('dk_mun_730', 'dk_mun_751'),
#  ('dk_mun_730', 'dk_mun_846'),
#  ('dk_mun_746', 'dk_mun_751'),
#  ('dk_mun_751', 'dk_mun_751'),
#  ('dk_mun_751', 'dk_mun_791'),
#  ('dk_mun_751', 'dk_mun_851'),
#  ('dk_mun_756', 'dk_mun_791'),
#  ('dk_mun_787', 'dk_mun_787'),
#  ('dk_mun_791', 'dk_mun_791'),
#  ('dk_mun_791', 'dk_mun_851'),
#  ('dk_mun_810', 'dk_mun_851'),
#  ('dk_mun_810', 'dk_mun_860'),
#  ('dk_mun_813', 'dk_mun_813'),
#  ('dk_mun_813', 'dk_mun_851'),
#  ('dk_mun_846', 'dk_mun_846'),
#  ('dk_mun_846', 'dk_mun_851'),
#  ('dk_mun_849', 'dk_mun_851'),
#  ('dk_mun_851', 'dk_mun_851'),
#  ('dk_mun_851', 'dk_mun_860')}

# %%
energy_grid.nodes[list(municipality_nodes)[0]]
# Out:
# {'Bus Index': 76,
#  'Bus Name': 'A2',
#  'Station Full Name': 'Bjæverskov',
#  'Location Name': 'ENDKE',
#  'Voltage base[kV]': '232,0',
#  'Voltage min[pu]': '0,00',
#  'Voltage max[pu]': '1,05',
#  '_id': 76,
#  'ConnectionPointCode': 'BJS',
#  'ConnectionPointName': 'Bjæverskov',
#  'MunicipalityNo': '259',
#  'Municipality': 'Køge',
#  'RegionName': 'Sjælland',
#  'ConnectionPointLatitude': 55.45053,
#  'ConnectionPointLongitude': 12.00791,
#  'NetCompanyName': 'SEAS/NVE TRANSMISSION',
#  'region_code': 'dk_mun_259'}

# %%
import sqltables
db = sqltables.Database()
latlon = db.create_table(column_names=["region_code", "lat", "lon"])
latlon.insert([[x["region_code"], x["ConnectionPointLatitude"], x["ConnectionPointLongitude"]] 
               for x in (energy_grid.nodes[k] for k in municipality_nodes.keys())])

# %%
mun_latlon = latlon.table("""select region_code, avg(lat) as lat, avg(lon) as lon from _ group by region_code""")
mun_points = {row.region_code: (row.lat, row.lon) for row in mun_latlon}

# %%
mun_points
# Out:
# {'dk_mun_101': (55.67414544444444, 12.590287444444444),
#  'dk_mun_151': (55.744171, 12.32608),
#  'dk_mun_159': (55.7501205, 12.485704),
#  'dk_mun_161': (55.686573, 12.397478),
#  'dk_mun_167': (55.604988999999996, 12.480812),
#  'dk_mun_169': (55.660772, 12.319345),
#  'dk_mun_183': (55.6346, 12.32171),
#  'dk_mun_185': (55.631542, 12.657965),
#  'dk_mun_201': (55.885227, 12.338456),
#  'dk_mun_217': (56.028681, 12.563658),
#  'dk_mun_219': (55.8955735, 12.196541750000002),
#  'dk_mun_240': (55.755691, 12.198973),
#  'dk_mun_250': (55.80958483333333, 11.896245666666665),
#  'dk_mun_253': (55.585099, 12.258356),
#  'dk_mun_259': (55.45053, 12.00791),
#  'dk_mun_260': (55.961136, 12.019283),
#  'dk_mun_265': (55.6285435, 12.1149735),
#  'dk_mun_269': (55.54376, 12.20485),
#  'dk_mun_306': (55.871017, 11.603077),
#  'dk_mun_316': (55.717711, 11.491859),
#  'dk_mun_326': (55.66188011111111, 11.087549777777777),
#  'dk_mun_340': (55.545725, 11.641376),
#  'dk_mun_350': (55.645783333333334, 11.932815666666668),
#  'dk_mun_360': (54.840392, 11.188055),
#  'dk_mun_370': (55.2519275, 11.774001333333333),
#  'dk_mun_376': (54.959536, 11.174958250000001),
#  'dk_mun_390': (54.995765, 11.881601),
#  'dk_mun_410': (55.431521000000004, 9.980076666666667),
#  'dk_mun_420': (55.249257, 10.168535),
#  'dk_mun_461': (55.395611111111116, 10.45324588888889),
#  'dk_mun_479': (55.07023, 10.57612),
#  'dk_mun_540': (54.923616, 9.785672),
#  'dk_mun_550': (55.053378, 8.836996),
#  'dk_mun_561': (55.507125, 8.57783),
#  'dk_mun_573': (55.5797085, 8.224657),
#  'dk_mun_575': (55.496068, 9.0819125),
#  'dk_mun_580': (55.027822, 9.351661499999999),
#  'dk_mun_607': (55.53232200000001, 9.638878250000001),
#  'dk_mun_621': (55.545798999999995, 9.514843999999998),
#  'dk_mun_630': (55.712496, 9.489462),
#  'dk_mun_657': (55.952752, 8.797765),
#  'dk_mun_661': (56.352613, 8.552965),
#  'dk_mun_665': (56.49206, 8.218299),
#  'dk_mun_671': (56.483126, 8.575286),
#  'dk_mun_706': (56.366732, 10.498075),
#  'dk_mun_707': (56.421722, 10.895915),
#  'dk_mun_730': (56.449552499999996, 10.0378765),
#  'dk_mun_746': (56.076675, 10.028266),
#  'dk_mun_751': (56.21375709999999, 10.226045300000001),
#  'dk_mun_756': (55.929066, 9.182534),
#  'dk_mun_760': (56.103189, 8.598395),
#  'dk_mun_787': (56.920664, 8.5579575),
#  'dk_mun_791': (56.46265328571428, 9.570112714285715),
#  'dk_mun_810': (57.267212, 9.979697),
#  'dk_mun_813': (57.372611000000006, 10.419545),
#  'dk_mun_820': (56.9178, 9.299185),
#  'dk_mun_846': (56.670914499999995, 9.886837),
#  'dk_mun_849': (57.114087, 9.502717),
#  'dk_mun_851': (57.050576466666676, 10.003492533333334),
#  'dk_mun_860': (57.450695, 10.026742)}

# %%
connection_points = {(m1, m2): (mun_points[m1], mun_points[m2]) for m1, m2 in municipality_connections}

import json
with open("connection_points.json", "w+") as fileobj:
    json.dump(list(connection_points.values()), fileobj)
