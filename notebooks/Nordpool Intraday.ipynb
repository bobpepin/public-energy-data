# %%
import sys
sys.path.append("..")
import energydata.nordpoolspot
from tqdm.notebook import tqdm

# %%
descriptor = {"start_datetime": "2023-05-01", "end_datetime": "2023-05-05", "dataset": "intraday", "zone": "DK1"}
dataset = energydata.nordpoolspot.NordpoolSpot(descriptor)

# %%
it = dataset.fetch_data()

rows = list(tqdm(it))
rows
# Out:
# 0it [00:00, ?it/s]
# [{'start_datetime': '2023-05-01T00:00:00+02:00',
#   'end_datetime': '2023-05-01T01:00:00+02:00',
#   'Product': 'PH-20230501-01 (X)',
#   'High': 108.17,
#   'Low': 89.2,
#   'Last': 100.56,
#   'Avg': 99.75,
#   'Volume': 159.9,
#   'zone': 'DK1'},
#  {'start_datetime': '2023-05-01T01:00:00+02:00',
#   'end_datetime': '2023-05-01T02:00:00+02:00',
#   'Product': 'PH-20230501-02 (X)',
#   'High': 98.0,
#   'Low': 66.75,
#   'Last': 92.8,
#   'Avg': 87.1,
#   'Volume': 257.6,
#   'zone': 'DK1'},
#  {'start_datetime': '2023-05-01T02:00:00+02:00',
#   'end_datetime': '2023-05-01T03:00:00+02:00',
#   'Product': 'PH-20230501-03 (X)',
#   'High': 92.76,
#   'Low': 57.75,
#   'Last': 85.99,
#   'Avg': 83.46,
#   'Volume': 257.5,
#   'zone': 'DK1'},
#  {'start_datetime': '2023-05-01T03:00:00+02:00',
#   'end_datetime': '2023-05-01T04:00:00+02:00',
#   'Product': 'PH-20230501-04 (X)',
#   'High': 88.13,
#   'Low': 70.0,
#   'Last': 73.04,
#   'Avg': 79.43,
# ...
